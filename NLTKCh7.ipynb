# %% [markdown]
# # 7. Extracting Information from Text

# %% [markdown]
# For any given question, it's likely that someone has written the answer down somewhere. The amount of natural language text that is available in electronic form is truly staggering, and is increasing every day. However, the complexity of natural language can make it very difficult to access the information in that text. The state of the art in NLP is still a long way from being able to build general-purpose representations of meaning from unrestricted text. If we instead focus our efforts on a limited set of questions or "entity relations," such as "where are different facilities located," or "who is employed by what company," we can make significant progress. The goal of this chapter is to answer the following questions:
#
#     How can we build a system that extracts structured data, such as tables, from unstructured text?
#
#     What are some robust methods for identifying the entities and relationships described in a text?
#
#     Which corpora are appropriate for this work, and how do we use them for training and evaluating our
#     models?
#
# Along the way, we'll apply techniques from the last two chapters to the problems of chunking and named-entity recognition.

# %% [markdown]
# # 1   Information Extraction

# %% [raw]
# Information comes in many shapes and sizes. One important form is structured data, where there is a regular and predictable organization of entities and relationships. For example, we might be interested in the relation between companies and locations. Given a particular company, we would like to be able to identify the locations where it does business; conversely, given a location, we would like to discover which companies do business in that location. If our data is in tabular form, such as the example in 1.1, then answering these queries is straightforward.
#
# Table 1.1:
#
# Locations data
#
# OrgName 	          LocationName
# Omnicom 	          New York
# DDB Needham 	      New York
# Kaplan Thaler Group   New York
# BBDO South 	          Atlanta
# Georgia-Pacific 	  Atlanta
#
# If this location data was stored in Python as a list of tuples (entity, relation, entity), then the question "Which organizations operate in Atlanta?" could be translated as follows:

# %%
locs = [('Omnicom', 'IN', 'New York'),
        ('DDB Needham', 'IN', 'New York'),
        ('Kaplan Thaler Group', 'IN', 'New York'),
        ('BBDO South', 'IN', 'Atlanta'),
        ('Georgia-Pacific', 'IN', 'Atlanta')]
query = [e1 for (e1, rel, e2) in locs if e2=='Atlanta']
print(query)
# Out:
# ['BBDO South', 'Georgia-Pacific']

# %% [markdown]
# Things are more tricky if we try to get similar information out of text. For example, consider the following snippet (from nltk.corpus.ieer, for fileid NYT19980315.0085).
#
# (1)		The fourth Wells account moving to another agency is the packaged paper-products division of Georgia-Pacific Corp., which arrived at Wells only last fall. Like Hertz and the History Channel, it is also leaving for an Omnicom-owned agency, the BBDO South unit of BBDO Worldwide. BBDO South in Atlanta, which handles corporate advertising for Georgia-Pacific, will assume additional duties for brands like Angel Soft toilet tissue and Sparkle paper towels, said Ken Haldin, a spokesman for Georgia-Pacific in Atlanta.
#
# If you read through (1), you will glean the information required to answer the example question. But how do we get a machine to understand enough about (1) to return the answers in 1.2? This is obviously a much harder task. Unlike 1.1, (1) contains no structure that links organization names with location names.
#
# One approach to this problem involves building a very general representation of meaning (10.). In this chapter we take a different approach, deciding in advance that we will only look for very specific kinds of information in text, such as the relation between organizations and locations. Rather than trying to use text like (1) to answer the question directly, we first convert the unstructured data of natural language sentences into the structured data of 1.1. Then we reap the benefits of powerful query tools such as SQL. This method of getting meaning from text is called Information Extraction.
#
# Information Extraction has many applications, including business intelligence, resume harvesting, media analysis, sentiment detection, patent search, and email scanning. A particularly important area of current research involves the attempt to extract structured data out of electronically-available scientific literature, especially in the domain of biology and medicine.

# %% [markdown]
# ## 1.1   Information Extraction Architecture

# %% [markdown]
# 1.1 shows the architecture for a simple information extraction system. It begins by processing a document using several of the procedures discussed in 3 and 5.: first, the raw text of the document is split into sentences using a sentence segmenter, and each sentence is further subdivided into words using a tokenizer. Next, each sentence is tagged with part-of-speech tags, which will prove very helpful in the next step, named entity detection. In this step, we search for mentions of potentially interesting entities in each sentence. Finally, we use relation detection to search for likely relations between different entities in the text.
#
# Figure 1.1: Simple Pipeline Architecture for an Information Extraction System. This system takes the raw text of a document as its input, and generates a list of (entity, relation, entity) tuples as its output. For example, given a document that indicates that the company Georgia-Pacific is located in Atlanta, it might generate the tuple ([ORG: 'Georgia-Pacific'] 'in' [LOC: 'Atlanta']).
#
# To perform the first three tasks, we can define a simple function that simply connects together NLTK's default sentence segmenter [1], word tokenizer [2], and part-of-speech tagger [3]:

# %%
# Important: From this chapter onwards, our program samples will assume you begin your interactive session or your program with the 
# following import statements:

from __future__ import division  # Python 2 users only
import nltk, re, pprint
from nltk import word_tokenize
from __future__ import print_function

def ie_preprocess(document):
    sentences = nltk.sent_tokenize(document)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    sentences = [nltk.pos_tag(sent) for sent in sentences]

# This might be all I need for now. I am not sure about including the NER tags?

# %%
# Me playing with this code

def ie_preprocess(document):
    sentences = nltk.sent_tokenize(document)
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    sentences = [nltk.pos_tag(sent) for sent in sentences]
    return sentences

sample_string = ''' 1.1 shows the architecture for a simple information extraction system. It begins by 
processing a document using several of the procedures discussed in 3 and 5.: first, the raw text of the document is 
split into sentences using a sentence segmenter, and each sentence is further subdivided into words using a 
tokenizer. Next, each sentence is tagged with part-of-speech tags, which will prove very helpful in the next 
step, named entity detection. In this step, we search for mentions of potentially interesting entities in 
each sentence. Finally, we use relation detection to search for likely relations between different entities 
in the text. Figure 1.1: Simple Pipeline Architecture for an Information Extraction System. This system takes
the raw text of a document as its input, and generates a list of (entity, relation, entity) tuples as its 
output. For example, given a document that indicates that the company Georgia-Pacific is located in Atlanta, 
it might generate the tuple ([ORG: 'Georgia-Pacific'] 'in' [LOC: 'Atlanta']). To perform the first three 
tasks, we can define a simple function that simply connects together NLTK's default sentence segmenter [1], 
word tokenizer [2], and part-of-speech tagger [3]:
'''

sentences = ie_preprocess(sample_string)


print (sentences[8])

#len(sentences)
#sentences[8]
# Out:
# [('To', 'TO'), ('perform', 'VB'), ('the', 'DT'), ('first', 'JJ'), ('three', 'CD'), ('tasks', 'NNS'), (',', ','), ('we', 'PRP'), ('can', 'MD'), ('define', 'VB'), ('a', 'DT'), ('simple', 'JJ'), ('function', 'NN'), ('that', 'WDT'), ('simply', 'RB'), ('connects', 'VBZ'), ('together', 'RB'), ('NLTK', 'NNP'), ("'s", 'POS'), ('default', 'NN'), ('sentence', 'NN'), ('segmenter', 'NN'), ('[', 'VBD'), ('1', 'CD'), (']', 'NN'), (',', ','), ('word', 'NN'), ('tokenizer', 'NN'), ('[', '$'), ('2', 'CD'), (']', 'NNP'), (',', ','), ('and', 'CC'), ('part-of-speech', 'JJ'), ('tagger', 'NN'), ('[', 'VBD'), ('3', 'CD'), (']', 'NNS'), (':', ':')]

# %%
nltk.ChunkParserI
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-672ca39eb61a> in <module>()
# ----> 1 nltk.ChunkParserI
#
# NameError: name 'nltk' is not defined

# %% [markdown]
# Next, in named entity detection, we segment and label the entities that might participate in interesting relations with one another. Typically, these will be definite noun phrases such as the knights who say "ni", or proper names such as Monty Python. In some tasks it is useful to also consider indefinite nouns or noun chunks, such as every student or cats, and these do not necessarily refer to entities in the same way as definite NPs and proper names.
#
# Finally, in relation extraction, we search for specific patterns between pairs of entities that occur near one another in the text, and use those patterns to build tuples recording the relationships between the entities.

# %% [markdown]
# # 2   Chunking

# %% [raw]
# The basic technique we will use for entity detection is chunking, which segments and labels multi-token sequences as illustrated in 2.1. The smaller boxes show the word-level tokenization and part-of-speech tagging, while the large boxes show higher-level chunking. Each of these larger boxes is called a chunk. Like tokenization, which omits whitespace, chunking usually selects a subset of the tokens. Also like tokenization, the pieces produced by a chunker do not overlap in the source text.
#
#
#  We     saw    | the    yellow   dog|
#  PRP    VBD    | DT       JJ      NN|
# -------------------------------------
# |NP |          |       NP           |
#
# Figure 2.1: Segmentation and Labeling at both the Token and Chunk Levels
#
# In this section, we will explore chunking in some depth, beginning with the definition and representation of chunks. We will see regular expression and n-gram approaches to chunking, and will develop and evaluate chunkers using the CoNLL-2000 chunking corpus. We will then return in (5) and 6 to the tasks of named entity recognition and relation extraction.

# %% [markdown]
# ## 2.1   Noun Phrase Chunking

# %% [markdown]
# We will begin by considering the task of noun phrase chunking, or NP-chunking, where we search for chunks corresponding to individual noun phrases. For example, here is some Wall Street Journal text with NP-chunks marked using brackets:
#
# (2)		[ The/DT market/NN ] for/IN [ system-management/NN software/NN ] for/IN [ Digital/NNP ] [ 's/POS hardware/NN ] is/VBZ fragmented/JJ enough/RB that/IN [ a/DT giant/NN ] such/JJ as/IN [ Computer/NNP Associates/NNPS ] should/MD do/VB well/RB there/RB ./.
#
# As we can see, NP-chunks are often smaller pieces than complete noun phrases. For example, the market for system-management software for Digital's hardware is a single noun phrase (containing two nested noun phrases), but it is captured in NP-chunks by the simpler chunk the market. One of the motivations for this difference is that NP-chunks are defined so as not to contain other NP-chunks. Consequently, any prepositional phrases or subordinate clauses that modify a nominal will not be included in the corresponding NP-chunk, since they almost certainly contain further noun phrases.
#
# One of the most useful sources of information for NP-chunking is part-of-speech tags. This is one of the motivations for performing part-of-speech tagging in our information extraction system. We demonstrate this approach using an example sentence that has been part-of-speech tagged in 2.2. In order to create an NP-chunker, we will first define a chunk grammar, consisting of rules that indicate how sentences should be chunked. In this case, we will define a simple grammar with a single regular-expression rule [2]. This rule says that an NP chunk should be formed whenever the chunker finds an optional determiner (DT) followed by any number of adjectives (JJ) and then a noun (NN). Using this grammar, we create a chunk parser [3], and test it on our example sentence [4]. The result is a tree, which we can either print [5], or display graphically [6].
#
# Note to self: when starting out, just use default noun chunkers and taggers.

# %%
sentence = [("the", "DT"), ("little", "JJ"), ("yellow", "JJ"), 
("dog", "NN"), ("barked", "VBD"), ("at", "IN"),  ("the", "DT"), ("cat", "NN")]

grammar = "NP: {<DT>?<JJ>*<NN>}" # [2]
# ?: 0 or 1
# *: 0 or any number
# <NN>: just one noun. There are no quantifiers here

cp = nltk.RegexpParser(grammar)# [3]
result = cp.parse(sentence) # [4]
print(result) # [5]
result.draw()
# Out:
# (S
#   (NP the/DT little/JJ yellow/JJ dog/NN)
#   barked/VBD
#   at/IN
#   (NP the/DT cat/NN))

# %% [markdown]
# ## 2.2   Tag Patterns

# %% [raw]
# The rules that make up a chunk grammar use tag patterns to describe sequences of tagged words. A tag pattern is a sequence of part-of-speech tags delimited using angle brackets, e.g. <DT>?<JJ>*<NN>. Tag patterns are similar to regular expression patterns (3.4). Now, consider the following noun phrases from the Wall Street Journal:
#
# another/DT sharp/JJ dive/NN
# trade/NN figures/NNS
# any/DT new/JJ policy/NN measures/NNS
# earlier/JJR stages/NNS
# Panamanian/JJ dictator/NN Manuel/NNP Noriega/NNP
#
# We can match these noun phrases using a slight refinement of the first tag pattern above, i.e. <DT>?<JJ.*>*<NN.*>+.
#
# Note: JJ.* allows us to capture both JJ and JJR. Similarly, NN.* allows us to capture all sorts of nouns, including NN, NNS, NNP, etc. Finally + means "1 or more."
#
# This will chunk any sequence of tokens beginning with an optional determiner, followed by zero or more adjectives of any type (including relative adjectives like earlier/JJR), followed by one or more nouns of any type. However, it is easy to find many more complicated examples which this rule will not cover:
#
# his/PRP$ Mansion/NNP House/NNP speech/NN : preposition before noun(s)
# the/DT price/NN cutting/VBG : noun followed by verb gerund?
# 3/CD %/NN to/TO 4/CD %/NN : 3% to 4% as a noun phrase. Not sure how to speak about this?
# more/JJR than/IN 10/CD %/NN : "more than 10%" as a noun phrase.
# the/DT fastest/JJS developing/VBG trends/NNS : VNG before noun.
# 's/POS skill/NN : Not sure what POS is?
#
# Note
#
# Your Turn: Try to come up with tag patterns to cover these cases. Test them using the graphical interface nltk.app.chunkparser(). Continue to refine your tag patterns with the help of the feedback given by this tool.

# %%
# More practice with NP-chunking...

phrase1 = [("another", "DT"), ("sharp", "JJ") , ("dive", "NN")]
phrase2 = [("trade", "NN"), ("figures", "NNS")]
phrase3 = [("any", "DT"), ("new", "JJ"), ("policy", "NN"), ("measures", "NNS")]
phrase4 = [("earlier", "JJR"), ("stages", "NNS")]
phrase5 = [("Panamanian", "JJ"), ("dictator", "NN"), ("Manuel", "NNP"), ("Noriega", "NNP")]
phrase6 = [("his", "PRP$"), ("Mansion", "NNP"), ("House", "NNP"), ("speech", "NN")]
phrase7 = [("the", "DT"), ("price", "NN"), ("cutting", "VBG")]
phrase8 = [("3", "CD"), ("%", "NN"), ("to", "TO"), ("4", "CD"), ("%", "NN")]
phrase9 = [("more", "JJR"), ("than", "IN"), ("10", "CD"), ("%", "NN")]
phrase10 = [("the", "DT"), ("fastest", "JJS"), ("developing", "VBG"), ("trends", "NNS")]
phrase11 = [("'s", "POS"), ("skill", "NN")]

grammar1 = "NP: {<DT>?<JJ>*<NN>}"
grammar2 = "NP: {<DT>?<JJ>*<NN.*>+}"
grammar3 = "NP: {<DT>?<JJ.*>*<NN.*>+}"
grammar4 = "NP: {<DT|PRP.*>?<JJ.*>*<NN.*>+}"
grammar5 = "NP: {<DT|PRP.*>?<JJ.*>*<NN.*>+<VBG>?}"
grammar6 = """
NP: {<CD>?<NN.*>+<TO>*<CD>?<NN.*>+}
NP: {<DT|PRP.*>?<JJ.*>*<NN.*>+<VBG>?}
"""
grammar7 = """
NP: {<JJ.*>?<IN>?<CD>?<NN.*>+<TO>?<CD>?<NN.*>*}
NP: {<DT|PRP.*>?<JJ.*>*<NN.*>+<VBG>?}
"""
grammar8 = """
NP: {<DT|PRP.*>?<JJ.*>*<VBG>?<NN.*>+}
NP: {<JJ.*>?<IN>?<CD>?<NN.*>+<TO>?<CD>?<NN.*>*}
NP: {<DT|PRP.*>?<JJ.*>*<NN.*>+<VBG>?}
"""
grammar9 = """
NP: {<POS>?<NN.*>+}
NP: {<DT|PRP.*>?<JJ.*>*<VBG>?<NN.*>+}
NP: {<JJ.*>?<IN>?<CD>?<NN.*>+<TO>?<CD>?<NN.*>*}
NP: {<DT|PRP.*>?<JJ.*>*<NN.*>+<VBG>?}
"""

# note that you should do the most irregular noun phrases in the beginning. it will match them first.
# Also, you do not have to define one regular expression for every possible noun phrase. You can have a number of noun phrases defined.

cp = nltk.RegexpParser(grammar9)
result = cp.parse(phrase1)
print(result)
result = cp.parse(phrase2)
print(result)
result = cp.parse(phrase3)
print(result)
result = cp.parse(phrase4)
print(result)
result = cp.parse(phrase5)
print(result)
result = cp.parse(phrase6)
print(result)
result = cp.parse(phrase7)
print(result)
result = cp.parse(phrase8)
print(result)
result = cp.parse(phrase9)
print(result)
result = cp.parse(phrase10)
print(result)
result = cp.parse(phrase11)
print(result)

# result.draw()

# try to do a loop later.
# Out:
# (S another/DT sharp/JJ (NP dive/NN))
# (S (NP trade/NN figures/NNS))
# (S any/DT new/JJ (NP policy/NN measures/NNS))
# (S earlier/JJR (NP stages/NNS))
# (S Panamanian/JJ (NP dictator/NN Manuel/NNP Noriega/NNP))
# (S his/PRP$ (NP Mansion/NNP House/NNP speech/NN))
# (S the/DT (NP price/NN) cutting/VBG)
# (S 3/CD (NP %/NN) to/TO 4/CD (NP %/NN))
# (S more/JJR than/IN 10/CD (NP %/NN))
# (S the/DT fastest/JJS developing/VBG (NP trends/NNS))
# (S (NP 's/POS skill/NN))

# %% [markdown]
# ## 2.3   Chunking with Regular Expressions

# %% [markdown]
# To find the chunk structure for a given sentence, the RegexpParser chunker begins with a flat structure in which no tokens are chunked. The chunking rules are applied in turn, successively updating the chunk structure. Once all of the rules have been invoked, the resulting chunk structure is returned.
#
# 2.3 shows a simple chunk grammar consisting of two rules. The first rule matches an optional determiner or possessive pronoun, zero or more adjectives, then a noun. The second rule matches one or more proper nouns. We also define an example sentence to be chunked [1], and run the chunker on this input [2].

# %%
grammar = r"""
  NP: {<DT|PP\$>?<JJ>*<NN>}   # chunk determiner/possessive, adjectives and noun
      {<NNP>+}                # chunk sequences of proper nouns
"""
cp = nltk.RegexpParser(grammar)
sentence = [("Rapunzel", "NNP"), ("let", "VBD"), ("down", "RP"),
                 ("her", "PP$"), ("long", "JJ"), ("golden", "JJ"), ("hair", "NN")]
print(cp.parse(sentence))
# Out:
# (S
#   (NP Rapunzel/NNP)
#   let/VBD
#   down/RP
#   (NP her/PP$ long/JJ golden/JJ hair/NN))

# %% [raw]
# Note
#
# The $ symbol is a special character in regular expressions, and must be backslash escaped in order to match the tag PP$.
#
# If a tag pattern matches at overlapping locations, the leftmost match takes precedence. For example, if we apply a rule that matches two consecutive nouns to a text containing three consecutive nouns, then only the first two nouns will be chunked:

# %%
nouns = [("money", "NN"), ("market", "NN"), ("fund", "NN")]
grammar = "NP: {<NN><NN>}  # Chunk two consecutive nouns"
cp = nltk.RegexpParser(grammar)
print(cp.parse(nouns))
# Out:
# (S (NP money/NN market/NN) fund/NN)

# %% [raw]
# Once we have created the chunk for money market, we have removed the context that would have permitted fund to be included in a chunk. This issue would have been avoided with a more permissive chunk rule, e.g. NP: {<NN>+}.
#
# Note
#
# We have added a comment to each of our chunk rules. These are optional; when they are present, the chunker prints these comments as part of its tracing output.

# %% [markdown]
# ## Exploring Text Corpora

# %% [markdown]
# In 2 we saw how we could interrogate a tagged corpus to extract phrases matching a particular sequence of part-of-speech tags. We can do the same work more easily with a chunker, as follows:

# %%
cp = nltk.RegexpParser('CHUNK: {<V.*> <TO> <V.*>}')
brown = nltk.corpus.brown
for sent in brown.tagged_sents():
    tree = cp.parse(sent)
    for subtree in tree.subtrees():
        if subtree.label() == 'CHUNK': print(subtree)
# Out:
# (CHUNK combined/VBN to/TO achieve/VB)
# (CHUNK continue/VB to/TO place/VB)
# (CHUNK serve/VB to/TO protect/VB)
# (CHUNK wanted/VBD to/TO wait/VB)
# (CHUNK allowed/VBN to/TO place/VB)
# (CHUNK expected/VBN to/TO become/VB)
# (CHUNK expected/VBN to/TO approve/VB)
# (CHUNK expected/VBN to/TO make/VB)
# (CHUNK intends/VBZ to/TO make/VB)
# (CHUNK seek/VB to/TO set/VB)
# (CHUNK like/VB to/TO see/VB)
# (CHUNK designed/VBN to/TO provide/VB)
# (CHUNK get/VB to/TO hear/VB)
# (CHUNK expects/VBZ to/TO tell/VB)
# (CHUNK expected/VBN to/TO give/VB)
# (CHUNK prefer/VB to/TO pay/VB)
# (CHUNK required/VBN to/TO obtain/VB)
# (CHUNK permitted/VBN to/TO teach/VB)
# (CHUNK designed/VBN to/TO reduce/VB)
# (CHUNK Asked/VBN to/TO elaborate/VB)
# (CHUNK got/VBN to/TO go/VB)
# (CHUNK raised/VBN to/TO pay/VB)
# (CHUNK scheduled/VBN to/TO go/VB)
# (CHUNK cut/VBN to/TO meet/VB)
# (CHUNK needed/VBN to/TO meet/VB)
# (CHUNK hastened/VBD to/TO add/VB)
# (CHUNK found/VBN to/TO prevent/VB)
# (CHUNK continue/VB to/TO insist/VB)
# (CHUNK compelled/VBN to/TO make/VB)
# (CHUNK made/VBN to/TO remove/VB)
# (CHUNK revamped/VBN to/TO give/VB)
# (CHUNK want/VB to/TO risk/VB)
# (CHUNK appear/VB to/TO spark/VB)
# (CHUNK fails/VBZ to/TO consider/VB)
# (CHUNK plans/VBZ to/TO call/VB)
# (CHUNK going/VBG to/TO examine/VB)
# (CHUNK plans/VBZ to/TO name/VB)
# (CHUNK come/VBN to/TO pass/VB)
# (CHUNK voted/VBD to/TO accept/VB)
# (CHUNK happens/VBZ to/TO hold/VB)
# (CHUNK authorized/VBN to/TO adopt/VB)
# (CHUNK hesitated/VBN to/TO prosecute/VB)
# (CHUNK try/VB to/TO make/VB)
# (CHUNK decided/VBN to/TO spend/VB)
# (CHUNK taken/VBN to/TO preserve/VB)
# (CHUNK left/VBN to/TO preserve/VB)
# (CHUNK stand/VB to/TO bring/VB)
# (CHUNK decided/VBN to/TO seek/VB)
# (CHUNK trying/VBG to/TO induce/VB)
# (CHUNK proposing/VBG to/TO make/VB)
# (CHUNK decided/VBN to/TO run/VB)
# (CHUNK directed/VBN to/TO investigate/VB)
# (CHUNK expected/VBN to/TO pass/VB)
# (CHUNK expected/VBN to/TO make/VB)
# (CHUNK expected/VBN to/TO encounter/VB)
# (CHUNK hopes/VBZ to/TO pass/VB)
# (CHUNK came/VBD to/TO pay/VB)
# (CHUNK expected/VBN to/TO receive/VB)
# (CHUNK understood/VBN to/TO follow/VB)
# (CHUNK wanted/VBD to/TO vote/VB)
# (CHUNK decide/VB to/TO call/VB)
# (CHUNK begin/VB to/TO flow/VB)
# (CHUNK appears/VBZ to/TO face/VB)
# (CHUNK fails/VBZ to/TO pass/VB)
# (CHUNK care/VB to/TO acknowledge/VB)
# (CHUNK like/VB to/TO convey/VB)
# (CHUNK continued/VBD to/TO wage/VB)
# (CHUNK try/VB to/TO avoid/VB)
# (CHUNK done/VBN to/TO arouse/VB)
# (CHUNK tried/VBN to/TO economize/VB)
# (CHUNK agreed/VBN to/TO cooperate/VB)
# (CHUNK want/VB to/TO find/VB)
# (CHUNK expected/VBN to/TO raise/VB)
# (CHUNK agreed/VBD to/TO form/VB)
# (CHUNK threatened/VBD to/TO form/VB)
# (CHUNK failed/VBD to/TO sign/VB)
# (CHUNK trying/VBG to/TO build/VB)
# (CHUNK plan/VB to/TO absorb/VB)
# (CHUNK working/VBG to/TO establish/VB)
# (CHUNK expects/VBZ to/TO evacuate/VB)
# (CHUNK need/VB to/TO hear/VB)
# (CHUNK scheduled/VBN to/TO hold/VB)
# (CHUNK decided/VBD to/TO ask/VB)
# (CHUNK scheduled/VBN to/TO fill/VB)
# (CHUNK going/VBG to/TO determine/VB)
# (CHUNK urged/VBN to/TO move/VB)
# (CHUNK conpired/VBN to/TO use/VB)
# (CHUNK used/VBN to/TO carry/VB)
# (CHUNK needed/VBD to/TO face/VB)
# (CHUNK failed/VBD to/TO tally/VB)
# (CHUNK failed/VBD to/TO produce/VB)
# (CHUNK tried/VBD to/TO stretch/VB)
# (CHUNK hopes/VBZ to/TO melt/VB)
# (CHUNK slated/VBN to/TO oppose/VB)
# (CHUNK scheduled/VBN to/TO share/VB)
# (CHUNK plans/VBZ to/TO bring/VB)
# (CHUNK seek/VB to/TO trim/VB)
# (CHUNK seems/VBZ to/TO improve/VB)
# (CHUNK appeared/VBD to/TO win/VB)
# (CHUNK gets/VBZ to/TO play/VB)
# (CHUNK hopes/VBZ to/TO start/VB)
# (CHUNK tried/VBN to/TO teach/VB)
# (CHUNK seem/VB to/TO get/VB)
# (CHUNK started/VBD to/TO form/VB)
# (CHUNK like/VB to/TO keep/VB)
# (CHUNK want/VB to/TO talk/VB)
# (CHUNK continue/VB to/TO abide/VB)
# (CHUNK refused/VBN to/TO reconsider/VB)
# (CHUNK expected/VBN to/TO put/VB)
# (CHUNK resigned/VBD to/TO take/VB)
# (CHUNK sought/VBD to/TO convince/VB)
# (CHUNK tried/VBD to/TO blast/VB)
# (CHUNK tried/VBD to/TO keep/VB)
# (CHUNK happened/VBD to/TO think/VB)
# (CHUNK expected/VBN to/TO continue/VB)
# (CHUNK plans/VBZ to/TO open/VB)
# (CHUNK recovering/VBG to/TO make/VB)
# (CHUNK supposed/VBN to/TO deliver/VB)
# (CHUNK get/VB to/TO like/VB)
# (CHUNK want/VB to/TO thank/VB)
# (CHUNK set/VBN to/TO play/VB)
# (CHUNK going/VBG to/TO pass/VB)
# (CHUNK paid/VBN to/TO play/VB)
# (CHUNK wanted/VBD to/TO pop/VB)
# (CHUNK expect/VB to/TO establish/VB)
# (CHUNK going/VBG to/TO try/VB)
# (CHUNK signed/VBD to/TO play/VB)
# (CHUNK fly/VB to/TO collect/VB)
# (CHUNK helps/VBZ to/TO bridge/VB)
# (CHUNK wants/VBZ to/TO pick/VB)
# (CHUNK relearns/VBZ to/TO mingle/VB)
# (CHUNK watching/VBG to/TO see/VB)
# (CHUNK learn/VB to/TO readjust/VB)
# (CHUNK promises/VBZ to/TO follow/VB)
# (CHUNK expect/VB to/TO offer/VB)
# (CHUNK like/VB to/TO come/VB)
# (CHUNK like/VB to/TO bring/VB)
# (CHUNK combined/VBD to/TO form/VB)
# (CHUNK chosen/VBN to/TO rule/VB)
# (CHUNK attempted/VBD to/TO stop/VB)
# (CHUNK required/VBN to/TO use/VB)
# (CHUNK prepared/VBN to/TO grant/VB)
# (CHUNK refused/VBD to/TO return/VB)
# (CHUNK demanded/VBD to/TO know/VB)
# (CHUNK decided/VBD to/TO end/VB)
# (CHUNK offered/VBD to/TO supply/VB)
# (CHUNK designed/VBN to/TO seek/VB)
# (CHUNK get/VB to/TO know/VB)
# (CHUNK get/VB to/TO know/VB)
# (CHUNK going/VBG to/TO call/VB)
# (CHUNK attempted/VBD to/TO end/VB)
# (CHUNK forbidden/VBN to/TO drive/VB)
# (CHUNK failed/VBD to/TO reach/VB)
# (CHUNK wish/VB to/TO appear/VB)
# (CHUNK hopes/VBZ to/TO rebuild/VB)
# (CHUNK used/VBN to/TO provide/VB)
# (CHUNK wanted/VBD to/TO make/VB)
# (CHUNK trying/VBG to/TO land/VB)
# (CHUNK prepared/VBN to/TO accept/VB)
# (CHUNK continue/VB to/TO operate/VB)
# (CHUNK taken/VBN to/TO overcome/VB)
# (CHUNK intend/VB to/TO make/VB)
# (CHUNK desiring/VBG to/TO study/VB)
# (CHUNK designed/VBN to/TO assure/VB)
# (CHUNK intend/VB to/TO attend/VB)
# (CHUNK failed/VBD to/TO cooperate/VB)
# (CHUNK agree/VB to/TO attend/VB)
# (CHUNK decided/VBD to/TO attend/VB)
# (CHUNK scheduled/VBN to/TO begin/VB)
# (CHUNK agreed/VBN to/TO meet/VB)
# (CHUNK failed/VBN to/TO show/VB)
# (CHUNK declined/VBD to/TO name/VB)
# (CHUNK tried/VBD to/TO subdue/VB)
# (CHUNK planning/VBG to/TO expand/VB)
# (CHUNK thought/VBN to/TO infest/VB)
# (CHUNK voted/VBD to/TO decertify/VB)
# (CHUNK designed/VBN to/TO give/VB)
# (CHUNK continued/VBD to/TO run/VB)
# (CHUNK failed/VBD to/TO place/VB)
# (CHUNK started/VBN to/TO turn/VB)
# (CHUNK bought/VBN to/TO provide/VB)
# (CHUNK asked/VBN to/TO set/VB)
# (CHUNK vote/VB to/TO appeal/VB)
# (CHUNK failed/VBD to/TO reach/VB)
# (CHUNK failed/VBD to/TO destroy/VB)
# (CHUNK encouraged/VBN to/TO try/VB)
# (CHUNK managed/VBD to/TO maneuver/VB)
# (CHUNK obligated/VBN to/TO make/VB)
# (CHUNK promised/VBD to/TO get/VB)
# (CHUNK attempting/VBG to/TO connect/VB)
# (CHUNK prepared/VBN to/TO answer/VB)
# (CHUNK failed/VBD to/TO report/VB)
# (CHUNK attempted/VBD to/TO cash/VB)
# (CHUNK wanting/VBG to/TO get/VB)
# (CHUNK combined/VBD to/TO make/VB)
# (CHUNK continue/VB to/TO grab/VB)
# (CHUNK designed/VBN to/TO provide/VB)
# (CHUNK appear/VB to/TO favor/VB)
# (CHUNK declined/VBD to/TO suggest/VB)
# (CHUNK expected/VBN to/TO advance/VB)
# (CHUNK required/VBN to/TO reach/VB)
# (CHUNK fail/VB to/TO give/VB)
# (CHUNK began/VBD to/TO come/VB)
# (CHUNK undertake/VB to/TO reply/VB)
# (CHUNK found/VBN to/TO deal/VB)
# (CHUNK forced/VBN to/TO buy/VB)
# (CHUNK starting/VBG to/TO get/VB)
# (CHUNK inclined/VBN to/TO explain/VB)
# (CHUNK supposed/VBN to/TO look/VB)
# (CHUNK chose/VBD to/TO take/VB)
# (CHUNK used/VBN to/TO emphasize/VB)
# (CHUNK seem/VB to/TO realize/VB)
# (CHUNK happen/VB to/TO grow/VB)
# (CHUNK tried/VBN to/TO compromise/VB)
# (CHUNK scheduled/VBN to/TO arrive/VB)
# (CHUNK prefer/VB to/TO see/VB)
# (CHUNK set/VBN to/TO open/VB)
# (CHUNK expected/VBN to/TO prove/VB)
# (CHUNK try/VB to/TO influence/VB)
# (CHUNK strive/VB to/TO set/VB)
# (CHUNK decided/VBD to/TO try/VB)
# (CHUNK asked/VBN to/TO read/VB)
# (CHUNK prepared/VBN to/TO demonstrate/VB)
# (CHUNK led/VBN to/TO believe/VB)
# (CHUNK went/VBD to/TO see/VB)
# (CHUNK begun/VBN to/TO pall/VB)
# (CHUNK going/VBG to/TO get/VB)
# (CHUNK painted/VBN to/TO match/VB)
# (CHUNK appointed/VBN to/TO serve/VB)
# (CHUNK expected/VBN to/TO register/VB)
# (CHUNK failed/VBD to/TO materialize/VB)
# (CHUNK wanted/VBD to/TO buy/VB)
# (CHUNK begin/VB to/TO implement/VB)
# (CHUNK tended/VBD to/TO confirm/VB)
# (CHUNK want/VB to/TO appear/VB)
# (CHUNK try/VB to/TO probe/VB)
# (CHUNK determined/VBN to/TO apply/VB)
# (CHUNK come/VBN to/TO warn/VB)
# (CHUNK known/VBN to/TO rely/VB)
# (CHUNK try/VB to/TO exploit/VB)
# (CHUNK tended/VBD to/TO cancel/VB)
# (CHUNK cease/VB to/TO marvel/VB)
# (CHUNK seem/VB to/TO represent/VB)
# (CHUNK seems/VBZ to/TO show/VB)
# (CHUNK declines/VBZ to/TO gamble/VB)
# (CHUNK needs/VBZ to/TO feel/VB)
# (CHUNK advanced/VBN to/TO argue/VB)
# (CHUNK undertakes/VBZ to/TO fight/VB)
# (CHUNK decided/VBD to/TO keep/VB)
# (CHUNK advertising/VBG to/TO attract/VB)
# (CHUNK wants/VBZ to/TO operate/VB)
# (CHUNK varied/VBN to/TO provide/VB)
# (CHUNK designed/VBN to/TO reduce/VB)
# (CHUNK use/VB to/TO deny/VB)
# (CHUNK combining/VBG to/TO lower/VB)
# (CHUNK combining/VBG to/TO raise/VB)
# (CHUNK intended/VBN to/TO effect/VB)
# (CHUNK tend/VB to/TO convert/VB)
# (CHUNK exist/VB to/TO raise/VB)
# (CHUNK wish/VB to/TO prevent/VB)
# (CHUNK wish/VB to/TO preserve/VB)
# (CHUNK attempting/VBG to/TO extend/VB)
# (CHUNK made/VBN to/TO take/VB)
# (CHUNK continue/VB to/TO set/VB)
# (CHUNK trying/VBG to/TO persuade/VB)
# (CHUNK attempted/VBD to/TO take/VB)
# (CHUNK decided/VBD to/TO break/VB)
# (CHUNK braced/VBN to/TO move/VB)
# (CHUNK needed/VBN to/TO keep/VB)
# (CHUNK used/VBN to/TO carry/VB)
# (CHUNK decided/VBD to/TO go/VB)
# (CHUNK happens/VBZ to/TO benefit/VB)
# (CHUNK attempted/VBD to/TO work/VB)
# (CHUNK decided/VBD to/TO join/VB)
# (CHUNK said/VBN to/TO regard/VB)
# (CHUNK sought/VBD to/TO bring/VB)
# (CHUNK want/VB to/TO give/VB)
# (CHUNK voting/VBG to/TO cut/VB)
# (CHUNK prepared/VBD to/TO choke/VB)
# (CHUNK used/VBD to/TO approach/VB)
# (CHUNK trying/VBG to/TO hit/VB)
# (CHUNK refused/VBD to/TO let/VB)
# (CHUNK began/VBD to/TO acquire/VB)
# (CHUNK proceeded/VBD to/TO sink/VB)
# (CHUNK proceeded/VBD to/TO follow/VB)
# (CHUNK hoping/VBG to/TO slice/VB)
# (CHUNK chose/VBD to/TO hit/VB)
# (CHUNK like/VB to/TO hit/VB)
# (CHUNK tries/VBZ to/TO answer/VB)
# (CHUNK want/VB to/TO talk/VB)
# (CHUNK got/VBN to/TO get/VB)
# (CHUNK used/VBD to/TO follow/VB)
# (CHUNK try/VB to/TO play/VB)
# (CHUNK conspired/VBN to/TO lose/VB)
# (CHUNK needed/VBN to/TO revive/VB)
# (CHUNK chosen/VBN to/TO run/VB)
# (CHUNK hopes/VBZ to/TO visit/VB)
# (CHUNK got/VBD to/TO see/VB)
# (CHUNK arranged/VBD to/TO sell/VB)
# (CHUNK delighted/VBN to/TO get/VB)
# (CHUNK want/VB to/TO enjoy/VB)
# (CHUNK tried/VBN to/TO get/VB)
# (CHUNK try/VB to/TO close/VB)
# (CHUNK required/VBN to/TO furnish/VB)
# (CHUNK obliged/VBN to/TO dole/VB)
# (CHUNK wished/VBD to/TO wait/VB)
# (CHUNK decided/VBD to/TO act/VB)
# (CHUNK hoped/VBN to/TO attend/VB)
# (CHUNK like/VB to/TO woo/VB)
# (CHUNK prepared/VBN to/TO discuss/VB)
# (CHUNK wanted/VBD to/TO go/VB)
# (CHUNK allowed/VBN to/TO file/VB)
# (CHUNK tried/VBD to/TO persuade/VB)
# (CHUNK began/VBD to/TO tell/VB)
# (CHUNK hoped/VBD to/TO peddle/VB)
# (CHUNK intended/VBN to/TO insure/VB)
# (CHUNK decided/VBD to/TO provide/VB)
# (CHUNK expected/VBN to/TO go/VB)
# (CHUNK expected/VBN to/TO sign/VB)
# (CHUNK like/VB to/TO eat/VB)
# (CHUNK like/VB to/TO talk/VB)
# (CHUNK ceased/VBN to/TO grumble/VB)
# (CHUNK tending/VBG to/TO bid/VB)
# (CHUNK start/VB to/TO pay/VB)
# (CHUNK failed/VBN to/TO measure/VB)
# (CHUNK going/VBG to/TO take/VB)
# (CHUNK needed/VBN to/TO push/VB)
# (CHUNK trying/VBG to/TO get/VB)
# (CHUNK try/VB to/TO get/VB)
# (CHUNK want/VB to/TO increase/VB)
# (CHUNK wants/VBZ to/TO bring/VB)
# (CHUNK threaten/VB to/TO strike/VB)
# (CHUNK begun/VBN to/TO grow/VB)
# (CHUNK combine/VB to/TO serve/VB)
# (CHUNK helping/VBG to/TO strengthen/VB)
# (CHUNK designed/VBN to/TO promote/VB)
# (CHUNK threatening/VBG to/TO expand/VB)
# (CHUNK seeks/VBZ to/TO get/VB)
# (CHUNK begin/VB to/TO see/VB)
# (CHUNK continue/VB to/TO expand/VB)
# (CHUNK failing/VBG to/TO render/VB)
# (CHUNK decided/VBD to/TO tackle/VB)
# (CHUNK expects/VBZ to/TO sign/VB)
# (CHUNK tends/VBZ to/TO become/VB)
# (CHUNK came/VBD to/TO understand/VB)
# (CHUNK deserve/VB to/TO breathe/VB)
# (CHUNK advised/VBN to/TO seek/VB)
# (CHUNK attempting/VBG to/TO make/VB)
# (CHUNK try/VB to/TO gun/VB)
# (CHUNK began/VBD to/TO fill/VB)
# (CHUNK proposes/VBZ to/TO preserve/VB)
# (CHUNK asked/VBN to/TO approve/VB)
# (CHUNK seeking/VBG to/TO break/VB)
# (CHUNK tends/VBZ to/TO spread/VB)
# (CHUNK want/VB to/TO amend/VB)
# (CHUNK rejected/VBN to/TO seek/VB)
# (CHUNK continued/VBN to/TO speak/VB)
# (CHUNK trying/VBG to/TO make/VB)
# (CHUNK expected/VBN to/TO head/VB)
# (CHUNK tempted/VBN to/TO let/VB)
# (CHUNK appear/VB to/TO cost/VB)
# (CHUNK attempt/VB to/TO shore/VB)
# (CHUNK seeking/VBG to/TO achieve/VB)
# (CHUNK expected/VBN to/TO report/VB)
# (CHUNK born/VBN to/TO play/VB)
# (CHUNK promising/VBG to/TO build/VB)
# (CHUNK minded/VBN to/TO read/VB)
# (CHUNK hope/VB to/TO win/VB)
# (CHUNK threatened/VBD to/TO ignite/VB)
# (CHUNK beginning/VBG to/TO take/VB)
# (CHUNK flew/VBD to/TO exert/VB)
# (CHUNK proceed/VB to/TO validate/VB)
# (CHUNK continues/VBZ to/TO feel/VB)
# (CHUNK want/VB to/TO make/VB)
# (CHUNK going/VBG to/TO get/VB)
# (CHUNK attempt/VB to/TO rewrite/VB)
# (CHUNK purport/VB to/TO advocate/VB)
# (CHUNK seeking/VBG to/TO capitalize/VB)
# (CHUNK exist/VB to/TO aid/VB)
# (CHUNK learn/VB to/TO put/VB)
# (CHUNK tends/VBZ to/TO create/VB)
# (CHUNK promised/VBD to/TO eat/VB)
# (CHUNK hopes/VBZ to/TO include/VB)
# (CHUNK moving/VBG to/TO create/VB)
# (CHUNK prepared/VBN to/TO undertake/VB)
# (CHUNK conspired/VBD to/TO overthrow/VB)
# (CHUNK seem/VB to/TO feel/VB)
# (CHUNK decided/VBN to/TO keep/VB)
# (CHUNK applied/VBN to/TO serve/VB)
# (CHUNK try/VB to/TO seize/VB)
# (CHUNK lead/VB to/TO involving/VBG)
# (CHUNK cut/VBN to/TO allow/VB)
# (CHUNK hope/VB to/TO enjoy/VB)
# (CHUNK likes/VBZ to/TO receive/VB)
# (CHUNK delighted/VBN to/TO learn/VB)
# (CHUNK going/VBG to/TO expand/VB)
# (CHUNK authorized/VBN to/TO deliver/VB)
# (CHUNK going/VBG to/TO can/VB)
# (CHUNK going/VBG to/TO close/VB)
# (CHUNK supposed/VBN to/TO make/VB)
# (CHUNK try/VB to/TO raise/VB)
# (CHUNK tried/VBD to/TO settle/VB)
# (CHUNK pass/VB to/TO enter/VB)
# (CHUNK came/VBD to/TO tell/VB)
# (CHUNK wanted/VBD to/TO grab/VB)
# (CHUNK stops/VBZ to/TO think/VB)
# (CHUNK expect/VB to/TO get/VB)
# (CHUNK chosen/VBN to/TO answer/VB)
# (CHUNK motivated/VBN to/TO seek/VB)
# (CHUNK disposed/VBD to/TO covet/VB)
# (CHUNK like/VB to/TO lie/VB)
# (CHUNK going/VBG to/TO tell/VB)
# (CHUNK prepared/VBN to/TO accept/VB)
# (CHUNK try/VB to/TO stop/VB)
# (CHUNK try/VB to/TO stop/VB)
# (CHUNK sought/VBD to/TO break/VB)
# (CHUNK inclined/VBN to/TO look/VB)
# (CHUNK begun/VBN to/TO act/VB)
# (CHUNK elect/VB to/TO slow/VB)
# (CHUNK like/VB to/TO challenge/VB)
# (CHUNK going/VBG to/TO move/VB)
# (CHUNK asked/VBN to/TO carry/VB)
# (CHUNK expect/VB to/TO stop/VB)
# (CHUNK expect/VB to/TO reduce/VB)
# (CHUNK expected/VBN to/TO supply/VB)
# (CHUNK supposed/VBN to/TO win/VB)
# (CHUNK seems/VBZ to/TO lack/VB)
# (CHUNK tends/VBZ to/TO treat/VB)
# (CHUNK like/VB to/TO share/VB)
# (CHUNK try/VB to/TO treat/VB)
# (CHUNK try/VB to/TO bring/VB)
# (CHUNK try/VB to/TO give/VB)
# (CHUNK continue/VB to/TO lack/VB)
# (CHUNK learn/VB to/TO color/VB)
# (CHUNK slated/VBN to/TO replace/VB)
# (CHUNK strive/VB to/TO put/VB)
# (CHUNK intends/VBZ to/TO provide/VB)
# (CHUNK try/VB to/TO solve/VB)
# (CHUNK decided/VBD to/TO use/VB)
# (CHUNK try/VB to/TO end/VB)
# (CHUNK going/VBG to/TO take/VB)
# (CHUNK trying/VBG to/TO organize/VB)
# (CHUNK permitted/VBN to/TO repair/VB)
# (CHUNK trying/VBG to/TO find/VB)
# (CHUNK planned/VBN to/TO rival/VB)
# (CHUNK seems/VBZ to/TO speak/VB)
# (CHUNK tried/VBD to/TO dissuade/VB)
# (CHUNK tends/VBZ to/TO shimmy/VB)
# (CHUNK designed/VBN to/TO teach/VB)
# (CHUNK prepared/VBN to/TO teach/VB)
# (CHUNK wanted/VBD to/TO sign/VB)
# (CHUNK made/VBN to/TO act/VB)
# (CHUNK continue/VB to/TO influence/VB)
# (CHUNK begins/VBZ to/TO notice/VB)
# (CHUNK expected/VBN to/TO win/VB)
# (CHUNK seek/VB to/TO find/VB)
# (CHUNK join/VB to/TO defeat/VB)
# (CHUNK meant/VBN to/TO repeat/VB)
# (CHUNK trying/VBG to/TO downgrade/VB)
# (CHUNK tried/VBD to/TO guard/VB)
# (CHUNK want/VB to/TO separate/VB)
# (CHUNK seem/VB to/TO indicate/VB)
# (CHUNK afford/VB to/TO buy/VB)
# (CHUNK try/VB to/TO develop/VB)
# (CHUNK attempting/VBG to/TO attract/VB)
# (CHUNK compelled/VBN to/TO write/VB)
# (CHUNK failed/VBN to/TO set/VB)
# (CHUNK continue/VB to/TO shape/VB)
# (CHUNK wants/VBZ to/TO study/VB)
# (CHUNK wants/VBZ to/TO study/VB)
# (CHUNK equipped/VBN to/TO care/VB)
# (CHUNK expected/VBN to/TO survive/VB)
# (CHUNK shocked/VBN to/TO see/VB)
# (CHUNK going/VBG to/TO play/VB)
# (CHUNK voted/VBN to/TO aid/VB)
# (CHUNK died/VBD to/TO uphold/VB)
# (CHUNK urged/VBN to/TO reduce/VB)
# (CHUNK wish/VB to/TO state/VB)
# (CHUNK expected/VBN to/TO give/VB)
# (CHUNK trying/VBG to/TO maintain/VB)
# (CHUNK attempt/VB to/TO seek/VB)
# (CHUNK wishes/VBZ to/TO commend/VB)
# (CHUNK qualified/VBN to/TO teach/VB)
# (CHUNK want/VB to/TO let/VB)
# (CHUNK informed/VBN to/TO report/VB)
# (CHUNK planning/VBG to/TO shelter/VB)
# (CHUNK plans/VBZ to/TO sit/VB)
# (CHUNK continue/VB to/TO inquire/VB)
# (CHUNK began/VBD to/TO realize/VB)
# (CHUNK refuse/VB to/TO acknowledge/VB)
# (CHUNK required/VBN to/TO certify/VB)
# (CHUNK desire/VB to/TO participate/VB)
# (CHUNK hasten/VB to/TO join/VB)
# (CHUNK like/VB to/TO question/VB)
# (CHUNK needed/VBN to/TO help/VB)
# (CHUNK prepared/VBN to/TO care/VB)
# (CHUNK like/VB to/TO suggest/VB)
# (CHUNK fear/VB to/TO negotiate/VB)
# (CHUNK tried/VBD to/TO prevent/VB)
# (CHUNK refusing/VBG to/TO pay/VB)
# (CHUNK like/VB to/TO quote/VB)
# (CHUNK transfer/VB to/TO ride/VB)
# (CHUNK managed/VBN to/TO automate/VB)
# (CHUNK expected/VBN to/TO pay/VB)
# (CHUNK collected/VBN to/TO buy/VB)
# (CHUNK continue/VB to/TO provide/VB)
# (CHUNK wish/VB to/TO congratulate/VB)
# (CHUNK help/VB to/TO turn/VB)
# (CHUNK try/VB to/TO keep/VB)
# (CHUNK try/VB to/TO frighten/VB)
# (CHUNK wish/VB to/TO advocate/VB)
# (CHUNK expect/VB to/TO see/VB)
# (CHUNK refuse/VB to/TO aid/VB)
# (CHUNK needs/VBZ to/TO stand/VB)
# (CHUNK strives/VBZ to/TO emulate/VB)
# (CHUNK refusing/VBG to/TO show/VB)
# (CHUNK seems/VBZ to/TO match/VB)
# (CHUNK decided/VBD to/TO rake/VB)
# (CHUNK entitled/VBN to/TO stay/VB)
# (CHUNK bringing/VBG to/TO bear/VB)
# (CHUNK beginning/VBG to/TO get/VB)
# (CHUNK threaten/VB to/TO use/VB)
# (CHUNK begin/VB to/TO play/VB)
# (CHUNK begin/VB to/TO hunt/VB)
# (CHUNK induced/VBN to/TO see/VB)
# (CHUNK going/VBG to/TO hang/VB)
# (CHUNK continue/VB to/TO test/VB)
# (CHUNK choose/VB to/TO agree/VB)
# (CHUNK chosen/VBN to/TO find/VB)
# (CHUNK compelled/VBN to/TO conduct/VB)
# (CHUNK need/VB to/TO realize/VB)
# (CHUNK used/VBN to/TO justify/VB)
# (CHUNK fail/VB to/TO respond/VB)
# (CHUNK intends/VBZ to/TO economize/VB)
# (CHUNK bound/VBN to/TO say/VB)
# (CHUNK trying/VBG to/TO mollify/VB)
# (CHUNK used/VBD to/TO say/VB)
# (CHUNK came/VBD to/TO reassert/VB)
# (CHUNK choose/VB to/TO call/VB)
# (CHUNK intend/VB to/TO re-enter/VB)
# (CHUNK conscripted/VBN to/TO enact/VB)
# (CHUNK continues/VBZ to/TO feed/VB)
# (CHUNK tried/VBD to/TO integrate/VB)
# (CHUNK poised/VBN to/TO strike/VB)
# (CHUNK try/VB to/TO force/VB)
# (CHUNK attempting/VBG to/TO reach/VB)
# (CHUNK afford/VB to/TO take/VB)
# (CHUNK forbidden/VBN to/TO sit/VB)
# (CHUNK plans/VBZ to/TO import/VB)
# (CHUNK likes/VBZ to/TO imagine/VB)
# (CHUNK used/VBD to/TO get/VB)
# (CHUNK trying/VBG to/TO make/VB)
# (CHUNK ceased/VBD to/TO suggest/VB)
# (CHUNK going/VBG to/TO work/VB)
# (CHUNK wanting/VBG to/TO cut/VB)
# (CHUNK choose/VB to/TO persuade/VB)
# (CHUNK trying/VBG to/TO keep/VB)
# (CHUNK like/VB to/TO embark/VB)
# (CHUNK suited/VBN to/TO defeat/VB)
# (CHUNK hastened/VBD to/TO put/VB)
# (CHUNK like/VB to/TO add/VB)
# (CHUNK want/VB to/TO preserve/VB)
# (CHUNK required/VBN to/TO participate/VB)
# (CHUNK happened/VBN to/TO save/VB)
# (CHUNK doing/VBG to/TO promote/VB)
# (CHUNK tempted/VBN to/TO quote/VB)
# (CHUNK continuing/VBG to/TO capture/VB)
# (CHUNK need/VB to/TO communicate/VB)
# (CHUNK like/VB to/TO see/VB)
# (CHUNK interested/VBN to/TO know/VB)
# (CHUNK allowed/VBN to/TO rust/VB)
# (CHUNK chose/VBD to/TO devote/VB)
# (CHUNK left/VBN to/TO choose/VB)
# (CHUNK want/VB to/TO own/VB)
# (CHUNK plan/VB to/TO become/VB)
# (CHUNK persuaded/VBN to/TO restock/VB)
# (CHUNK seems/VBZ to/TO improve/VB)
# (CHUNK arranged/VBN to/TO permit/VB)
# (CHUNK seem/VB to/TO lend/VB)
# (CHUNK allowed/VBN to/TO mix/VB)
# (CHUNK starts/VBZ to/TO swing/VB)
# (CHUNK seems/VBZ to/TO stop/VB)
# (CHUNK ordered/VBN to/TO hold/VB)
# (CHUNK fitted/VBN to/TO endure/VB)
# (CHUNK trying/VBG to/TO follow/VB)
# (CHUNK threatening/VBG to/TO explode/VB)
# (CHUNK rides/VBZ to/TO break/VB)
# (CHUNK managed/VBD to/TO make/VB)
# (CHUNK dancing/VBG to/TO display/VB)
# (CHUNK hasten/VB to/TO report/VB)
# (CHUNK seems/VBZ to/TO come/VB)
# (CHUNK reassuring/VBG to/TO see/VB)
# (CHUNK profess/VB to/TO know/VB)
# (CHUNK help/VB to/TO explain/VB)
# (CHUNK forced/VBN to/TO rely/VB)
# (CHUNK attempt/VB to/TO homogenize/VB)
# (CHUNK like/VB to/TO put/VB)
# (CHUNK continue/VB to/TO try/VB)
# (CHUNK seem/VB to/TO deal/VB)
# (CHUNK decide/VB to/TO let/VB)
# (CHUNK tries/VBZ to/TO take/VB)
# (CHUNK trying/VBG to/TO forget/VB)
# (CHUNK trying/VBG to/TO acquire/VB)
# (CHUNK threatens/VBZ to/TO linger/VB)
# (CHUNK decided/VBN to/TO forego/VB)
# (CHUNK managed/VBN to/TO hold/VB)
# (CHUNK intended/VBN to/TO illustrate/VB)
# (CHUNK tried/VBN to/TO get/VB)
# (CHUNK learn/VB to/TO live/VB)
# (CHUNK helping/VBG to/TO move/VB)
# (CHUNK striving/VBG to/TO hold/VB)
# (CHUNK choose/VB to/TO work/VB)
# (CHUNK tried/VBD to/TO see/VB)
# (CHUNK trying/VBG to/TO create/VB)
# (CHUNK made/VBN to/TO appear/VB)
# (CHUNK failed/VBD to/TO make/VB)
# (CHUNK seemed/VBD to/TO deserve/VB)
# (CHUNK managed/VBN to/TO mix/VB)
# (CHUNK want/VB to/TO hurt/VB)
# (CHUNK liked/VBD to/TO nip/VB)
# (CHUNK manages/VBZ to/TO acquire/VB)
# (CHUNK widened/VBN to/TO enchant/VB)
# (CHUNK serve/VB to/TO contradict/VB)
# (CHUNK dare/VB to/TO experiment/VB)
# (CHUNK tried/VBD to/TO humanize/VB)
# (CHUNK tries/VBZ to/TO preserve/VB)
# (CHUNK helps/VBZ to/TO rebut/VB)
# (CHUNK seems/VBZ to/TO make/VB)
# (CHUNK began/VBD to/TO play/VB)
# (CHUNK cares/VBZ to/TO remember/VB)
# (CHUNK serve/VB to/TO show/VB)
# (CHUNK want/VB to/TO collect/VB)
# (CHUNK designed/VBN to/TO invite/VB)
# (CHUNK attempt/VB to/TO make/VB)
# (CHUNK designed/VBN to/TO belong/VB)
# (CHUNK seem/VB to/TO come/VB)
# (CHUNK wanted/VBD to/TO identify/VB)
# (CHUNK neglect/VB to/TO cultivate/VB)
# (CHUNK chooses/VBZ to/TO lead/VB)
# (CHUNK chosen/VBN to/TO sing/VB)
# (CHUNK expected/VBN to/TO follow/VB)
# (CHUNK formed/VBN to/TO spur/VB)
# (CHUNK tends/VBZ to/TO shy/VB)
# (CHUNK seeking/VBG to/TO become/VB)
# (CHUNK tries/VBZ to/TO make/VB)
# (CHUNK began/VBD to/TO change/VB)
# (CHUNK try/VB to/TO solve/VB)
# (CHUNK formed/VBN to/TO fill/VB)
# (CHUNK determined/VBN to/TO avoid/VB)
# (CHUNK seems/VBZ to/TO work/VB)
# (CHUNK began/VBD to/TO fall/VB)
# (CHUNK began/VBD to/TO depart/VB)
# (CHUNK refused/VBD to/TO give/VB)
# (CHUNK like/VB to/TO sniff/VB)
# (CHUNK continue/VB to/TO demonstrate/VB)
# (CHUNK begins/VBZ to/TO wilt/VB)
# (CHUNK going/VBG to/TO murder/VB)
# (CHUNK trying/VBG to/TO puzzle/VB)
# (CHUNK expects/VBZ to/TO profit/VB)
# (CHUNK chooses/VBZ to/TO die/VB)
# (CHUNK wishes/VBZ to/TO pay/VB)
# (CHUNK conditioned/VBN to/TO expect/VB)
# (CHUNK hoped/VBD to/TO tell/VB)
# (CHUNK refusing/VBG to/TO make/VB)
# (CHUNK intended/VBD to/TO stop/VB)
# (CHUNK failed/VBD to/TO lead/VB)
# (CHUNK need/VB to/TO discipline/VB)
# (CHUNK attempts/VBZ to/TO trace/VB)
# (CHUNK conspire/VB to/TO defy/VB)
# (CHUNK learning/VBG to/TO think/VB)
# (CHUNK wants/VBZ to/TO know/VB)
# (CHUNK wants/VBZ to/TO supply/VB)
# (CHUNK begin/VB to/TO look/VB)
# (CHUNK start/VB to/TO think/VB)
# (CHUNK attempt/VB to/TO say/VB)
# (CHUNK come/VBN to/TO feel/VB)
# (CHUNK supposed/VBN to/TO put/VB)
# (CHUNK called/VBN to/TO work/VB)
# (CHUNK continue/VB to/TO exist/VB)
# (CHUNK observed/VBN to/TO characterize/VB)
# (CHUNK continue/VB to/TO alienate/VB)
# (CHUNK continue/VB to/TO preach/VB)
# (CHUNK means/VBZ to/TO say/VB)
# (CHUNK fit/VBN to/TO place/VB)
# (CHUNK concerned/VBN to/TO stand/VB)
# (CHUNK strive/VB to/TO formulate/VB)
# (CHUNK proceeded/VBD to/TO give/VB)
# (CHUNK offer/VB to/TO remind/VB)
# (CHUNK offered/VBN to/TO allow/VB)
# (CHUNK requested/VBN to/TO teach/VB)
# (CHUNK said/VBN to/TO repeat/VB)
# (CHUNK mean/VB to/TO say/VB)
# (CHUNK inclined/VBN to/TO extenuate/VB)
# (CHUNK came/VBD to/TO rescue/VB)
# (CHUNK venture/VB to/TO assert/VB)
# (CHUNK come/VB to/TO destroy/VB)
# (CHUNK compelled/VBN to/TO ask/VB)
# (CHUNK begins/VBZ to/TO look/VB)
# (CHUNK refuse/VB to/TO accept/VB)
# (CHUNK entitled/VBN to/TO excoriate/VB)
# (CHUNK come/VB to/TO occupy/VB)
# (CHUNK prepared/VBN to/TO resort/VB)
# (CHUNK obliged/VBN to/TO become/VB)
# (CHUNK disposed/VBN to/TO allow/VB)
# (CHUNK prepared/VBN to/TO give/VB)
# (CHUNK trying/VBG to/TO continue/VB)
# (CHUNK attempting/VBG to/TO bridge/VB)
# (CHUNK destined/VBN to/TO live/VB)
# (CHUNK daring/VBG to/TO trust/VB)
# (CHUNK called/VBN to/TO stand/VB)
# (CHUNK die/VB to/TO save/VB)
# (CHUNK told/VBN to/TO express/VB)
# (CHUNK supposed/VBN to/TO perform/VB)
# (CHUNK designed/VBN to/TO give/VB)
# (CHUNK fear/VB to/TO negotiate/VB)
# (CHUNK threatening/VBG to/TO devour/VB)
# (CHUNK try/VB to/TO escape/VB)
# (CHUNK tried/VBD to/TO swim/VB)
# (CHUNK learn/VB to/TO say/VB)
# (CHUNK threatening/VBG to/TO eat/VB)
# (CHUNK remains/VBZ to/TO show/VB)
# (CHUNK attempted/VBN to/TO analyze/VB)
# (CHUNK tried/VBN to/TO consider/VB)
# (CHUNK begin/VB to/TO talk/VB)
# (CHUNK tended/VBD to/TO stifle/VB)
# (CHUNK begin/VB to/TO understand/VB)
# (CHUNK fail/VB to/TO achieve/VB)
# (CHUNK made/VBN to/TO keep/VB)
# (CHUNK desiring/VBG to/TO unite/VB)
# (CHUNK invited/VBN to/TO speak/VB)
# (CHUNK hesitate/VB to/TO ask/VB)
# (CHUNK trying/VBG to/TO make/VB)
# (CHUNK help/VB to/TO determine/VB)
# (CHUNK combine/VB to/TO provide/VB)
# (CHUNK attempt/VB to/TO compensate/VB)
# (CHUNK learn/VB to/TO recognize/VB)
# (CHUNK serve/VB to/TO promote/VB)
# (CHUNK claim/VB to/TO incarnate/VB)
# (CHUNK led/VBN to/TO emphasize/VB)
# (CHUNK tend/VB to/TO consider/VB)
# (CHUNK expected/VBN to/TO seek/VB)
# (CHUNK disposed/VBN to/TO compromise/VB)
# (CHUNK served/VBD to/TO provide/VB)
# (CHUNK mean/VB to/TO imply/VB)
# (CHUNK mean/VB to/TO imply/VB)
# (CHUNK attempts/VBZ to/TO face/VB)
# (CHUNK need/VB to/TO submit/VB)
# (CHUNK prepared/VBN to/TO run/VB)
# (CHUNK asked/VBN to/TO choose/VB)
# (CHUNK continuing/VBG to/TO incur/VB)
# (CHUNK seems/VBZ to/TO think/VB)
# (CHUNK begin/VB to/TO amass/VB)
# (CHUNK sought/VBN to/TO limit/VB)
# (CHUNK bring/VB to/TO bear/VB)
# (CHUNK invited/VBN to/TO participate/VB)
# (CHUNK sought/VBD to/TO bring/VB)
# (CHUNK attempting/VBG to/TO explore/VB)
# (CHUNK seen/VBN to/TO consist/VB)
# (CHUNK committed/VBN to/TO avoid/VB)
# (CHUNK claim/VB to/TO serve/VB)
# (CHUNK determined/VBN to/TO avoid/VB)
# (CHUNK trying/VBG to/TO converse/VB)
# (CHUNK started/VBN to/TO adjust/VB)
# (CHUNK trying/VBG to/TO make/VB)
# (CHUNK decided/VBD to/TO take/VB)
# (CHUNK forced/VBN to/TO conclude/VB)
# (CHUNK beginning/VBG to/TO make/VB)
# (CHUNK helped/VBD to/TO make/VB)
# (CHUNK made/VBN to/TO give/VB)
# (CHUNK determined/VBD to/TO exclude/VB)
# (CHUNK sought/VBD to/TO win/VB)
# (CHUNK sought/VBD to/TO avoid/VB)
# (CHUNK meant/VBD to/TO incur/VB)
# (CHUNK supposed/VBN to/TO result/VB)
# (CHUNK cited/VBN to/TO show/VB)
# (CHUNK supposed/VBD to/TO possess/VB)
# (CHUNK burned/VBN to/TO make/VB)
# (CHUNK wanted/VBD to/TO find/VB)
# (CHUNK helps/VBZ to/TO meet/VB)
# (CHUNK rejoiced/VBD to/TO see/VB)
# (CHUNK began/VBD to/TO suspect/VB)
# (CHUNK began/VBD to/TO review/VB)
# (CHUNK called/VBD to/TO sit/VB)
# (CHUNK began/VBD to/TO write/VB)
# (CHUNK decided/VBD to/TO try/VB)
# (CHUNK takes/VBZ to/TO tell/VB)
# (CHUNK seemed/VBD to/TO widen/VB)
# (CHUNK proceeded/VBD to/TO teach/VB)
# (CHUNK helps/VBZ to/TO make/VB)
# (CHUNK remember/VB to/TO make/VB)
# (CHUNK supposed/VBN to/TO like/VB)
# (CHUNK working/VBG to/TO improve/VB)
# (CHUNK like/VB to/TO make/VB)
# (CHUNK added/VBN to/TO encourage/VB)
# (CHUNK like/VB to/TO shear/VB)
# (CHUNK needs/VBZ to/TO tell/VB)
# (CHUNK like/VB to/TO grow/VB)
# (CHUNK allowed/VBN to/TO mature/VB)
# (CHUNK used/VBN to/TO attack/VB)
# (CHUNK continued/VBD to/TO threaten/VB)
# (CHUNK decide/VB to/TO build/VB)
# (CHUNK used/VBN to/TO destroy/VB)
# (CHUNK going/VBG to/TO develop/VB)
# (CHUNK put/VBN to/TO see/VB)
# (CHUNK fail/VB to/TO develop/VB)
# (CHUNK seem/VB to/TO fall/VB)
# (CHUNK serve/VB to/TO emphasize/VB)
# (CHUNK tend/VB to/TO stamp/VB)
# (CHUNK fail/VB to/TO enter/VB)
# (CHUNK rehearing/VBG to/TO acquire/VB)
# (CHUNK fail/VB to/TO convey/VB)
# (CHUNK needed/VBN to/TO attain/VB)
# (CHUNK seem/VB to/TO reduce/VB)
# (CHUNK continue/VB to/TO show/VB)
# (CHUNK sponsored/VBD to/TO win/VB)
# (CHUNK invited/VBN to/TO judge/VB)
# (CHUNK asked/VBN to/TO pick/VB)
# (CHUNK qualified/VBN to/TO judge/VB)
# (CHUNK helping/VBG to/TO create/VB)
# (CHUNK qualified/VBN to/TO win/VB)
# (CHUNK continuing/VBG to/TO donate/VB)
# (CHUNK found/VBN to/TO take/VB)
# (CHUNK built/VBN to/TO accommodate/VB)
# (CHUNK bothered/VBD to/TO make/VB)
# (CHUNK wanted/VBD to/TO purchase/VB)
# (CHUNK managing/VBG to/TO get/VB)
# (CHUNK formed/VBN to/TO develop/VB)
# (CHUNK used/VBN to/TO indicate/VB)
# (CHUNK meant/VBN to/TO pertain/VB)
# (CHUNK designed/VBN to/TO cater/VB)
# (CHUNK equipped/VBN to/TO handle/VB)
# (CHUNK pulled/VBN to/TO clear/VB)
# (CHUNK Tend/VB to/TO make/VB)
# (CHUNK progresses/VBZ to/TO insure/VB)
# (CHUNK Endeavor/VB to/TO get/VB)
# (CHUNK used/VBN to/TO separate/VB)
# (CHUNK used/VBN to/TO separate/VB)
# (CHUNK seems/VBZ to/TO know/VB)
# (CHUNK wanted/VBD to/TO trot/VB)
# (CHUNK likes/VBZ to/TO trot/VB)
# (CHUNK wants/VBZ to/TO trot/VB)
# (CHUNK started/VBD to/TO pace/VB)
# (CHUNK starting/VBG to/TO go/VB)
# (CHUNK expected/VBN to/TO race/VB)
# (CHUNK designed/VBN to/TO push/VB)
# (CHUNK looks/VBZ to/TO run/VB)
# (CHUNK began/VBD to/TO motor/VB)
# (CHUNK trained/VBN to/TO drag/VB)
# (CHUNK fled/VBD to/TO make/VB)
# (CHUNK seemed/VBD to/TO know/VB)
# (CHUNK used/VBD to/TO say/VB)
# (CHUNK preferred/VBD to/TO get/VB)
# (CHUNK hope/VB to/TO cover/VB)
# (CHUNK want/VB to/TO miss/VB)
# (CHUNK scheduled/VBN to/TO vanish/VB)
# (CHUNK continued/VBD to/TO live/VB)
# (CHUNK seem/VB to/TO cascade/VB)
# (CHUNK forget/VB to/TO buy/VB)
# (CHUNK fail/VB to/TO shorten/VB)
# (CHUNK intend/VB to/TO cook/VB)
# (CHUNK sized/VBN to/TO fit/VB)
# (CHUNK continue/VB to/TO release/VB)
# (CHUNK wish/VB to/TO create/VB)
# (CHUNK trim/VB to/TO fit/VB)
# (CHUNK cut/VBN to/TO fit/VB)
# (CHUNK help/VB to/TO prevent/VB)
# (CHUNK designed/VBN to/TO take/VB)
# (CHUNK used/VBN to/TO transport/VB)
# (CHUNK want/VB to/TO buy/VB)
# (CHUNK used/VBN to/TO fasten/VB)
# (CHUNK help/VB to/TO keep/VB)
# (CHUNK needed/VBN to/TO build/VB)
# (CHUNK designed/VBN to/TO accommodate/VB)
# (CHUNK adjusted/VBN to/TO suit/VB)
# (CHUNK used/VBN to/TO cut/VB)
# (CHUNK want/VB to/TO avoid/VB)
# (CHUNK agreed/VBN to/TO take/VB)
# (CHUNK planned/VBD to/TO destroy/VB)
# (CHUNK allowed/VBN to/TO issue/VB)
# (CHUNK managed/VBD to/TO coerce/VB)
# (CHUNK want/VB to/TO know/VB)
# (CHUNK planning/VBG to/TO bring/VB)
# (CHUNK urged/VBN to/TO keep/VB)
# (CHUNK come/VB to/TO swim/VB)
# (CHUNK enjoined/VBN to/TO look/VB)
# (CHUNK prepared/VBN to/TO cope/VB)
# (CHUNK want/VB to/TO make/VB)
# (CHUNK allowed/VBN to/TO dry/VB)
# (CHUNK pays/VBZ to/TO buy/VB)
# (CHUNK want/VB to/TO play/VB)
# (CHUNK expected/VBN to/TO last/VB)
# (CHUNK plan/VB to/TO add/VB)
# (CHUNK want/VB to/TO start/VB)
# (CHUNK plan/VB to/TO buy/VB)
# (CHUNK going/VBG to/TO need/VB)
# (CHUNK continue/VB to/TO reduce/VB)
# (CHUNK needed/VBN to/TO arrive/VB)
# (CHUNK done/VBN to/TO correct/VB)
# (CHUNK cost/VB to/TO make/VB)
# (CHUNK settled/VBD to/TO find/VB)
# (CHUNK grew/VBD to/TO fulfill/VB)
# (CHUNK attempted/VBN to/TO restrict/VB)
# (CHUNK conceived/VBN to/TO affirm/VB)
# (CHUNK prefer/VB to/TO believe/VB)
# (CHUNK tried/VBD to/TO refashion/VB)
# (CHUNK begin/VB to/TO fear/VB)
# (CHUNK linger/VB to/TO haunt/VB)
# (CHUNK disciplined/VBN to/TO serve/VB)
# (CHUNK trained/VBN to/TO fulfill/VB)
# (CHUNK organized/VBN to/TO furnish/VB)
# (CHUNK continued/VBD to/TO paint/VB)
# (CHUNK made/VBN to/TO weave/VB)
# (CHUNK try/VB to/TO place/VB)
# (CHUNK hesitate/VB to/TO add/VB)
# (CHUNK seemed/VBN to/TO emphasize/VB)
# (CHUNK mean/VB to/TO project/VB)
# (CHUNK wishes/VBZ to/TO convey/VB)
# (CHUNK beginning/VBG to/TO learn/VB)
# (CHUNK start/VB to/TO study/VB)
# (CHUNK said/VBN to/TO start/VB)
# (CHUNK wished/VBD to/TO get/VB)
# (CHUNK Try/VB to/TO push/VB)
# (CHUNK taken/VBN to/TO see/VB)
# (CHUNK promises/VBZ to/TO open/VB)
# (CHUNK selected/VBN to/TO operate/VB)
# (CHUNK used/VBN to/TO measure/VB)
# (CHUNK employed/VBN to/TO measure/VB)
# (CHUNK used/VBN to/TO detect/VB)
# (CHUNK tend/VB to/TO reflect/VB)
# (CHUNK used/VBN to/TO scan/VB)
# (CHUNK decided/VBD to/TO enter/VB)
# (CHUNK preparing/VBG to/TO matriculate/VB)
# (CHUNK continued/VBD to/TO help/VB)
# (CHUNK intend/VB to/TO carry/VB)
# (CHUNK lived/VBD to/TO see/VB)
# (CHUNK manage/VB to/TO experiment/VB)
# (CHUNK tempted/VBN to/TO compare/VB)
# (CHUNK made/VBN to/TO see/VB)
# (CHUNK caused/VBN to/TO glow/VB)
# (CHUNK made/VBN to/TO flow/VB)
# (CHUNK happened/VBD to/TO place/VB)
# (CHUNK used/VBN to/TO construct/VB)
# (CHUNK used/VBN to/TO fill/VB)
# (CHUNK examine/VB to/TO make/VB)
# (CHUNK designed/VBN to/TO counter/VB)
# (CHUNK tend/VB to/TO become/VB)
# (CHUNK try/VB to/TO share/VB)
# (CHUNK continue/VB to/TO make/VB)
# (CHUNK come/VBN to/TO expect/VB)
# (CHUNK used/VBN to/TO keep/VB)
# (CHUNK bound/VBN to/TO increase/VB)
# (CHUNK trying/VBG to/TO match/VB)
# (CHUNK going/VBG to/TO take/VB)
# (CHUNK continue/VB to/TO exceed/VB)
# (CHUNK extended/VBN to/TO compare/VB)
# (CHUNK continue/VB to/TO divorce/VB)
# (CHUNK fail/VB to/TO lower/VB)
# (CHUNK supposed/VBN to/TO stand/VB)
# (CHUNK prepared/VBN to/TO teach/VB)
# (CHUNK school/VB to/TO cover/VB)
# (CHUNK make/VB to/TO assess/VB)
# (CHUNK try/VB to/TO set/VB)
# (CHUNK encouraged/VBD to/TO take/VB)
# (CHUNK try/VB to/TO maintain/VB)
# (CHUNK plan/VB to/TO limit/VB)
# (CHUNK make/VB to/TO assure/VB)
# (CHUNK afford/VB to/TO spend/VB)
# (CHUNK Aim/VB to/TO balance/VB)
# (CHUNK Check/VB to/TO see/VB)
# (CHUNK called/VBN to/TO determine/VB)
# (CHUNK cooperate/VB to/TO launch/VB)
# (CHUNK designed/VBN to/TO expose/VB)
# (CHUNK existing/VBG to/TO acquaint/VB)
# (CHUNK like/VB to/TO organize/VB)
# (CHUNK begin/VB to/TO appreciate/VB)
# (CHUNK inclined/VBN to/TO think/VB)
# (CHUNK needed/VBN to/TO protect/VB)
# (CHUNK struggling/VBG to/TO meet/VB)
# (CHUNK helping/VBG to/TO account/VB)
# (CHUNK want/VB to/TO learn/VB)
# (CHUNK used/VBD to/TO think/VB)
# (CHUNK fights/VBZ to/TO change/VB)
# (CHUNK tends/VBZ to/TO rise/VB)
# (CHUNK expects/VBZ to/TO extend/VB)
# (CHUNK learn/VB to/TO wear/VB)
# (CHUNK tried/VBN to/TO make/VB)
# (CHUNK appears/VBZ to/TO lie/VB)
# (CHUNK attempted/VBN to/TO provide/VB)
# (CHUNK found/VBN to/TO allow/VB)
# (CHUNK planned/VBN to/TO duplicate/VB)
# (CHUNK wants/VBZ to/TO interest/VB)
# (CHUNK want/VB to/TO risk/VB)
# (CHUNK want/VB to/TO use/VB)
# (CHUNK continue/VB to/TO learn/VB)
# (CHUNK meant/VBN to/TO convey/VB)
# (CHUNK used/VBN to/TO minimize/VB)
# (CHUNK try/VB to/TO wrestle/VB)
# (CHUNK trying/VBG to/TO install/VB)
# (CHUNK plan/VB to/TO build/VB)
# (CHUNK equipped/VBN to/TO handle/VB)
# (CHUNK equipped/VBN to/TO package/VB)
# (CHUNK equipped/VBN to/TO receive/VB)
# (CHUNK equipped/VBN to/TO save/VB)
# (CHUNK plan/VB to/TO increase/VB)
# (CHUNK hopes/VBZ to/TO cut/VB)
# (CHUNK bound/VBN to/TO swell/VB)
# (CHUNK begin/VB to/TO feel/VB)
# (CHUNK want/VB to/TO change/VB)
# (CHUNK arrange/VB to/TO rent/VB)
# (CHUNK plan/VB to/TO travel/VB)
# (CHUNK plan/VB to/TO visit/VB)
# (CHUNK like/VB to/TO start/VB)
# (CHUNK wish/VB to/TO budget/VB)
# (CHUNK wanting/VBG to/TO rent/VB)
# (CHUNK want/VB to/TO see/VB)
# (CHUNK want/VB to/TO throw/VB)
# (CHUNK designed/VBN to/TO work/VB)
# (CHUNK trying/VBG to/TO prepare/VB)
# (CHUNK began/VBD to/TO develop/VB)
# (CHUNK used/VBN to/TO suggest/VB)
# (CHUNK wanted/VBD to/TO polish/VB)
# (CHUNK pays/VBZ to/TO consider/VB)
# (CHUNK compelled/VBN to/TO use/VB)
# (CHUNK began/VBD to/TO fall/VB)
# (CHUNK begun/VBN to/TO write/VB)
# (CHUNK made/VBN to/TO seem/VB)
# (CHUNK attempting/VBG to/TO direct/VB)
# (CHUNK pleased/VBN to/TO call/VB)
# (CHUNK scheduled/VBN to/TO nominate/VB)
# (CHUNK come/VB to/TO spend/VB)
# (CHUNK managed/VBD to/TO irrigate/VB)
# (CHUNK stooped/VBD to/TO scoop/VB)
# (CHUNK fall/VB to/TO show/VB)
# (CHUNK try/VB to/TO push/VB)
# (CHUNK begins/VBZ to/TO deteriorate/VB)
# (CHUNK used/VBD to/TO like/VB)
# (CHUNK offered/VBD to/TO ship/VB)
# (CHUNK hopes/VBZ to/TO find/VB)
# (CHUNK invented/VBN to/TO hold/VB)
# (CHUNK learn/VB to/TO like/VB)
# (CHUNK labored/VBD to/TO set/VB)
# (CHUNK set/VBN to/TO receive/VB)
# (CHUNK entered/VBN to/TO compete/VB)
# (CHUNK seem/VB to/TO make/VB)
# (CHUNK seemed/VBD to/TO answer/VB)
# (CHUNK decided/VBD to/TO use/VB)
# (CHUNK began/VBD to/TO show/VB)
# (CHUNK Wishing/VBG to/TO show/VB)
# (CHUNK learned/VBD to/TO set/VB)
# (CHUNK forced/VBN to/TO fly/VB)
# (CHUNK hope/VB to/TO break/VB)
# (CHUNK came/VBD to/TO recognize/VB)
# (CHUNK turning/VBG to/TO cup/VB)
# (CHUNK seems/VBZ to/TO creep/VB)
# (CHUNK going/VBG to/TO live/VB)
# (CHUNK got/VBN to/TO learn/VB)
# (CHUNK going/VBG to/TO live/VB)
# (CHUNK like/VB to/TO sew/VB)
# (CHUNK love/VB to/TO run/VB)
# (CHUNK love/VB to/TO crack/VB)
# (CHUNK yearn/VB to/TO make/VB)
# (CHUNK tried/VBN to/TO see/VB)
# (CHUNK love/VB to/TO dust/VB)
# (CHUNK like/VB to/TO become/VB)
# (CHUNK decide/VB to/TO write/VB)
# (CHUNK cause/VB to/TO exist/VB)
# (CHUNK learn/VB to/TO portray/VB)
# (CHUNK learn/VB to/TO portray/VB)
# (CHUNK began/VBD to/TO advise/VB)
# (CHUNK taught/VBN to/TO yield/VB)
# (CHUNK prefer/VB to/TO cope/VB)
# (CHUNK helps/VBZ to/TO explain/VB)
# (CHUNK surprised/VBN to/TO bump/VB)
# (CHUNK seemed/VBD to/TO brave/VB)
# (CHUNK begins/VBZ to/TO regard/VB)
# (CHUNK began/VBD to/TO embezzle/VB)
# (CHUNK appears/VBZ to/TO endorse/VB)
# (CHUNK expected/VBN to/TO like/VB)
# (CHUNK begin/VB to/TO assert/VB)
# (CHUNK began/VBD to/TO challenge/VB)
# (CHUNK going/VBG to/TO become/VB)
# (CHUNK helping/VBG to/TO make/VB)
# (CHUNK began/VBD to/TO stress/VB)
# (CHUNK began/VBD to/TO describe/VB)
# (CHUNK fails/VBZ to/TO gain/VB)
# (CHUNK liked/VBD to/TO play/VB)
# (CHUNK love/VB to/TO audition/VB)
# (CHUNK wanted/VBD to/TO show/VB)
# (CHUNK like/VB to/TO see/VB)
# (CHUNK loved/VBD to/TO dance/VB)
# (CHUNK try/VB to/TO bid/VB)
# (CHUNK wanted/VBD to/TO go/VB)
# (CHUNK asked/VBN to/TO leave/VB)
# (CHUNK continued/VBD to/TO promote/VB)
# (CHUNK wished/VBD to/TO meet/VB)
# (CHUNK hoping/VBG to/TO see/VB)
# (CHUNK got/VBD to/TO know/VB)
# (CHUNK paused/VBD to/TO comfort/VB)
# (CHUNK hesitate/VB to/TO quote/VB)
# (CHUNK decided/VBD to/TO see/VB)
# (CHUNK wanted/VBD to/TO take/VB)
# (CHUNK need/VB to/TO know/VB)
# (CHUNK need/VB to/TO look/VB)
# (CHUNK beginning/VBG to/TO protrude/VB)
# (CHUNK try/VB to/TO speak/VB)
# (CHUNK decides/VBZ to/TO proceed/VB)
# (CHUNK interested/VBN to/TO hear/VB)
# (CHUNK seems/VBZ to/TO probe/VB)
# (CHUNK preferring/VBG to/TO consider/VB)
# (CHUNK known/VBN to/TO go/VB)
# (CHUNK amazed/VBN to/TO realize/VB)
# (CHUNK seeking/VBG to/TO help/VB)
# (CHUNK interpreted/VBN to/TO conform/VB)
# (CHUNK explored/VBN to/TO find/VB)
# (CHUNK trying/VBG to/TO throw/VB)
# (CHUNK designed/VBN to/TO find/VB)
# (CHUNK required/VBN to/TO mark/VB)
# (CHUNK asked/VBN to/TO consider/VB)
# (CHUNK seem/VB to/TO involve/VB)
# (CHUNK seems/VBZ to/TO smell/VB)
# (CHUNK seems/VBZ to/TO see/VB)
# (CHUNK learned/VBN to/TO develop/VB)
# (CHUNK arranged/VBN to/TO meet/VB)
# (CHUNK need/VB to/TO work/VB)
# (CHUNK want/VB to/TO raise/VB)
# (CHUNK need/VB to/TO bring/VB)
# (CHUNK expect/VB to/TO grow/VB)
# (CHUNK expected/VBN to/TO work/VB)
# (CHUNK want/VB to/TO include/VB)
# (CHUNK going/VBG to/TO produce/VB)
# (CHUNK want/VB to/TO hire/VB)
# (CHUNK want/VB to/TO buy/VB)
# (CHUNK want/VB to/TO hire/VB)
# (CHUNK going/VBG to/TO farm/VB)
# (CHUNK need/VB to/TO know/VB)
# (CHUNK want/VB to/TO undertake/VB)
# (CHUNK want/VB to/TO buy/VB)
# (CHUNK wish/VB to/TO locate/VB)
# (CHUNK plan/VB to/TO sell/VB)
# (CHUNK want/VB to/TO go/VB)
# (CHUNK intend/VB to/TO raise/VB)
# (CHUNK cost/VB to/TO live/VB)
# (CHUNK expected/VBN to/TO produce/VB)
# (CHUNK expect/VB to/TO get/VB)
# (CHUNK forced/VBN to/TO lay/VB)
# (CHUNK trying/VBG to/TO explain/VB)
# (CHUNK happened/VBD to/TO light/VB)
# (CHUNK began/VBD to/TO turn/VB)
# (CHUNK intended/VBN to/TO warn/VB)
# (CHUNK used/VBN to/TO transform/VB)
# (CHUNK forced/VBN to/TO overcome/VB)
# (CHUNK begins/VBZ to/TO give/VB)
# (CHUNK failed/VBN to/TO post/VB)
# (CHUNK refused/VBD to/TO permit/VB)
# (CHUNK encouraged/VBN to/TO beget/VB)
# (CHUNK obliged/VBN to/TO obey/VB)
# (CHUNK united/VBD to/TO push/VB)
# (CHUNK try/VB to/TO oppose/VB)
# (CHUNK made/VBN to/TO impose/VB)
# (CHUNK wanted/VBD to/TO clarify/VB)
# (CHUNK proposed/VBD to/TO sail/VB)
# (CHUNK determined/VBN to/TO catch/VB)
# (CHUNK forced/VBN to/TO turn/VB)
# (CHUNK seemed/VBD to/TO sense/VB)
# (CHUNK seemed/VBD to/TO know/VB)
# (CHUNK tried/VBD to/TO brush/VB)
# (CHUNK turning/VBG to/TO repeat/VB)
# (CHUNK tried/VBN to/TO persuade/VB)
# (CHUNK wanted/VBN to/TO turn/VB)
# (CHUNK preparing/VBG to/TO pacify/VB)
# (CHUNK forced/VBN to/TO retreat/VB)
# (CHUNK contracted/VBD to/TO supply/VB)
# (CHUNK forced/VBN to/TO leave/VB)
# (CHUNK offering/VBG to/TO bring/VB)
# (CHUNK attempt/VB to/TO bring/VB)
# (CHUNK decided/VBD to/TO cast/VB)
# (CHUNK liked/VBD to/TO tease/VB)
# (CHUNK going/VBG to/TO buy/VB)
# (CHUNK com/VB to/TO sea/VB)
# (CHUNK drilled/VBN to/TO follow/VB)
# (CHUNK born/VBN to/TO command/VB)
# (CHUNK come/VBN to/TO recognize/VB)
# (CHUNK allowed/VBN to/TO account/VB)
# (CHUNK created/VBN to/TO fan/VB)
# (CHUNK come/VBN to/TO mean/VB)
# (CHUNK trying/VBG to/TO make/VB)
# (CHUNK refusing/VBG to/TO keep/VB)
# (CHUNK wishes/VBZ to/TO discuss/VB)
# (CHUNK want/VB to/TO ask/VB)
# (CHUNK want/VB to/TO tap/VB)
# (CHUNK said/VBN to/TO use/VB)
# (CHUNK employed/VBN to/TO see/VB)
# (CHUNK shoot/VB to/TO kill/VB)
# (CHUNK refused/VBD to/TO touch/VB)
# (CHUNK threatened/VBD to/TO shoot/VB)
# (CHUNK said/VBD to/TO let/VB)
# (CHUNK begin/VB to/TO roll/VB)
# (CHUNK held/VBN to/TO assure/VB)
# (CHUNK going/VBG to/TO make/VB)
# (CHUNK managed/VBD to/TO get/VB)
# (CHUNK wanted/VBD to/TO play/VB)
# (CHUNK prepared/VBD to/TO counterattack/VB)
# (CHUNK failed/VBN to/TO rally/VB)
# (CHUNK tried/VBD to/TO rape/VB)
# (CHUNK refused/VBD to/TO speak/VB)
# (CHUNK called/VBN to/TO look/VB)
# (CHUNK refused/VBD to/TO say/VB)
# (CHUNK mean/VB to/TO suggest/VB)
# (CHUNK prepared/VBN to/TO carry/VB)
# (CHUNK designed/VBN to/TO overthrow/VB)
# (CHUNK trying/VBG to/TO put/VB)
# (CHUNK needed/VBN to/TO work/VB)
# (CHUNK disposed/VBN to/TO exploit/VB)
# (CHUNK fail/VB to/TO see/VB)
# (CHUNK bound/VBN to/TO fall/VB)
# (CHUNK tempted/VBN to/TO place/VB)
# (CHUNK need/VB to/TO ask/VB)
# (CHUNK seek/VB to/TO undermine/VB)
# (CHUNK hand/VB to/TO show/VB)
# (CHUNK begun/VBN to/TO spit/VB)
# (CHUNK threatened/VBD to/TO ignite/VB)
# (CHUNK invited/VBN to/TO take/VB)
# (CHUNK rushing/VBG to/TO keep/VB)
# (CHUNK like/VB to/TO wander/VB)
# (CHUNK like/VB to/TO follow/VB)
# (CHUNK professing/VBG to/TO believe/VB)
# (CHUNK want/VB to/TO show/VB)
# (CHUNK enabled/VBN to/TO attend/VB)
# (CHUNK determined/VBN to/TO exercise/VB)
# (CHUNK inclined/VBN to/TO exaggerate/VB)
# (CHUNK like/VB to/TO go/VB)
# (CHUNK determined/VBN to/TO marry/VB)
# (CHUNK said/VBD to/TO sprinkle/VB)
# (CHUNK used/VBN to/TO stop/VB)
# (CHUNK bought/VBN to/TO apply/VB)
# (CHUNK supposed/VBN to/TO cause/VB)
# (CHUNK said/VBN to/TO give/VB)
# (CHUNK allowed/VBN to/TO rest/VB)
# (CHUNK enters/VBZ to/TO spoil/VB)
# (CHUNK wish/VB to/TO deny/VB)
# (CHUNK allowed/VBN to/TO warm/VB)
# (CHUNK wishes/VBZ to/TO entertain/VB)
# (CHUNK allowed/VBN to/TO stand/VB)
# (CHUNK refused/VBD to/TO accept/VB)
# (CHUNK wished/VBD to/TO continue/VB)
# (CHUNK persuaded/VBN to/TO accept/VB)
# (CHUNK decided/VBD to/TO charge/VB)
# (CHUNK decided/VBD to/TO go/VB)
# (CHUNK allowed/VBN to/TO see/VB)
# (CHUNK agreed/VBD to/TO take/VB)
# (CHUNK decide/VB to/TO send/VB)
# (CHUNK allowed/VBN to/TO delay/VB)
# (CHUNK request/VB to/TO leave/VB)
# (CHUNK promised/VBN to/TO treat/VB)
# (CHUNK declined/VBD to/TO enter/VB)
# (CHUNK added/VBN to/TO reinforce/VB)
# (CHUNK obliged/VBN to/TO publish/VB)
# (CHUNK continue/VB to/TO serve/VB)
# (CHUNK plans/VBZ to/TO serve/VB)
# (CHUNK Hoping/VBG to/TO cut/VB)
# (CHUNK obliged/VBN to/TO announce/VB)
# (CHUNK wish/VB to/TO preserve/VB)
# (CHUNK heard/VBN to/TO remark/VB)
# (CHUNK hopes/VBZ to/TO redress/VB)
# (CHUNK desires/VBZ to/TO walk/VB)
# (CHUNK prefer/VB to/TO take/VB)
# (CHUNK likes/VBZ to/TO measure/VB)
# (CHUNK proposed/VBD to/TO corral/VB)
# (CHUNK intended/VBD to/TO stay/VB)
# (CHUNK ceased/VBD to/TO look/VB)
# (CHUNK manages/VBZ to/TO overlook/VB)
# (CHUNK troubled/VBN to/TO read/VB)
# (CHUNK destined/VBN to/TO go/VB)
# (CHUNK expected/VBD to/TO go/VB)
# (CHUNK used/VBD to/TO characterize/VB)
# (CHUNK helping/VBG to/TO raise/VB)
# (CHUNK decided/VBD to/TO stay/VB)
# (CHUNK used/VBD to/TO refer/VB)
# (CHUNK needs/VBZ to/TO educate/VB)
# (CHUNK tended/VBN to/TO tamp/VB)
# (CHUNK like/VB to/TO underline/VB)
# (CHUNK begun/VBN to/TO falter/VB)
# (CHUNK intend/VB to/TO include/VB)
# (CHUNK wish/VB to/TO improve/VB)
# (CHUNK try/VB to/TO take/VB)
# (CHUNK prefers/VBZ to/TO designate/VB)
# (CHUNK want/VB to/TO join/VB)
# (CHUNK seeking/VBG to/TO increase/VB)
# (CHUNK used/VBN to/TO make/VB)
# (CHUNK used/VBN to/TO make/VB)
# (CHUNK inclined/VBN to/TO remain/VB)
# (CHUNK heard/VBN to/TO say/VB)
# (CHUNK stopped/VBN to/TO receive/VB)
# (CHUNK used/VBN to/TO describe/VB)
# (CHUNK claimed/VBD to/TO own/VB)
# (CHUNK tried/VBD to/TO find/VB)
# (CHUNK meant/VBD to/TO pay/VB)
# (CHUNK given/VBN to/TO go/VB)
# (CHUNK wanted/VBD to/TO make/VB)
# (CHUNK began/VBD to/TO gallop/VB)
# (CHUNK attempting/VBG to/TO lasso/VB)
# (CHUNK failing/VBG to/TO encircle/VB)
# (CHUNK got/VBN to/TO get/VB)
# (CHUNK trying/VBG to/TO maneuver/VB)
# (CHUNK beginning/VBG to/TO go/VB)
# (CHUNK began/VBD to/TO pull/VB)
# (CHUNK began/VBD to/TO draw/VB)
# (CHUNK like/VB to/TO go/VB)
# (CHUNK tend/VB to/TO compete/VB)
# (CHUNK doing/VBG to/TO help/VB)
# (CHUNK begins/VBZ to/TO see/VB)
# (CHUNK Desiring/VBG to/TO fill/VB)
# (CHUNK tends/VBZ to/TO look/VB)
# (CHUNK try/VB to/TO match/VB)
# (CHUNK played/VBN to/TO win/VB)
# (CHUNK failed/VBD to/TO make/VB)
# (CHUNK began/VBD to/TO involve/VB)
# (CHUNK learning/VBG to/TO bunt/VB)
# (CHUNK dared/VBD to/TO dream/VB)
# (CHUNK dared/VBD to/TO taunt/VB)
# (CHUNK refused/VBD to/TO come/VB)
# (CHUNK undertook/VBD to/TO set/VB)
# (CHUNK essayed/VBD to/TO down/VB)
# (CHUNK began/VBD to/TO prosper/VB)
# (CHUNK liked/VBD to/TO wring/VB)
# (CHUNK happened/VBD to/TO sit/VB)
# (CHUNK hastened/VBN to/TO place/VB)
# (CHUNK began/VBD to/TO offer/VB)
# (CHUNK seemed/VBD to/TO indicate/VB)
# (CHUNK liked/VBD to/TO imagine/VB)
# (CHUNK expected/VBN to/TO know/VB)
# (CHUNK began/VBD to/TO appear/VB)
# (CHUNK begin/VB to/TO store/VB)
# (CHUNK continue/VB to/TO sanction/VB)
# (CHUNK intended/VBN to/TO demonstrate/VB)
# (CHUNK permitted/VBN to/TO exercise/VB)
# (CHUNK encouraged/VBN to/TO develop/VB)
# (CHUNK failing/VBG to/TO behave/VB)
# (CHUNK appeared/VBD to/TO regard/VB)
# (CHUNK seek/VB to/TO disprove/VB)
# (CHUNK tends/VBZ to/TO fuse/VB)
# (CHUNK prefers/VBZ to/TO adduce/VB)
# (CHUNK empowered/VBN to/TO compel/VB)
# (CHUNK designed/VBN to/TO prevent/VB)
# (CHUNK disposed/VBN to/TO heed/VB)
# (CHUNK agree/VB to/TO let/VB)
# (CHUNK seeking/VBG to/TO reform/VB)
# (CHUNK used/VBD to/TO crowd/VB)
# (CHUNK Ask/VB to/TO see/VB)
# (CHUNK interested/VBN to/TO learn/VB)
# (CHUNK pass/VB to/TO add/VB)
# (CHUNK demanding/VBG to/TO know/VB)
# (CHUNK seems/VBZ to/TO threaten/VB)
# (CHUNK tried/VBD to/TO describe/VB)
# (CHUNK tried/VBD to/TO explain/VB)
# (CHUNK seem/VB to/TO feel/VB)
# (CHUNK got/VBN to/TO play/VB)
# (CHUNK ceased/VBN to/TO need/VB)
# (CHUNK like/VB to/TO live/VB)
# (CHUNK came/VBD to/TO see/VB)
# (CHUNK threatens/VBZ to/TO break/VB)
# (CHUNK begins/VBZ to/TO fade/VB)
# (CHUNK begins/VBZ to/TO appear/VB)
# (CHUNK equipped/VBN to/TO tell/VB)
# (CHUNK used/VBN to/TO increase/VB)
# (CHUNK hired/VBN to/TO repeat/VB)
# (CHUNK wished/VBD to/TO make/VB)
# (CHUNK seems/VBZ to/TO exist/VB)
# (CHUNK means/VBZ to/TO choose/VB)
# (CHUNK struggle/VB to/TO insulate/VB)
# (CHUNK serves/VBZ to/TO crystallize/VB)
# (CHUNK doomed/VBN to/TO become/VB)
# (CHUNK serves/VBZ to/TO illuminate/VB)
# (CHUNK failed/VBD to/TO furnish/VB)
# (CHUNK encouraged/VBN to/TO trade/VB)
# (CHUNK continued/VBD to/TO come/VB)
# (CHUNK promised/VBD to/TO send/VB)
# (CHUNK attempted/VBD to/TO understand/VB)
# (CHUNK decided/VBD to/TO send/VB)
# (CHUNK assigned/VBN to/TO arrest/VB)
# (CHUNK planned/VBD to/TO build/VB)
# (CHUNK offered/VBD to/TO surrender/VB)
# (CHUNK gone/VBN to/TO live/VB)
# (CHUNK returned/VBD to/TO succeed/VB)
# (CHUNK expected/VBN to/TO arrange/VB)
# (CHUNK expected/VBN to/TO supply/VB)
# (CHUNK expected/VBN to/TO entertain/VB)
# (CHUNK tried/VBN to/TO bring/VB)
# (CHUNK provoked/VBN to/TO use/VB)
# (CHUNK refused/VBD to/TO let/VB)
# (CHUNK needed/VBN to/TO outwit/VB)
# (CHUNK purporting/VBG to/TO inform/VB)
# (CHUNK inspired/VBN to/TO remind/VB)
# (CHUNK mean/VB to/TO tell/VB)
# (CHUNK trying/VBG to/TO demonstrate/VB)
# (CHUNK went/VBD to/TO visit/VB)
# (CHUNK continued/VBD to/TO teach/VB)
# (CHUNK beginning/VBG to/TO devise/VB)
# (CHUNK learn/VB to/TO like/VB)
# (CHUNK stood/VBD to/TO watch/VB)
# (CHUNK planned/VBN to/TO go/VB)
# (CHUNK trying/VBG to/TO plan/VB)
# (CHUNK continues/VBZ to/TO grow/VB)
# (CHUNK learn/VB to/TO keep/VB)
# (CHUNK learned/VBD to/TO polish/VB)
# (CHUNK left/VBD to/TO meet/VB)
# (CHUNK fails/VBZ to/TO make/VB)
# (CHUNK resolved/VBN to/TO maintain/VB)
# (CHUNK register/VB to/TO vote/VB)
# ...
# (CHUNK turned/VBD to/TO survey/VB)
# (CHUNK started/VBD to/TO struggle/VB)
# (CHUNK started/VBD to/TO return/VB)
# (CHUNK pretended/VBN to/TO give/VB)
# (CHUNK served/VBD to/TO increase/VB)
# (CHUNK determined/VBN to/TO drive/VB)
# (CHUNK try/VB to/TO go/VB)
# (CHUNK began/VBD to/TO run/VB)
# (CHUNK continued/VBD to/TO come/VB)
# (CHUNK continued/VBN to/TO camouflage/VB)
# (CHUNK Forced/VBN to/TO realize/VB)
# (CHUNK trying/VBG to/TO grab/VB)
# (CHUNK trying/VBG to/TO read/VB)
# (CHUNK began/VBD to/TO drink/VB)
# (CHUNK started/VBD to/TO slide/VB)
# (CHUNK mean/VB to/TO pry/VB)
# (CHUNK going/VBG to/TO sell/VB)
# (CHUNK pleased/VBN to/TO hear/VB)
# (CHUNK starting/VBG to/TO itch/VB)
# (CHUNK like/VB to/TO think/VB)
# (CHUNK supposed/VBN to/TO meet/VB)
# (CHUNK wait/VB to/TO get/VB)
# (CHUNK seem/VB to/TO dwell/VB)
# (CHUNK feared/VBD to/TO dwell/VB)
# (CHUNK tried/VBD to/TO date/VB)
# (CHUNK trying/VBG to/TO cut/VB)
# (CHUNK beginning/VBG to/TO collect/VB)
# (CHUNK determined/VBN to/TO find/VB)
# (CHUNK put/VB to/TO use/VB)
# (CHUNK determined/VBN to/TO spend/VB)
# (CHUNK hoping/VBG to/TO escape/VB)
# (CHUNK pleased/VBN to/TO note/VB)
# (CHUNK calculated/VBN to/TO glamorize/VB)
# (CHUNK began/VBD to/TO explain/VB)
# (CHUNK want/VB to/TO see/VB)
# (CHUNK wanted/VBD to/TO turn/VB)
# (CHUNK began/VBD to/TO whip/VB)
# (CHUNK failed/VBD to/TO find/VB)
# (CHUNK meant/VBN to/TO save/VB)
# (CHUNK wanted/VBD to/TO waste/VB)
# (CHUNK want/VB to/TO get/VB)
# (CHUNK going/VBG to/TO explode/VB)
# (CHUNK seemed/VBD to/TO disintegrate/VB)
# (CHUNK intended/VBN to/TO propitiate/VB)
# (CHUNK embarrassing/VBG to/TO see/VB)
# (CHUNK going/VBG to/TO keel/VB)
# (CHUNK seemed/VBD to/TO enjoy/VB)
# (CHUNK like/VB to/TO know/VB)
# (CHUNK deserve/VB to/TO lie/VB)
# (CHUNK want/VB to/TO see/VB)
# (CHUNK pretending/VBG to/TO joke/VB)
# (CHUNK used/VBD to/TO try/VB)
# (CHUNK trying/VBG to/TO look/VB)
# (CHUNK began/VBD to/TO watch/VB)
# (CHUNK want/VB to/TO go/VB)
# (CHUNK seemed/VBD to/TO sink/VB)
# (CHUNK began/VBD to/TO ooze/VB)
# (CHUNK began/VBD to/TO move/VB)
# (CHUNK seemed/VBD to/TO know/VB)
# (CHUNK trying/VBG to/TO talk/VB)
# (CHUNK continued/VBD to/TO lash/VB)
# (CHUNK turned/VBD to/TO look/VB)
# (CHUNK struggled/VBD to/TO control/VB)
# (CHUNK deserved/VBD to/TO live/VB)
# (CHUNK like/VB to/TO hunt/VB)
# (CHUNK left/VBN to/TO say/VB)
# (CHUNK like/VB to/TO recognize/VB)
# (CHUNK wanting/VBG to/TO fly/VB)
# (CHUNK dispatched/VBN to/TO harry/VB)
# (CHUNK started/VBD to/TO buckle/VB)
# (CHUNK began/VBD to/TO crawl/VB)
# (CHUNK wanted/VBD to/TO lose/VB)
# (CHUNK going/VBG to/TO show/VB)
# (CHUNK going/VBG to/TO give/VB)
# (CHUNK trying/VBG to/TO size/VB)
# (CHUNK seemed/VBD to/TO promise/VB)
# (CHUNK hate/VB to/TO run/VB)
# (CHUNK turned/VBD to/TO face/VB)
# (CHUNK wish/VB to/TO enter/VB)
# (CHUNK intend/VB to/TO speak/VB)
# (CHUNK determined/VBN to/TO make/VB)
# (CHUNK want/VB to/TO upset/VB)
# (CHUNK resolved/VBD to/TO make/VB)
# (CHUNK left/VBN to/TO distract/VB)
# (CHUNK vied/VBN to/TO knock/VB)
# (CHUNK equipped/VBN to/TO die/VB)
# (CHUNK tried/VBD to/TO roll/VB)
# (CHUNK commenced/VBD to/TO weep/VB)
# (CHUNK began/VBD to/TO uncap/VB)
# (CHUNK going/VBG to/TO get/VB)
# (CHUNK expected/VBN to/TO risk/VB)
# (CHUNK decided/VBD to/TO set/VB)
# (CHUNK seem/VB to/TO locate/VB)
# (CHUNK allowed/VBN to/TO come/VB)
# (CHUNK allowed/VBN to/TO leave/VB)
# (CHUNK sent/VBN to/TO clean/VB)
# (CHUNK proceeded/VBD to/TO disturb/VB)
# (CHUNK came/VBD to/TO teach/VB)
# (CHUNK wait/VB to/TO get/VB)
# (CHUNK beginning/VBG to/TO stir/VB)
# (CHUNK got/VBN to/TO get/VB)
# (CHUNK seemed/VBD to/TO think/VB)
# (CHUNK trying/VBG to/TO get/VB)
# (CHUNK struggling/VBG to/TO get/VB)
# (CHUNK mean/VB to/TO pull/VB)
# (CHUNK got/VBN to/TO take/VB)
# (CHUNK trying/VBG to/TO think/VB)
# (CHUNK seeming/VBG to/TO scream/VB)
# (CHUNK sought/VBD to/TO make/VB)
# (CHUNK proceeded/VBD to/TO give/VB)
# (CHUNK advised/VBN to/TO flee/VB)
# (CHUNK like/VB to/TO hurt/VB)
# (CHUNK want/VB to/TO go/VB)
# (CHUNK chanced/VBD to/TO glance/VB)
# (CHUNK vowed/VBD to/TO take/VB)
# (CHUNK started/VBD to/TO move/VB)
# (CHUNK began/VBD to/TO sizzle/VB)
# (CHUNK cared/VBD to/TO see/VB)
# (CHUNK time/VB to/TO pay/VB)
# (CHUNK determined/VBN to/TO hold/VB)
# (CHUNK beginning/VBG to/TO fold/VB)
# (CHUNK wanted/VBD to/TO smoke/VB)
# (CHUNK seem/VB to/TO get/VB)
# (CHUNK trying/VBG to/TO find/VB)
# (CHUNK like/VB to/TO keep/VB)
# (CHUNK seem/VB to/TO snap/VB)
# (CHUNK like/VB to/TO think/VB)
# (CHUNK beginning/VBG to/TO find/VB)
# (CHUNK beginning/VBG to/TO look/VB)
# (CHUNK going/VBG to/TO last/VB)
# (CHUNK going/VBG to/TO prove/VB)
# (CHUNK hoped/VBD to/TO die/VB)
# (CHUNK gone/VBN to/TO live/VB)
# (CHUNK stayed/VBD to/TO get/VB)
# (CHUNK turned/VBD to/TO go/VB)
# (CHUNK going/VBG to/TO see/VB)
# (CHUNK going/VBG to/TO laugh/VB)
# (CHUNK tried/VBD to/TO bite/VB)
# (CHUNK seem/VB to/TO rise/VB)
# (CHUNK come/VBN to/TO see/VB)
# (CHUNK got/VBN to/TO know/VB)
# (CHUNK seem/VB to/TO take/VB)
# (CHUNK beginning/VBG to/TO creep/VB)
# (CHUNK seemed/VBN to/TO rain/VB)
# (CHUNK like/VB to/TO hear/VB)
# (CHUNK come/VBN to/TO make/VB)
# (CHUNK started/VBD to/TO move/VB)
# (CHUNK bent/VBD to/TO pick/VB)
# (CHUNK permitted/VBN to/TO operate/VB)
# (CHUNK beginning/VBG to/TO get/VB)
# (CHUNK seemed/VBD to/TO think/VB)
# (CHUNK tried/VBD to/TO make/VB)
# (CHUNK wanted/VBD to/TO present/VB)
# (CHUNK expected/VBN to/TO stay/VB)
# (CHUNK wish/VB to/TO start/VB)
# (CHUNK got/VBN to/TO run/VB)
# (CHUNK like/VB to/TO talk/VB)
# (CHUNK disappointed/VBN to/TO find/VB)
# (CHUNK tried/VBN to/TO reason/VB)
# (CHUNK trying/VBG to/TO close/VB)
# (CHUNK want/VB to/TO help/VB)
# (CHUNK surprised/VBN to/TO see/VB)
# (CHUNK trying/VBG to/TO find/VB)
# (CHUNK neglected/VBD to/TO play/VB)
# (CHUNK wanted/VBD to/TO call/VB)
# (CHUNK like/VB to/TO offer/VB)
# (CHUNK want/VB to/TO say/VB)
# (CHUNK wished/VBD to/TO see/VB)
# (CHUNK overheard/VBN to/TO say/VB)
# (CHUNK like/VB to/TO get/VB)
# (CHUNK expected/VBN to/TO perform/VB)
# (CHUNK going/VBG to/TO bring/VB)
# (CHUNK seek/VB to/TO storm/VB)
# (CHUNK used/VBN to/TO defend/VB)
# (CHUNK shocked/VBN to/TO find/VB)
# (CHUNK hesitate/VB to/TO speak/VB)
# (CHUNK beginning/VBG to/TO study/VB)
# (CHUNK grow/VB to/TO devote/VB)
# (CHUNK wish/VB to/TO turn/VB)
# (CHUNK going/VBG to/TO fail/VB)
# (CHUNK wished/VBD to/TO change/VB)
# (CHUNK wanted/VBD to/TO take/VB)
# (CHUNK wanted/VBD to/TO bring/VB)
# (CHUNK like/VB to/TO know/VB)
# (CHUNK intend/VB to/TO marry/VB)
# (CHUNK began/VBD to/TO talk/VB)
# (CHUNK used/VBD to/TO play/VB)
# (CHUNK trying/VBG to/TO get/VB)
# (CHUNK happen/VB to/TO drive/VB)
# (CHUNK hating/VBG to/TO get/VB)
# (CHUNK try/VB to/TO walk/VB)
# (CHUNK left/VBN to/TO believe/VB)
# (CHUNK tried/VBD to/TO rest/VB)
# (CHUNK dying/VBG to/TO defend/VB)
# (CHUNK used/VBD to/TO kid/VB)
# (CHUNK wanted/VBD to/TO paint/VB)
# (CHUNK going/VBG to/TO organize/VB)
# (CHUNK try/VB to/TO paint/VB)
# (CHUNK used/VBD to/TO hang/VB)
# (CHUNK prepared/VBN to/TO worship/VB)
# (CHUNK want/VB to/TO stir/VB)
# (CHUNK beginning/VBG to/TO gather/VB)
# (CHUNK tried/VBD to/TO believe/VB)
# (CHUNK used/VBD to/TO say/VB)
# (CHUNK began/VBD to/TO shudder/VB)
# (CHUNK come/VBN to/TO understand/VB)
# (CHUNK come/VBN to/TO see/VB)
# (CHUNK called/VBD to/TO say/VB)
# (CHUNK decided/VBN to/TO cremate/VB)
# (CHUNK want/VB to/TO meet/VB)
# (CHUNK impelled/VBN to/TO kneel/VB)
# (CHUNK trying/VBG to/TO touch/VB)
# (CHUNK trying/VBG to/TO flatter/VB)
# (CHUNK trying/VBG to/TO worry/VB)
# (CHUNK trying/VBG to/TO worry/VB)
# (CHUNK want/VB to/TO go/VB)
# (CHUNK like/VB to/TO take/VB)
# (CHUNK wanted/VBD to/TO know/VB)
# (CHUNK trying/VBG to/TO get/VB)
# (CHUNK gone/VBN to/TO purify/VB)
# (CHUNK waiting/VBG to/TO see/VB)
# (CHUNK come/VBN to/TO skirt/VB)
# (CHUNK trying/VBG to/TO make/VB)
# (CHUNK go/VB to/TO sleep/VB)
# (CHUNK tried/VBD to/TO emulate/VB)
# (CHUNK began/VBD to/TO pulse/VB)
# (CHUNK amazed/VBN to/TO find/VB)
# (CHUNK kneeling/VBG to/TO tie/VB)
# (CHUNK trying/VBG to/TO get/VB)
# (CHUNK trying/VBG to/TO smile/VB)
# (CHUNK seemed/VBD to/TO float/VB)
# (CHUNK tried/VBD to/TO see/VB)
# (CHUNK stop/VB to/TO analyze/VB)
# (CHUNK supposed/VBN to/TO joke/VB)
# (CHUNK supposed/VBN to/TO handle/VB)
# (CHUNK want/VB to/TO ask/VB)
# (CHUNK got/VBN to/TO admit/VB)
# (CHUNK tried/VBD to/TO leave/VB)
# (CHUNK began/VBD to/TO walk/VB)
# (CHUNK supposed/VBD to/TO stay/VB)
# (CHUNK going/VBG to/TO tell/VB)
# (CHUNK going/VBG to/TO get/VB)
# (CHUNK intended/VBN to/TO make/VB)
# (CHUNK began/VBD to/TO zip/VB)
# (CHUNK obliged/VBN to/TO roll/VB)
# (CHUNK want/VB to/TO stop/VB)
# (CHUNK going/VBG to/TO marry/VB)
# (CHUNK liked/VBD to/TO hear/VB)
# (CHUNK tempted/VBN to/TO tell/VB)
# (CHUNK seemed/VBD to/TO mark/VB)
# (CHUNK tried/VBD to/TO explain/VB)
# (CHUNK managed/VBD to/TO look/VB)
# (CHUNK needed/VBD to/TO get/VB)
# (CHUNK answered/VBD to/TO find/VB)
# (CHUNK afford/VB to/TO get/VB)
# (CHUNK started/VBD to/TO look/VB)
# (CHUNK takes/VBZ to/TO get/VB)
# (CHUNK going/VBG to/TO get/VB)
# (CHUNK tried/VBD to/TO quiet/VB)
# (CHUNK trying/VBG to/TO sound/VB)
# (CHUNK came/VBD to/TO meet/VB)
# (CHUNK seemed/VBD to/TO focus/VB)
# (CHUNK want/VB to/TO talk/VB)
# (CHUNK want/VB to/TO see/VB)
# (CHUNK wants/VBZ to/TO get/VB)
# (CHUNK went/VBD to/TO turn/VB)
# (CHUNK surprised/VBN to/TO find/VB)
# (CHUNK want/VB to/TO stay/VB)
# (CHUNK going/VBG to/TO make/VB)
# (CHUNK hoped/VBD to/TO dig/VB)
# (CHUNK trying/VBG to/TO make/VB)
# (CHUNK going/VBG to/TO lug/VB)
# (CHUNK surprised/VBN to/TO see/VB)
# (CHUNK stop/VB to/TO read/VB)
# (CHUNK intended/VBD to/TO move/VB)
# (CHUNK rising/VBG to/TO sting/VB)
# (CHUNK arranged/VBN to/TO live/VB)
# (CHUNK managed/VBN to/TO find/VB)
# (CHUNK inclined/VBN to/TO wobble/VB)
# (CHUNK supposed/VBN to/TO care/VB)
# (CHUNK shuddered/VBD to/TO think/VB)
# (CHUNK seemed/VBN to/TO understand/VB)
# (CHUNK aroused/VBN to/TO go/VB)
# (CHUNK hate/VB to/TO call/VB)
# (CHUNK wish/VB to/TO leave/VB)
# (CHUNK seemed/VBD to/TO follow/VB)
# (CHUNK supposed/VBN to/TO matter/VB)
# (CHUNK bothered/VBN to/TO tell/VB)
# (CHUNK hesitate/VB to/TO use/VB)
# (CHUNK used/VBD to/TO say/VB)
# (CHUNK try/VB to/TO persuade/VB)
# (CHUNK wanted/VBD to/TO keep/VB)
# (CHUNK trying/VBG to/TO keep/VB)
# (CHUNK blushed/VBD to/TO admit/VB)
# (CHUNK want/VB to/TO continue/VB)
# (CHUNK chosen/VBN to/TO represent/VB)
# (CHUNK want/VB to/TO leave/VB)
# (CHUNK wanted/VBD to/TO work/VB)
# (CHUNK seemed/VBD to/TO regard/VB)
# (CHUNK forbore/VBD to/TO mention/VB)
# (CHUNK managed/VBN to/TO open/VB)
# (CHUNK want/VB to/TO encourage/VB)
# (CHUNK want/VB to/TO watch/VB)
# (CHUNK remember/VB to/TO warn/VB)
# (CHUNK used/VBD to/TO take/VB)
# (CHUNK want/VB to/TO use/VB)
# (CHUNK started/VBD to/TO throw/VB)
# (CHUNK began/VBD to/TO swing/VB)
# (CHUNK started/VBD to/TO carry/VB)
# (CHUNK began/VBD to/TO look/VB)
# (CHUNK going/VBG to/TO happen/VB)
# (CHUNK began/VBD to/TO walk/VB)
# (CHUNK trying/VBG to/TO say/VB)
# (CHUNK trying/VBG to/TO say/VB)
# (CHUNK started/VBD to/TO say/VB)
# (CHUNK wants/VBZ to/TO take/VB)
# (CHUNK started/VBD to/TO take/VB)
# (CHUNK began/VBD to/TO fascinate/VB)
# (CHUNK left/VBD to/TO spend/VB)
# (CHUNK seemed/VBD to/TO work/VB)
# (CHUNK trying/VBG to/TO talk/VB)
# (CHUNK lied/VBD to/TO shorten/VB)
# (CHUNK trying/VBG to/TO make/VB)
# (CHUNK wanted/VBD to/TO force/VB)
# (CHUNK refused/VBN to/TO take/VB)
# (CHUNK seemed/VBD to/TO please/VB)
# (CHUNK grew/VBD to/TO depend/VB)
# (CHUNK meant/VBD to/TO tell/VB)
# (CHUNK trying/VBG to/TO pull/VB)
# (CHUNK seemed/VBD to/TO shiver/VB)
# (CHUNK trying/VBG to/TO remember/VB)
# (CHUNK worked/VBD to/TO recall/VB)
# (CHUNK wished/VBD to/TO call/VB)
# (CHUNK seemed/VBD to/TO stare/VB)
# (CHUNK began/VBD to/TO tremble/VB)
# (CHUNK refusing/VBG to/TO think/VB)
# (CHUNK refusing/VBG to/TO think/VB)
# (CHUNK hoping/VBG to/TO frighten/VB)
# (CHUNK wanted/VBD to/TO run/VB)
# (CHUNK began/VBD to/TO ache/VB)
# (CHUNK began/VBD to/TO bother/VB)
# (CHUNK tried/VBD to/TO take/VB)
# (CHUNK wanted/VBD to/TO kill/VB)
# (CHUNK stopped/VBD to/TO see/VB)
# (CHUNK going/VBG to/TO tell/VB)
# (CHUNK going/VBG to/TO push/VB)
# (CHUNK wanted/VBD to/TO slap/VB)
# (CHUNK started/VBD to/TO type/VB)
# (CHUNK helped/VBN to/TO build/VB)
# (CHUNK refused/VBN to/TO drive/VB)
# (CHUNK wanted/VBD to/TO go/VB)
# (CHUNK likes/VBZ to/TO play/VB)
# (CHUNK like/VB to/TO rise/VB)
# (CHUNK tried/VBN to/TO push/VB)
# (CHUNK trying/VBG to/TO run/VB)
# (CHUNK tried/VBD to/TO make/VB)
# (CHUNK used/VBD to/TO say/VB)
# (CHUNK come/VBN to/TO exist/VB)
# (CHUNK fit/VBN to/TO put/VB)
# (CHUNK stoop/VB to/TO lift/VB)
# (CHUNK wanted/VBD to/TO draw/VB)
# (CHUNK going/VBG to/TO pick/VB)
# (CHUNK intended/VBD to/TO wait/VB)
# (CHUNK determined/VBD to/TO foil/VB)
# (CHUNK strode/VBD to/TO answer/VB)
# (CHUNK trusted/VBN to/TO carry/VB)
# (CHUNK seemed/VBD to/TO help/VB)
# (CHUNK chose/VBD to/TO come/VB)
# (CHUNK tried/VBD to/TO ignore/VB)
# (CHUNK liked/VBN to/TO break/VB)
# (CHUNK began/VBD to/TO aid/VB)
# (CHUNK going/VBG to/TO tear/VB)
# (CHUNK like/VB to/TO exhibit/VB)
# (CHUNK forced/VBN to/TO make/VB)
# (CHUNK hate/VB to/TO admit/VB)
# (CHUNK got/VBN to/TO decide/VB)
# (CHUNK tried/VBD to/TO sell/VB)
# (CHUNK try/VB to/TO swing/VB)
# (CHUNK expect/VB to/TO call/VB)
# (CHUNK paused/VBN to/TO get/VB)
# (CHUNK proceeded/VBD to/TO search/VB)
# (CHUNK began/VBD to/TO suspect/VB)
# (CHUNK endeavoring/VBG to/TO cut/VB)
# (CHUNK wanted/VBD to/TO know/VB)
# (CHUNK daring/VBG to/TO commit/VB)
# (CHUNK given/VBN to/TO dig/VB)
# (CHUNK urged/VBN to/TO attend/VB)
# (CHUNK refused/VBD to/TO receive/VB)
# (CHUNK beckoned/VBN to/TO cross/VB)
# (CHUNK taken/VBN to/TO keep/VB)
# (CHUNK trying/VBG to/TO hold/VB)
# (CHUNK managing/VBG to/TO get/VB)
# (CHUNK promised/VBD to/TO illustrate/VB)
# (CHUNK pretending/VBG to/TO black/VB)
# (CHUNK wanted/VBN to/TO remind/VB)
# (CHUNK Resolving/VBG to/TO get/VB)
# (CHUNK started/VBD to/TO start/VB)
# (CHUNK starting/VBG to/TO woolgather/VB)
# (CHUNK bound/VBN to/TO get/VB)
# (CHUNK wanted/VBD to/TO keep/VB)
# (CHUNK looked/VBN to/TO see/VB)
# (CHUNK chosen/VBN to/TO complement/VB)
# (CHUNK live/VB to/TO hear/VB)
# (CHUNK leaping/VBG to/TO light/VB)
# (CHUNK trying/VBG to/TO prove/VB)
# (CHUNK trying/VBG to/TO determine/VB)
# (CHUNK supposed/VBN to/TO put/VB)
# (CHUNK proceeded/VBD to/TO neglect/VB)
# (CHUNK care/VB to/TO count/VB)
# (CHUNK shuddered/VBD to/TO think/VB)
# (CHUNK telephoned/VBD to/TO announce/VB)
# (CHUNK neglected/VBN to/TO consider/VB)
# (CHUNK trouble/VB to/TO memorize/VB)
# (CHUNK deigned/VBD to/TO appear/VB)
# (CHUNK seemed/VBD to/TO understand/VB)
# (CHUNK try/VB to/TO revive/VB)
# (CHUNK seemed/VBD to/TO produce/VB)
# (CHUNK returning/VBG to/TO jump/VB)
# (CHUNK tried/VBD to/TO farm/VB)
# (CHUNK going/VBG to/TO set/VB)
# (CHUNK turned/VBD to/TO stare/VB)
# (CHUNK seem/VB to/TO think/VB)
# (CHUNK liked/VBD to/TO hire/VB)
# (CHUNK remember/VB to/TO telephone/VB)
# (CHUNK like/VB to/TO work/VB)
# (CHUNK like/VB to/TO disclose/VB)
# (CHUNK got/VBD to/TO put/VB)
# (CHUNK got/VBN to/TO run/VB)
# (CHUNK waiting/VBG to/TO get/VB)
# (CHUNK need/VB to/TO worry/VB)
# (CHUNK seems/VBZ to/TO think/VB)
# (CHUNK tries/VBZ to/TO baffle/VB)
# (CHUNK mean/VB to/TO reconsider/VB)
# (CHUNK refused/VBD to/TO make/VB)
# (CHUNK seems/VBZ to/TO make/VB)
# (CHUNK seems/VBZ to/TO refer/VB)
# (CHUNK seems/VBZ to/TO say/VB)
# (CHUNK delighted/VBN to/TO meet/VB)
# (CHUNK like/VB to/TO know/VB)
# (CHUNK regret/VB to/TO say/VB)
# (CHUNK seems/VBZ to/TO refer/VB)
# (CHUNK come/VBN to/TO talk/VB)
# (CHUNK seem/VB to/TO remember/VB)
# (CHUNK want/VB to/TO hear/VB)
# (CHUNK trying/VBG to/TO get/VB)
# (CHUNK forgot/VBD to/TO say/VB)
# (CHUNK seemed/VBD to/TO believe/VB)
# (CHUNK wanted/VBN to/TO get/VB)
# (CHUNK wanted/VBD to/TO see/VB)
# (CHUNK wanted/VBD to/TO touch/VB)
# (CHUNK got/VBN to/TO entertain/VB)
# (CHUNK tried/VBD to/TO keep/VB)
# (CHUNK going/VBG to/TO tell/VB)
# (CHUNK thought/VBN to/TO mix/VB)
# (CHUNK going/VBG to/TO jump/VB)
# (CHUNK beginning/VBG to/TO catch/VB)
# (CHUNK try/VB to/TO see/VB)
# (CHUNK phoned/VBD to/TO say/VB)
# (CHUNK bothering/VBG to/TO look/VB)
# (CHUNK forced/VBN to/TO wipe/VB)
# (CHUNK used/VBD to/TO pretend/VB)
# (CHUNK refused/VBD to/TO approach/VB)
# (CHUNK used/VBN to/TO express/VB)
# (CHUNK proceeds/VBZ to/TO lash/VB)
# (CHUNK used/VBD to/TO hang/VB)
# (CHUNK seeks/VBZ to/TO expunge/VB)
# (CHUNK trying/VBG to/TO redeem/VB)
# (CHUNK seemed/VBD to/TO take/VB)
# (CHUNK tried/VBD to/TO conceal/VB)
# (CHUNK came/VBD to/TO know/VB)
# (CHUNK refuses/VBZ to/TO continue/VB)
# (CHUNK given/VBN to/TO understand/VB)
# (CHUNK propose/VB to/TO vent/VB)
# (CHUNK proceeded/VBD to/TO mask/VB)
# (CHUNK withhold/VB to/TO keep/VB)
# (CHUNK begin/VB to/TO wither/VB)
# (CHUNK help/VB to/TO intensify/VB)
# (CHUNK seems/VBZ to/TO overtake/VB)
# (CHUNK want/VB to/TO buy/VB)

# %%
def bob_chunker (chunk_string):
    cp = nltk.RegexpParser(chunk_string)
    brown = nltk.corpus.brown
    for sent in brown.tagged_sents():
        tree = cp.parse(sent)
        for subtree in tree.subtrees():
            if subtree.label() == 'CHUNK': print(subtree)

chunk_phrase = 'CHUNK: {<V.*> <TO> <V.*>}'
chunk_phrase2 =  'CHUNK: {<N.*><N.*><N.*><N.*>+}' # alternative: 3 nouns + 1 or more nouns
bob_chunker(chunk_phrase2)
# Out:
# (CHUNK Court/NN-TL Judge/NN-TL Durwood/NP Pye/NP)
# (CHUNK Mayor-nominate/NN-TL Ivan/NP Allen/NP Jr./NP)
# (CHUNK Georgia's/NP$ automobile/NN title/NN law/NN)
# (CHUNK State/NN-TL Welfare/NN-TL Department's/NN$-TL handling/NN)
# (CHUNK Fulton/NP-TL Tax/NN-TL Commissioner's/NN$-TL Office/NN-TL)
# (CHUNK Mayor/NN-TL William/NP B./NP Hartsfield/NP)
# (CHUNK Mrs./NP J./NP M./NP Cheshire/NP)
# (CHUNK E./NP Pelham/NP Rd./NN-TL Aj/NN)
# (CHUNK
#   State/NN-TL
#   Party/NN-TL
#   Chairman/NN-TL
#   James/NP
#   W./NP
#   Dorsey/NP)
# (CHUNK Texas/NP Sen./NN-TL John/NP Tower/NP)
# (CHUNK Lt./NN-TL Gov./NN-TL Garland/NP Byrd's/NP$ campaign/NN)
# (CHUNK Schley/NP County/NN-TL Rep./NN-TL B./NP D./NP Pelham/NP)
# (CHUNK Colquitt/NP-TL Policeman/NN-TL Tom/NP Williams/NP)
# (CHUNK Rep./NN-TL Charles/NP E./NP Hughes/NP)
# (CHUNK State/NN-TL Health/NN-TL Department's/NN$-TL authority/NN)
# (CHUNK Lamar/NP-TL county/NN-TL Hospital/NN-TL District/NN-TL)
# (CHUNK Sen./NN-TL A./NP R./NP Schwartz/NP)
# (CHUNK Sen./NN-TL A./NP M./NP Aikin/NP Jr./NP)
# (CHUNK Rep./NN-TL Henry/NP C./NP Grover/NP)
# (CHUNK Dr./NN-TL Clarence/NP Charles/NP Clark/NP)
# (CHUNK Dr./NN-TL J./NP R./NP McLemore/NP)
# (CHUNK Rhode/NP-TL Island/NN-TL State/NN-TL College/NN-TL)
# (CHUNK Supt./NN-TL Chester/NP O./NP Strickland/NP)
# (CHUNK Summerdale/NP police/NN burglary/NN trial/NN)
# (CHUNK Judge/NN-TL James/NP B./NP Parsons/NP)
# (CHUNK Judge/NN-TL John/NP M./NP Karns/NP)
# (CHUNK Hospital/NN outpatient/NN clinic/NN diagnostic/NN service/NN)
# (CHUNK Senate/NN-TL Republican/NP-TL Leader/NN-TL Dirksen/NP)
# (CHUNK
#   House/NN-TL
#   Republican/NP-TL
#   Leader/NN-TL
#   Charles/NP
#   Halleck/NP)
# (CHUNK House/NN-TL Speaker/NN-TL Sam/NP Rayburn/NP)
# (CHUNK President/NN-TL Eisenhower's/NP$ cabinet/NN selections/NNS)
# (CHUNK State/NN-TL Dean/NP Rusk's/NP$ speeches/NNS)
# (CHUNK Vice-President/NN-TL Richard/NP M./NP Nixon/NP)
# (CHUNK Senator/NN-TL Thruston/NP B./NP Morton/NP)
# (CHUNK Senator/NN-TL J./NP W./NP Fulbright/NP)
# (CHUNK Fire/NN-TL Chief/NN-TL John/NP A./NP Laughlin/NP)
# (CHUNK Narragansett/NP-TL Race/NN-TL Track/NN-TL grounds/NNS)
# (CHUNK Miss/NP Mary/NP R./NP Grant/NP)
# (CHUNK state/NN law/NN enforcement/NN officers/NNS)
# (CHUNK Council/NN-TL President/NN-TL Raymond/NP Fortin/NP Sr./NP)
# (CHUNK Providence/NP-TL Town/NN-TL Council/NN-TL meeting/NN)
# (CHUNK Council/NN president/NN Frank/NP SanAntonio/NP)
# (CHUNK Town/NN-TL Solicitor/NN-TL Michael/NP A./NP Abatuno/NP)
# (CHUNK Sen./NN-TL Walter/NP H./NP Jones/NP R-Bergen/NN)
# (CHUNK Sen./NN-TL Wayne/NP Dumont/NP Jr./NP R-Warren/NN)
# (CHUNK Mack/NP-TL Truck/NN-TL Co./NN-TL plant/NN)
# (CHUNK Sen./NN-TL Charles/NP W./NP Sandman/NP)
# (CHUNK Sen./NN-TL Clifford/NP Case/NP Aj/NN)
# (CHUNK Mrs./NP Harriet/NP Copeland/NP Greenfield/NP)
# (CHUNK Westfield/NP-TL Women's/NNS$-TL Republican/NP-TL Club/NN-TL)
# (CHUNK County/NN-TL Supervisor/NN-TL Weldon/NP R./NP Sheets/NP)
# (CHUNK Mayor/NN-TL James/NP J./NP Sheeran/NP)
# (CHUNK Orange/NP-TL public/NN safety/NN commissioner/NN)
# (CHUNK
#   Conservation/NN-TL
#   Commissioner/NN-TL
#   Salvatore/NP
#   A./NP
#   Bontempo/NP)
# (CHUNK State/NN-TL Controller/NN-TL Arthur/NP Levitt/NP)
# (CHUNK Representative/NN-TL Charles/NP A./NP Buckley/NP)
# (CHUNK Carmine/NP G./NP De/NP Sapio/NP)
# (CHUNK Controller/NN-TL Lawrence/NP E./NP Gerosa/NP)
# (CHUNK Representative/NN-TL James/NP W./NP Trimble/NP)
# (CHUNK Speaker/NN-TL Sam/NP Rayburn's/NP$ forces/NNS)
# (CHUNK Thomas/NP P./NP O'Neill/NP Jr./NP)
# (CHUNK R./NP Sargent/NP Shriver/NP Jr./NP)
# (CHUNK Maurice/NP Couve/NP De/NP Murville/NP)
# (CHUNK William/NP S./NP Pfaff/NP Jr./NP)
# (CHUNK President/NN-TL John/NP F./NP Kennedy/NP)
# (CHUNK President/NN-TL Dwight/NP D./NP Eisenhower/NP)
# (CHUNK Vice-President/NN-TL L./NP B./NP Johnson/NP)
# (CHUNK Congressman/NN-TL Frank/NP E./NP Smith/NP)
# (CHUNK US/NN Sens./NNS-TL James/NP O./NP Eastland/NP)
# (CHUNK Gov./NN-TL Jimmie/NP H./NP Davis/NP administration/NN)
# (CHUNK City/NN-TL Controller/NN-TL Alexander/NP Hemphill/NP)
# (CHUNK Hughes/NP-TL Steel/NN-TL Erection/NN-TL Co./NN-TL)
# (CHUNK Director/NN-TL Donald/NP C./NP Wagner/NP)
# (CHUNK City/NN-TL Solicitor/NN-TL David/NP Berger/NP)
# (CHUNK District/NN-TL Attorney/NN-TL James/NP C./NP Crumlish/NP)
# (CHUNK U./NP-TL S./NP-TL District/NN-TL Court/NN-TL)
# (CHUNK City/NN-TL Council's/NN$-TL Finance/NN-TL Committee/NN-TL)
# (CHUNK Police/NNS-TL Commissioner/NN-TL Howard/NP R./NP Leary/NP)
# (CHUNK
#   City/NN
#   Finance/NN-TL
#   Director/NN-TL
#   Richard/NP
#   J./NP
#   McConnell/NP)
# (CHUNK Health/NN-TL Commissioner/NN-TL Eugene/NP A./NP Gillis/NP)
# (CHUNK Norristown/NP attorney/NN Julian/NP W./NP Barnard/NP)
# (CHUNK Montgomery/NP-TL County/NN-TL Court/NN-TL Friday/NR)
# (CHUNK President/NN-TL Judge/NN-TL William/NP F./NP Dannehower/NP)
# (CHUNK Judge/NN-TL Warren/NP K./NP Hess/NP)
# (CHUNK
#   $300,000,000/NNS
#   Eastwick/NP-TL
#   Redevelopment/NN-TL
#   Area/NN-TL
#   project/NN)
# (CHUNK Henry/NP A./NP Berger/NP firm/NN)
# (CHUNK Philadelphia/NP-TL Builders/NNS-TL Eastwick/NP Corp./NN-TL)
# (CHUNK Dr./NN-TL Constantinos/NP A./NP Doxiadis/NP)
# (CHUNK Battalion/NN-TL Chief/NN-TL Stanton/NP M./NP Gladden/NP)
# (CHUNK World/NN-TL Affairs/NNS-TL Council/NN-TL Monday/NR night/NN)
# (CHUNK Mrs./NP Ralph/NP H./NP Molvar/NP)
# (CHUNK Chairman/NN-TL C./NP Richard/NP Mears/NP)
# (CHUNK Dr./NN-TL Melvin/NP W./NP Barnes/NP)
# (CHUNK Emerald/NN-TL Empire/NN-TL Kiwanis/NP-TL Club/NN-TL)
# (CHUNK Multnomah/NP-TL County/NN-TL Circuit/NN-TL Judge/NN-TL)
# (CHUNK Beaverton/NP-TL School/NN-TL District/NN-TL No./NN-TL)
# (CHUNK Monday/NR night/NN workshop/NN session/NN)
# (CHUNK Sen./NN-TL Wayne/NP L./NP Morse/NP)
# (CHUNK Labor/NN-TL Commissioner/NN-TL Norman/NP Nilsen/NP)
# (CHUNK Oak/NN-TL Lodge/NN-TL Water/NN-TL district/NN board/NN)
# (CHUNK Secretary/NN-TL Hugh/NP G./NP Stout/NP)
# (CHUNK Rev./NP T./NP F./NP Zimmerman/NP)
# (CHUNK Rev./NP T./NP F./NP Zimmerman/NP)
# (CHUNK Rev./NP R./NP L./NP Brandt/NP)
# (CHUNK U.S./NP-TL Dist./NN-TL Judge/NN-TL Charles/NP L./NP Powell/NP)
# (CHUNK Portland's/NP$ insurance/NN fraud/NN trial/NN)
# (CHUNK Attorney/NN Dwight/NP L./NP Schwab/NP)
# (CHUNK prosecutor/NN A./NP Lawrence/NP Burbank/NP)
# (CHUNK Catcher/NN Frank/NP House's/NP$ throw/NN)
# (CHUNK Rookie/NN southpaw/NN George/NP Stepanovich/NP)
# (CHUNK Shortstop/NN-TL Jerry/NP Adair's/NP$ glove/NN)
# (CHUNK baseman/NN Throneberry's/NP$ head/NN Brandt/NP)
# (CHUNK
#   Baltimore's/NP$
#   Florida/NP-TL
#   Grapefruit/NN-TL
#   League/NN-TL
#   news/NN)
# (CHUNK Kansas/NP City/NN-TL rookie/NN hurlers/NNS)
# (CHUNK J./NP A./NP W./NP Iglehart/NP)
# (CHUNK Relations/NNS-TL Director/NN-TL Jack/NP Dunn/NP)
# (CHUNK $4,500/NNS St./NN-TL Patrick's/NP$-TL Day/NN-TL Purse/NN-TL)
# (CHUNK Richard/NP M./NP Forbes's/NP$ Paget/NP)
# (CHUNK Glen/NP T./NP Hallowell's/NP$ Milties/NP Miss/NP)
# (CHUNK St./NN-TL Patty/NP-TL Day/NN-TL celebrants/NNS)
# (CHUNK apprentice/NN James/NP P./NP Verrone/NP)
# (CHUNK St./NN-TL Patrick's/NP$-TL Day/NN-TL Purse/NN-TL)
# (CHUNK Columbus/NP-TL track/NN meet/NN tonight/NR)
# (CHUNK York/NP-TL Yankee/NP-TL shortstop/NN Tony/NP Kubek/NP)
# (CHUNK Chicago/NP-TL White/NN-TL Sox/NPS-TL today/NR)
# (CHUNK Army/NN-TL Signal/NN-TL Corps/NN-TL veteran/NN)
# (CHUNK Assistant/NN coach/NN John/NP Cudmore/NP)
# (CHUNK Air/NN-TL Force/NN-TL fullback/NN Nick/NP Arshinkoff/NP)
# (CHUNK sophomore/NN center/NN Mike/NP Kelsey/NP)
# (CHUNK Air/NN-TL Force/NN-TL film/NN Monday/NR)
# (CHUNK Texas/NP Tech's/NP$ sweat-suits/NNS drill/NN Monday/NR)
# (CHUNK coach/NN Hank/NP Stram's/NP$ men/NNS)
# (CHUNK Buffalo/NP coach/NN Buster/NP Ramsey/NP)
# (CHUNK Louisiana/NP-TL State/NN-TL field/NN general/NN)
# (CHUNK pinpoint/NN pitching/NN Monday/NR night/NN)
# (CHUNK Billy/NP Gardner's/NP$ line/NN double/NN)
# (CHUNK Chicago/NP-TL White/NN-TL Sox/NPS-TL Monday/NR)
# (CHUNK
#   Boston/NP-TL
#   Red/NN-TL
#   Sox/NPS-TL
#   Outfielder/NN-TL
#   Jackie/NP
#   Jensen/NP)
# (CHUNK Diving/NN-TL Champion/NN-TL Zoe/NP Ann/NP Olsen/NP)
# (CHUNK Union/NN-TL Pacific/NP-TL Railroad/NN-TL streamliner/NN)
# (CHUNK Sports/NNS-TL Writer/NN-TL Ensign/NP Ritchie/NP)
# (CHUNK ball/NN player's/NN$ ball/NN player/NN)
# (CHUNK football/NN champion/NN Philadelphia/NP-TL Eagles/NNS-TL)
# (CHUNK Norm/NP Van/NP Brocklin/NP permission/NN)
# (CHUNK Mayor/NN-TL Wagner's/NP$ Baseball/NN-TL Committee/NN-TL)
# (CHUNK Mrs./NP Charles/NP Shipman/NP Payson/NP)
# (CHUNK Commissioner/NN-TL Ford/NP C./NP Frick/NP)
# (CHUNK Golf/NN-TL Writers/NNS-TL Association/NN-TL tonight/NR)
# (CHUNK Pirate/NN-TL Manager/NN-TL Danny/NP Murtaugh/NP)
# (CHUNK record/NN five-home/NN run/NN day/NN)
# (CHUNK St./NP-TL Louis/NP-TL University/NN-TL players/NNS)
# (CHUNK Los/NP Angeles'/NP$ Wrigley/NP Field/NP Jr./NP)
# (CHUNK Mrs./NP Joan/NP Monroe/NP Armour/NP)
# (CHUNK F./NP Lee/NP H./NP Wendell/NP)
# (CHUNK Walter/NP D./NP Monroe/NP Jr./NP)
# (CHUNK Mrs./NP Camilla/NP Alsop/NP Wendell/NP)
# (CHUNK Mrs./NP Frank/NP S./NP Sims/NP)
# (CHUNK Chicago/NP-TL Cancer/NN-TL Research/NN-TL Foundation/NN-TL)
# (CHUNK Mrs./NP Henry/NP T./NP Sulcer/NP)
# (CHUNK Oak/NN-TL Park/NN-TL Arms/NNS-TL hotel/NN)
# (CHUNK John/NP G./NP Beadles'/NPS$ beach/NN house/NN)
# (CHUNK States/NNS-TL Lawn/NN-TL Tennis/NN-TL association/NN)
# (CHUNK Presbyterian-St./NP Luke's/NP$ Fashion/NN-TL show/NN)
# (CHUNK Mrs./NP Maurice/NP P./NP Geraghty/NP)
# (CHUNK Miss/NP Abra/NP Prentice's/NP$ debut/NN supper/NN dance/NN)
# (CHUNK Richard/NP S./NP Burkes'/NPS$ home/NN)
# (CHUNK Mrs./NP Charles/NP H./NP Sethness/NP Jr./NP)
# (CHUNK Mrs./NP Clinton/NP B./NP King/NP)
# (CHUNK Towne/NN-TL Bal/NP Masque/NP tomorrow/NR)
# (CHUNK N./NP Y./NP C./NP today/NR)
# (CHUNK Danny/NP Thomas/NP A./NP L./NP S./NP A./NP C./NP)
# (CHUNK Danny's/NP$ St./NN-TL Jude/NP-TL hospital/NN)
# (CHUNK emergency/NN telephone/NN building/NN fund/NN drive/NN)
# (CHUNK U-I/NN Chief/NN-TL Milt/NP Rackmil/NP)
# (CHUNK Ray/NP Lenobel's/NP$ fur/NN firm/NN)
# (CHUNK Dick/NP Nixon's/NP$ campaign/NN slogan/NN)
# (CHUNK Mrs./NP J./NP Edward/NP Hackstaff/NP)
# (CHUNK Mrs./NP J./NP Clinton/NP Bowman/NP)
# (CHUNK Mrs./NP Robert/NP L./NP Chase/NP)
# (CHUNK Mrs./NP John/NP C./NP Vroman/NP Jr./NP)
# (CHUNK Mrs./NP Robert/NP F./NP McDermott/NP)
# (CHUNK Mrs./NP Piero/NP De/NP Luise/NP)
# (CHUNK stag/NN dinner/NN Friday/NR evening/NN)
# (CHUNK Mrs./NP D./NP W./NP Moore/NP)
# (CHUNK Mrs./NP J./NP Clinton/NP Bowman/NP)
# (CHUNK Mrs./NP Rollie/NP W./NP Bradford/NP)
# (CHUNK Mrs./NP Samuel/NP Butler/NP Jr./NP)
# (CHUNK Mrs./NP Donald/NP Carr/NP Campbell/NP)
# (CHUNK Mrs./NP John/NP C./NP Davis/NP)
# (CHUNK Mrs./NP William/NP E./NP Glass/NN-TL)
# (CHUNK Mrs./NP Richard/NP Gibson/NP Smith/NP)
# (CHUNK Mrs./NP James/NP S./NP Sudier/NP)
# (CHUNK Mrs./NP Andrew/NP S./NP Kelsey/NP)
# (CHUNK Rev./NP Robert/NP D./NP Howard/NP)
# (CHUNK Miss/NP Judith/NP Ellen/NP Gay/NP)
# (CHUNK Mrs./NP Ferris/NP M./NP Gay/NP)
# (CHUNK Dr./NN-TL W./NP B./NP I./NP Martin/NP)
# (CHUNK Miss/NP Joan/NP Frances/NP Baker/NP)
# (CHUNK Rhodes/NP Semmes/NP Baker/NP Jr./NP)
# (CHUNK Mrs./NP Henry/NP Cater/NP Parmer/NP)
# (CHUNK Mrs./NP Howard/NP M./NP Dean/NP)
# (CHUNK Mrs./NP James/NP A./NP Reeder/NP)
# (CHUNK Miss/NP Shirley/NP Joan/NP Meredith/NP)
# (CHUNK Mrs./NP Hardy/NP P./NP Mills/NP)
# (CHUNK Miss/NP Glenda/NP Kay/NP Meredith/NP)
# (CHUNK Miss/NP Marcile/NP Marie/NP Glison/NP)
# (CHUNK Thomas/NP Earl/NP Loving/NP Jr./NP)
# (CHUNK Mrs./NP Charles/NP Ervin/NP Glison/NP)
# (CHUNK Mrs./NP H./NP J./NP Grinsfelder/NP)
# (CHUNK Mrs./NP Harry/NP K./NP Cohen/NP)
# (CHUNK Mrs./NP Bernhard/NP S./NP Blumenthal/NP)
# (CHUNK Mrs./NP Harry/NP M./NP Rose/NP)
# (CHUNK Mrs./NP B./NP Lewis/NP Kaufnabb/NP)
# (CHUNK Mrs./NP Samuel/NP P./NP Weinberg/NP)
# (CHUNK Mrs./NP Robert/NP O./NP Spurdle/NP)
# (CHUNK Mrs./NP James/NP A./NP Moody/NP)
# (CHUNK Mrs./NP Frank/NP C./NP Wilkinson/NP)
# (CHUNK Mrs./NP Harold/NP G./NP Lacy/NP)
# (CHUNK Mrs./NP Albert/NP W./NP Terry/NP)
# (CHUNK Mrs./NP Henry/NP M./NP Chance/NP)
# (CHUNK Mrs./NP Robert/NP O./NP Spurdle/NP)
# (CHUNK Mrs./NP Harcourt/NP N./NP Trimble/NP)
# (CHUNK Mrs./NP John/NP A./NP Moller/NP)
# (CHUNK Mrs./NP William/NP G./NP Kilhour/NP)
# (CHUNK Mrs./NP John/NP L./NP Baringer/NP)
# (CHUNK Mrs./NP Samuel/NP B./NP D./NP Baird/NP)
# (CHUNK Mrs./NP William/NP H./NP Meyle/NP)
# (CHUNK Mrs./NP Richard/NP W./NP Hole/NP)
# (CHUNK Mrs./NP William/NP F./NP Harrity/NP)
# (CHUNK Mrs./NP Robert/NP O./NP Spurdle/NP)
# (CHUNK Mrs./NP E./NP H./NP Kloman/NP)
# (CHUNK Mrs./NP Robert/NP W./NP Wolcott/NP)
# (CHUNK Mrs./NP Frederick/NP C./NP Wheeler/NP)
# (CHUNK Mrs./NP William/NP A/NN Boyd/NP)
# (CHUNK Mrs/NN F./NP Vernon/NP Putt/NP)
# (CHUNK Mrs./NP John/NP Charles/NP Cotty/NP)
# (CHUNK Mrs./NP Francis/NP G./NP Felske/NP)
# (CHUNK Mrs./NP I./NP S./NP Kamens/NP)
# (CHUNK Mrs./NP N./NP Volney/NP Ludwick/NP)
# (CHUNK Mrs./NP John/NP J./NP Evans/NP)
# (CHUNK Mrs./NP A./NP Voorhees/NP Anderson/NP)
# (CHUNK Miss/NP Mary/NP Ann/NP Marella/NP)
# (CHUNK Mr./NP Robert/NP L./NP Orcutt/NP)
# (CHUNK Mrs./NP Donald/NP R./NP Orcutt/NP)
# (CHUNK Mrs./NP Harry/NP D./NP Hoaps/NP)
# (CHUNK Mrs./NP James/NP F./NP Mitchell/NP)
# (CHUNK Mrs./NP John/NP B./NP Walbridge/NP)
# (CHUNK Mrs./NP L./NP DeForest/NP Emmert/NP)
# (CHUNK Mrs./NP Ashman/NP E./NP Emmert/NP)
# (CHUNK Mrs./NP William/NP H./NP Merner/NP)
# (CHUNK Mrs./NP H./NP E./NP Godwin/NP)
# (CHUNK Mrs./NP Richard/NP Peter/NP Vieth/NP)
# (CHUNK Miss/NP Susan/NP Ann/NP Vieth/NP)
# (CHUNK Mrs./NP Nell/NP Kennedy/NP Wall/NP)
# (CHUNK Louise/NP S./NP McGehee/NP school/NN)
# (CHUNK Delta/NP Kappa/NP Epsilon/NP fraternity/NN)
# (CHUNK Mrs./NP Richard/NP B./NP McConnell/NP)
# (CHUNK Mrs./NP Raymond/NP B./NP Walker/NP)
# (CHUNK Mrs./NP McConnell's/NP$ debutante/NN niece/NN)
# (CHUNK Debutante/NN Miss/NP Lady/NP Helen/NP Hardy/NP)
# (CHUNK Mrs./NP G./NP Henry/NP Pierson/NP Jr./NP)
# (CHUNK roses/NNS slipper/NN satin/NN gown/NN)
# (CHUNK Mrs./NP Peter/NP Feringa/NP Jr./NP)
# (CHUNK street/NN length/NN silk/NN taffeta/NN dress/NN)
# (CHUNK Anne/NP Arundel/NP county/NN home/NN)
# (CHUNK Anne/NP Arundel/NP county/NN school/NN superintendent/NN)
# (CHUNK Dr./NN-TL David/NP S./NP Jenkins/NP)
# (CHUNK Mrs./NP D./NP Ellwood/NP Williams/NP)
# (CHUNK Dr./NN-TL Thomas/NP G./NP Pullen/NP)
# (CHUNK State/NN-TL Senator/NN-TL Joseph/NP A./NP Bertorelli/NP)
# (CHUNK city's/NN$ snow/NN clearing/NN program/NN)
# (CHUNK Councilman/NN-TL William/NP D./NP Schaefer/NP)
# (CHUNK snow/NN emergency/NN route/NN plan/NN)
# (CHUNK Spring/NN-TL Grove/NN-TL State/NN-TL Hospital/NN-TL)
# (CHUNK Anne/NP-TL Arundel/NP-TL County/NN-TL Jail/NN-TL)
# (CHUNK Trooper/NN-TL J./NP A./NP Grzesiak/NP)
# (CHUNK Bow/NP-TL St./NN-TL police/NN court/NN)
# (CHUNK Vic/NP theater/NN Saturday/NR afternoon/NN)
# (CHUNK Judge/NN-TL Joseph/NP Sam/NP Perry/NP)
# (CHUNK city/NN police/NN narcotics/NNS unit/NN)
# (CHUNK Patrolman/NN James/NP F./NP Simms/NP)
# (CHUNK Assistant/NN Prosecutor/NN-TL Fred/NP Lewis/NP)
# (CHUNK Circuit/NN Judge/NN-TL Paul/NP R./NP Cash/NP)
# (CHUNK gas/NN explosion/NN Saturday/NR night/NN)
# (CHUNK Lyle/NP-TL Elliott/NP-TL Funeral/NN-TL Home/NN-TL)
# (CHUNK Assistant/NN Fire/NN-TL Chief/NN-TL Chester/NP Cornell/NP)
# (CHUNK mother's/NN$ death/NN yesterday/NR afternoon/NN)
# (CHUNK Mrs./NP Frank/NP C./NP Smith/NP)
# (CHUNK
#   Tareytown/NP-TL
#   Acres/NNS-TL
#   Homeowners/NNS-TL
#   Association/NN-TL)
# (CHUNK Principal/NN Clayton/NP W./NP Pohly/NP)
# (CHUNK Traffic/NN-TL Judge/NN-TL George/NP T./NP Murphy/NP)
# (CHUNK U.S./NP-TL Ambassador/NN-TL Winthrop/NP G./NP Brown/NP)
# (CHUNK Pathet/NP Lao/NP rebel/NN attacks/NNS)
# (CHUNK Havana/NP automobile/NN service/NN stations/NNS)
# (CHUNK board/NN chairman/NN Henry/NP L./NP Bowden/NP)
# (CHUNK Patrolman/NN-TL G./NP E./NP Hammons/NP)
# (CHUNK Atlanta/NP Negro/NP student/NN movement/NN)
# (CHUNK movie/NN theater/NN integration/NN Friday/NR)
# (CHUNK Oakland/NP-TL City/NN-TL Methodist/NP Church/NN-TL)
# (CHUNK Rev./NP J./NP H./NP Hearn/NP)
# (CHUNK Mrs./NP Emma/NP B./NP Odom/NP)
# (CHUNK Mrs./NP Lola/NP M./NP Harris/NP)
# (CHUNK Mrs./NP Gene/NP F./NP Stoll/NP)
# (CHUNK Mrs./NP W./NP E./NP Little/NP)
# (CHUNK Mrs./NP Hal/NP B./NP Wansley/NP)
# (CHUNK Patrolmen/NNS J./NP W./NP Slate/NN-TL)
# (CHUNK A./NP L./NP Crawford/NP Jr./NP)
# (CHUNK Mrs./NP R./NP C./NP Thomas/NP)
# (CHUNK fire/NN ant/NN eradication/NN program/NN)
# (CHUNK W./NP E./NP Blasingame/NP state/NN entomologist/NN)
# (CHUNK afternoon/NN rush/NN traffic/NN hours/NNS)
# (CHUNK Georgia/NP weekend/NN traffic/NN crashes/NNS)
# (CHUNK Mrs./NP Lucille/NP Herrington/NP Jones/NP)
# (CHUNK Administrator/NN-TL Andrew/NP F./NP Juras/NP)
# (CHUNK Mrs./NP Grace/NP O./NP Peck/NP)
# (CHUNK Joseph/NP E./NP Harvey/NP Jr./NP)
# (CHUNK Portland/NP-TL Rotary/NP-TL Club/NN-TL Tuesday/NR)
# (CHUNK bank/NN robber/NN Lawrence/NP G./NP Huntley/NP)
# (CHUNK Sheriff/NN-TL W./NP H./NP Forsyth/NP)
# (CHUNK Mrs./NP Lucy/NP Brett/NP Andrew/NP)
# (CHUNK
#   Labor/NN-TL
#   Relations/NNS-TL
#   Board/NN-TL
#   election/NN
#   Thursday/NR)
# (CHUNK Mrs./NP Sidney/NP S./NP Stein/NP Jr./NP)
# (CHUNK $100/NNS U.S./NP-TL Savings/NNS-TL Bond/NP-TL)
# (CHUNK baton/NN twirler/NN Sue/NP Ann/NP Nuttall/NP)
# (CHUNK 4-H/NN sheep/NN showman/NN contest/NN)
# (CHUNK champion/NN 4-H/NN market/NN hog/NN)
# (CHUNK Dr./NN-TL Allan/NP A./NP DiSimone/NP)
# (CHUNK Mrs./NP Stephen/NP M./NP Kochanek/NP)
# (CHUNK Patrolman/NN Robert/NP J./NP Nunes/NP)
# (CHUNK city/NN sewer/NN maintenance/NN division/NN)
# (CHUNK firm's/NN$ incinerator/NN site/NN yesterday/NR)
# (CHUNK Rhode/NP-TL Island/NN-TL Incinerator/NN-TL Service/NN-TL)
# (CHUNK state/NN Labor/NN-TL Relations/NNS-TL Board/NN-TL)
# (CHUNK Warwick/NP-TL School/NN-TL Committee's/NN$-TL appointment/NN)
# (CHUNK Dr./NN-TL Michael/NP F./NP Walsh/NP)
# (CHUNK Supt./NN-TL Clarence/NP S./NP Taylor/NP)
# (CHUNK Judge/NN-TL Fred/NP B./NP Perkins/NP)
# (CHUNK Journal-Bulletin/NP Santa/NP Claus/NP Fund/NN-TL)
# (CHUNK destroyer/NN picket/NN escort/NN Kretchmer/NP)
# (CHUNK U.S./NP-TL Attorney/NN-TL Macon/NP-TL Weaver/NP)
# (CHUNK Ku/NP Klux/NP Klan/NP membership/NN)
# (CHUNK Judge/NN-TL H./NP Hobart/NP Grooms/NP)
# (CHUNK Ku/NP Klux/NP Klan/NP connections/NNS)
# (CHUNK Dr./NN-TL James/NP McN./NP Hester/NP)
# (CHUNK Dr./NN-TL Carroll/NP V./NP Newsom/NP)
# (CHUNK U./NP-TL S./NP-TL Forest/NN-TL Service/NN-TL)
# (CHUNK water/NN pollution/NN control/NN programs/NNS)
# (CHUNK Reed/NP Rogers/NP Da/NP Fonta/NP)
# (CHUNK Columbus/NP-TL Day/NN-TL Celebration/NN-TL Committee/NN-TL)
# (CHUNK Judge/NN-TL John/NP B./NP Molinari/NP)
# (CHUNK John/NP P./NP Figone/NP Jr./NP)
# (CHUNK Morton/NP-TL Foods/NNS-TL stock/NN issue/NN)
# (CHUNK E.G.T./NP partner/NN Dean/NP Guerin/NP)
# (CHUNK U.S./NP potato/NN chip/NN industry/NN)
# (CHUNK Texas/NP-TL Cotton/NN-TL Ginner's/NN$-TL Association/NN-TL)
# (CHUNK Lummus/NP-TL Cotton/NN-TL Gin/NN-TL Co./NN-TL)
# (CHUNK Moss/NP-TL Gordin/NP-TL Lint/NN-TL Cleaner/NN-TL Co./NN-TL)
# (CHUNK John/NP E./NP Mitchell/NP Co./NN-TL)
# (CHUNK Hinckley/NP-TL Gin/NN-TL Supply/NN-TL Co./NN-TL)
# (CHUNK Cen-Tennial/NN-TL Gin/NN-TL Supply/NN-TL Co./NN-TL)
# (CHUNK Cotton/NN-TL Belt/NN-TL Gin/NN-TL Service/NN-TL)
# (CHUNK Dallas/NP-TL Sales/NNS-TL Executives/NNS-TL Club/NN-TL)
# (CHUNK N./NP R./NP Crozier/NP Tech./NP Paulah/NP Thompson/NP)
# (CHUNK Palo/NP Alto/NP venture/NN capital/NN firm/NN)
# (CHUNK Treasury/NN-TL Secretary/NN-TL Douglas/NP Dillon/NP)
# (CHUNK Railroad/NN-TL president/NN Alfred/NP E./NP Perlman/NP)
# (CHUNK Board/NN-TL Chairman/NN-TL Howard/NP Simpson/NP)
# (CHUNK O/NN president/NN Walter/NP J./NP Tuohy/NP)
# (CHUNK government's/NN$ short-term/NN borrowing/NN costs/NNS)
# (CHUNK Farm/NN machinery/NN dealer/NN Bob/NP Houtz/NP)
# (CHUNK farm/NN equipment/NN vice/NN president/NN)
# (CHUNK company's/NN$ farm/NN equipment/NN dealers/NNS)
# (CHUNK J./NP I./NP Case/NP tractors/NNS)
# (CHUNK country's/NN$ farm/NN equipment/NN manufacturers/NNS)
# (CHUNK Ford/NP-TL Motor/NN-TL Co./NN-TL vice/NN president/NN)
# (CHUNK Christian/NP Dior/NP shoes/NNS Paris/NP)
# (CHUNK Mrs./NP E./NP E./NP Fogelson/NP)
# (CHUNK Hollywood's/NP$ Louis/NP B./NP Mayer/NP)
# (CHUNK Mrs./NP Phil/NP G./NP Abell/NP)
# (CHUNK Mmes/NN R./NP P./NP Anderson/NP)
# (CHUNK Mrs./NP Alice/NP H./NP Reese/NP)
# (CHUNK Mrs./NP Clara/NP L./NP Oliver/NP)
# (CHUNK Mrs./NP Joseph/NP R./NP Bolker/NP)
# (CHUNK
#   Music/NN-TL
#   Center/NN-TL
#   Building/NN-TL
#   Fund/NN-TL
#   Committee/NN-TL)
# (CHUNK Los/NP-TL Angeles/NP-TL Country/NN-TL Club/NN-TL)
# (CHUNK Mmes./NPS William/NP A./NP Thompson/NP)
# (CHUNK Dr./NN-TL W./NP A./NP Swim/NP)
# (CHUNK Dan/NP McFarland/NP Chandler/NP Jr./NP)
# (CHUNK to/NPS Austin/NP C./NP Smith/NP Jr./NP)
# (CHUNK Mrs./NP Samuel/NP Moody/NP Haskins/NP)
# (CHUNK Henri/NP De/NP La/NP Chapelles/NPS)
# (CHUNK Mrs./NP Werner/NP H./NP Althaus/NP)
# (CHUNK Hotel/NN-TL Escape's/NN$-TL Bonanza/NN-TL room/NN)
# (CHUNK Fireside/NN-TL Steak/NN-TL Ranch/NN-TL Wednesday/NR)
# (CHUNK Galt/NP-TL Ocean/NN-TL Mile/NN-TL Hotel/NN-TL)
# (CHUNK Miami/NP-TL Playboy/NN-TL Club's/NN$-TL pianist/NN)
# (CHUNK St./NN-TL Thomas/NP-TL Aquinas/NP-TL Monday/NR)
# (CHUNK Fort/NN-TL Lauderdale/NP high/NN Thursday/NR)
# (CHUNK couples/NNS Sunday/NR school/NN class/NN)
# (CHUNK Rev./NP John/NP D./NP Henderson/NP)
# (CHUNK Rev./NP Warren/NP I./NP Densmore/NP)
# (CHUNK Sherman/NP Clay/NP box/NN office/NN)
# (CHUNK conductor/NN Earl/NP Bernard/NP Murray/NP)
# (CHUNK San/NP Francisco/NP Chamber/NN-TL Music/NN-TL Society/NN-TL)
# (CHUNK Puerto/NP Rico/NP Governor/NN-TL Luis/NP Munoz/NP Marin/NP)
# (CHUNK Monthly/NN-TL editor/NN Edward/NP Weeks/NP)
# (CHUNK KQED/NN Summer/NN-TL Music/NN-TL Festival/NN-TL)
# (CHUNK Dr./NN-TL Robert/NP C./NP Miller/NP)
# (CHUNK Mrs./NP Henry/NP Francis/NP Lenygon/NP)
# (CHUNK Mrs./NP Lenygon's/NP$ committee/NN associates/NNS)
# (CHUNK Mrs./NP Allen/NP Lehman/NP McCluskey/NP)
# (CHUNK Brevard/NP-TL Music/NN-TL Center/NN-TL summer/NN camp/NN)
# (CHUNK conductor/NN James/NP Christian/NP Pfohl/NP)
# (CHUNK Joseph/NP P./NP Kennedy/NP School/NN-TL)
# (CHUNK C./NP Melvin/NP Sharpe/NP Health/NN-TL School/NN-TL)
# (CHUNK Transylvania/NP-TL Symphony/NN-TL Conductor/NN-TL Pfohl/NP)
# (CHUNK Gallery/NN-TL Director/NN-TL John/NP Walker/NP)
# (CHUNK community/NN case/NN work/NN service/NN)
# (CHUNK Soviet/NN-TL Premier/NN-TL Nikita/NP S./NP Khrushchev/NP)
# (CHUNK Ambassador/NN-TL Llewellyn/NP E./NP Thompson/NP)
# (CHUNK Sen./NN-TL John/NP L./NP McClellan/NP)
# (CHUNK Boston/NP house/NN carpenters'/NNS$ strike/NN)
# (CHUNK State/NN-TL John/NP Foster/NP Dulles/NP)
# (CHUNK Congressman/NN-TL Adam/NP Clayton/NP Powell/NP)
# (CHUNK Clint/NP Anderson's/NP$ three-fifths/NNS modification/NN)
# (CHUNK
#   Tournament/NN-TL
#   Chairman/NN-TL
#   Clifford/NP
#   Roberts'/NP$
#   clubhouse/NN
#   apartment/NN)
# (CHUNK Open/NN-TL Champion/NN-TL Kel/NP Nagle/NP)
# (CHUNK Baseball/NN commissioner/NN Ford/NP Frick/NP)
# (CHUNK President-elect/NN-TL John/NP F./NP Kennedy's/NP$ Convair/NP)
# (CHUNK Inauguration/NN-TL Eve/NN-TL entertainment/NN gala/NN)
# (CHUNK Hollywood/NP Couturier/NP Don/NP Loper/NP)
# (CHUNK General/NN-TL David/NP M./NP Shoup/NP)
# (CHUNK Oregon/NP Democrat/NP Maurine/NP Neuberger/NP)
# (CHUNK Democrat/NP Theodore/NP Francis/NP Greene/NP)
# (CHUNK Decathlon/NN-TL Man/NN-TL Rafer/NP Johnson/NP)
# (CHUNK A.A.U.'s/NP$ James/NP E./NP Sullivan/NP)
# (CHUNK Ace/NN-TL Driver/NN-TL Stirling/NP Moss/NP)
# (CHUNK Dr./NN-TL Albert/NP C./NP Barnes/NP)
# (CHUNK District/NN-TL Judge/NN-TL William/NP A./NP Bootle/NP)
# (CHUNK Detroit's/NP$ Wayne/NP-TL State/NN-TL University/NN-TL)
# (CHUNK
#   Chicago's/NP$-TL
#   Chancellor/NN-TL
#   Lawrence/NP
#   A./NP
#   Kimpton/NP)
# (CHUNK Harvard's/NP$ Dean/NN-TL McGeorge/NP Bundy/NP)
# (CHUNK Trustee/NN-TL Chairman/NN-TL Glen/NP A./NP Lloyd/NP)
# (CHUNK Geneticist/NN-TL George/NP Wells/NP Beadle/NP)
# (CHUNK Idealist/NN-TL Robert/NP Maynard/NP Hutchins/NP)
# (CHUNK President/NN-TL John/NP F./NP Kennedy/NP)
# (CHUNK U.N./NP-TL Ambassador/NN-TL Adlai/NP Stevenson/NP)
# (CHUNK Defense/NN-TL Minister/NN-TL Bahi/NP Ladgham/NP)
# (CHUNK Capt./NN-TL Byron/NP D./NP Rickards/NP)
# (CHUNK
#   U.S./NP-TL
#   Immigration/NN-TL
#   Service/NN-TL
#   Border/NN-TL
#   Patrol/NN-TL)
# (CHUNK FBI/NN agent/NN Francis/NP Crosby/NP)
# (CHUNK U./NP-TL S./NP-TL Treasury/NN-TL bonds/NNS)
# (CHUNK Illinois/NP-TL State/NN-TL Toll/NN-TL Highway/NN-TL)
# (CHUNK Commerce/NN-TL Secretary/NN-TL Luther/NP Hodges/NP)
# (CHUNK college/NN age/NN limit/NN law/NN)
# (CHUNK road/NN maintenance/NN bond/NN issue/NN)
# (CHUNK Georgia/NP Tech/NP research/NN staff/NN)
# (CHUNK Chairman/NN-TL Charles/NP O./NP Emmerich/NP)
# (CHUNK
#   Georgia/NP-TL
#   Power/NN-TL
#   Company's/NN$-TL
#   record/NN
#   construction/NN
#   budget/NN)
# (CHUNK Dictator/NN-TL Marcos/NP Perez/NP Jimenez/NP)
# (CHUNK Mayor/NN-TL Robert/NP F./NP Wagner/NP)
# (CHUNK State/NN-TL Controller/NN-TL Arthur/NP Levitt/NP)
# (CHUNK press/NN conference/NN Mr./NP Kennedy/NP)
# (CHUNK Viet/NP Minh/NP guerrilla/NN fighters/NNS)
# (CHUNK Dade/NP-TL County/NN-TL Port/NN-TL Authority/NN-TL)
# (CHUNK Chicago/NP-TL Tribune/NN-TL News/NN-TL Service/NN-TL)
# (CHUNK world/NN trade/NN trip/NN people/NNS)
# (CHUNK Stone/NN-TL Harbor/NN-TL bird/NN sanctuary/NN)
# (CHUNK Stone/NN-TL Harbor/NN-TL bird/NN sanctuary's/NN$ allies/NNS)
# (CHUNK
#   glamor/NN
#   President/NN-TL
#   Kennedy's/NP$
#   Peace/NN-TL
#   Corps/NN-TL)
# (CHUNK Dean/NN-TL John/NP W./NP Schwada/NP)
# (CHUNK Herrin-Murphysboro-West/NP Frankfort/NP labor/NN market/NN)
# (CHUNK Gen./NN-TL J./NP M./NP Swing/NP)
# (CHUNK Gen./NN-TL Maxwell/NP Taylor's/NP$ statement/NN)
# (CHUNK Viet/NP-TL Nam's/NP$-TL rice/NN surplus/NN)
# (CHUNK President/NN-TL Ngo/NP Dinh/NP Diem/NN-TL)
# (CHUNK President/NN-TL Lyndon/NP B./NP Johnson's/NP$ visit/NN)
# (CHUNK Gov./NN-TL John/NP M./NP Dalton/NP)
# (CHUNK I./NP A./NP P./NP A./NP)
# (CHUNK I./NP A./NP P./NP A./NP)
# (CHUNK Soviet/NN-TL Communist/NN-TL Party/NN-TL Congress/NP-TL)
# (CHUNK Premier/NN-TL Khrushchev's/NP$ Berlin/NP policy/NN)
# (CHUNK Dr./NN-TL James/NP B./NP Conant/NP)
# (CHUNK Commission/NN-TL Chairman/NN-TL Charles/NP O./NP Emmerich/NP)
# (CHUNK Mr./NP Podger's/NP$ hammock/NN purchase/NN)
# (CHUNK Thomas/NP B./NP Carvey/NP Jr./NP)
# (CHUNK Hughes/NP-TL Aircraft's/NN$-TL moon/NN missiles/NNS)
# (CHUNK State/NN-TL Sen./NN-TL Dick/NP Richards/NP)
# (CHUNK Soviet/NN-TL news/NN agency/NN TASS/NN)
# (CHUNK U.S./NP-TL President's/NN$-TL disarmament/NN adviser/NN)
# (CHUNK Cyrus/NP H./NP K./NP Curtis/NP)
# (CHUNK Gen./NN-TL Chung/NP Hee/NP Park/NP)
# (CHUNK
#   addition/NN
#   Rep./NN-TL
#   Frelinghuysen's/NP$
#   brother/NN
#   Harry/NP)
# (CHUNK Rev./NP Dr./NN-TL Luther/NP A./NP Weigle/NP)
# (CHUNK Yale/NP-TL University/NN-TL Divinity/NN-TL School/NN-TL)
# (CHUNK Prof./NN-TL C./NP H./NP Dodd/NP)
# (CHUNK lecturer/NN Roy/NP P./NP Basler/NP)
# (CHUNK county/NN unit/NN system/NN stands/NNS)
# (CHUNK
#   Lt./NN-TL
#   Gov./NN-TL
#   Garland/NP
#   Byrd's/NP$
#   Senate/NN-TL
#   Committee/NN-TL)
# (CHUNK State/NN-TL Party/NN-TL Chairman/NN-TL James/NP Gray/NP)
# (CHUNK Rhode/NP-TL Island/NN-TL Development/NN-TL Council/NN-TL)
# (CHUNK Mr./NP Irving/NP J./NP Fain/NP)
# (CHUNK Providence/NP Sunday/NR Journal/NN-TL article/NN)
# (CHUNK Defense/NN-TL Secretary/NN-TL Robert/NP S./NP McNamara/NP)
# (CHUNK Jan/NP Masaryk/NP award/NN August/NP)
# (CHUNK General/NN-TL Motors/NNS-TL stock/NN holdings/NNS)
# (CHUNK Congressman/NN-TL Wilbur/NP D./NP Mills/NP)
# (CHUNK Mayflower/NP-TL Hotel/NN-TL cypress/NN swamp/NN)
# (CHUNK camel/NN driver/NN Bashir/NP Ahmad/NP)
# (CHUNK
#   Stans/NP-HL
#   column/NN-HL
#   business/NN-HL
#   scandal/NN-HL
#   views/NNS-HL)
# (CHUNK R./NP H./NP S./NP Crossman/NP)
# (CHUNK Dr./NN-TL Glenn/NP T./NP Seaborg/NP)
# (CHUNK John/NP A./NP McCone's/NP$ letter/NN)
# (CHUNK Dr./NN-TL William/NP V./NP O'Brien/NP)
# (CHUNK J./NP B./NP Speed/NP Museum/NN-TL)
# (CHUNK Saturday/NR night/NN TV/NN movie/NN)
# (CHUNK York/NP-TL Times'/NNS$-TL magazine/NN section/NN)
# (CHUNK U.S./NP pilot/NN Alan/NP Lawrence/NP Pope/NP)
# (CHUNK Eleanor/NP-TL Roosevelt/NP-TL Tractor/NN-TL Committee/NN-TL)
# (CHUNK F./NP L./NP Lucas's/NP$ article/NN)
# (CHUNK Los/NP-TL Angeles/NP-TL Times/NNS-TL version/NN)
# (CHUNK
#   James/NP
#   Webb/NP
#   Young's/NP$
#   Madison/NP-TL
#   Avenue/NN-TL
#   column/NN)
# (CHUNK book/NN C./NP P./NP Snow/NP)
# (CHUNK Sir/NP Charles/NP Snow's/NP$ Godkin/NP-TL Lectures/NNS-TL)
# (CHUNK time/NN John/NP Crosby's/NP$ TV/NN series/NN)
# (CHUNK month/NN Edward/NP R./NP Murrow/NP)
# (CHUNK Field/NN-TL Marshal/NN-TL Viscount/NP Slim/NP)
# (CHUNK Republican/NP-TL Party/NN-TL district/NN chieftain/NN)
# (CHUNK Paula/NP Prentiss'/NP$ comedy/NN performance/NN)
# (CHUNK colleague/NN George/NP Herbert/NP Palmer/NP)
# (CHUNK Vanguard/NN-TL album/NN Madrigal/NN-TL Masterpieces/NNS-TL)
# (CHUNK
#   Helen/NP-TL
#   Tamiris-Daniel/NP-TL
#   Nagrin/NP-TL
#   Dance/NN-TL
#   Company/NN-TL)
# (CHUNK R./NP C./NP A./NP Victor/NN-TL LOC/NN)
# (CHUNK R./NP C./NP A./NP Victor/NN-TL LOC/NN)
# (CHUNK night's/NN$ Lewisohn/NP-TL Stadium/NN-TL concert/NN)
# (CHUNK Paul/NP Creston's/NP$ Dance/NN-TL Overture/NN-TL)
# (CHUNK Leningrad/NP-TL State/NN-TL Kirov/NP-TL Ballet/NN-TL)
# (CHUNK Senator/NN-TL Hubert/NP H./NP Humphrey/NP)
# (CHUNK Senator/NN-TL Lyndon/NP B./NP Johnson/NP)
# (CHUNK total/NN U.S./NP Negro/NP population/NN)
# (CHUNK Dr./NN-TL W./NP B./NP Bonnor/NP)
# (CHUNK Dr./NN-TL R./NP A./NP Lyttleton/NP)
# (CHUNK Dr./NN-TL G./NP J./NP Whitrow/NP)
# (CHUNK Fall/NN-TL Color/NN-TL Week/NN-TL Sept./NP)
# (CHUNK Pierre/NP S./NP Du/NP Pont/NP)
# (CHUNK Mille/NP Miglia/NP automobile/NN race/NN)
# (CHUNK fact/NN Mr./NP Remarque's/NP$ intention/NN)
# (CHUNK Field/NN-TL Marshal/NN-TL Montgomery's/NP$ belief/NN)
# (CHUNK Minnesota's/NP$-TL Physiologist/NN-TL Ancel/NP Keys/NP)
# (CHUNK York's/NP$-TL Dr./NN-TL Norman/NP Jolliffe/NP)
# (CHUNK brain's/NN$ total/NN solid/NN weight/NN)
# (CHUNK California's/NP$-TL Dr./NN-TL Laurance/NP Kinsell/NP)
# (CHUNK Dr./NN-TL A./NP E./NP Ahrens/NP)
# (CHUNK Dr./NN-TL N./NP L./NP Frothingham/NP)
# (CHUNK Dr./NN-TL George/NP W./NP Crane/NP)
# (CHUNK Han/NP-TL Emperor/NN-TL Wu/NP Ti/NP)
# (CHUNK Day/NN-TL Adventists'/NPS$ world/NN radio/NN program/NN)
# (CHUNK President/NN-TL Mohammad/NP Ayub/NP Khan/NP)
# (CHUNK country/NN Gustave/NP Weigel's/NP$ delineation/NN)
# (CHUNK Student/NN-TL Volunteer/NN-TL Movement/NN-TL speakers/NNS)
# (CHUNK Quaker/NP poet/NN John/NP Greenleaf/NP Whittier/NP)
# (CHUNK
#   Harriet/NP
#   Beecher/NP
#   Stowe's/NP$
#   Uncle/NP-TL
#   Tom's/NP$-TL
#   Cabin/NN-TL)
# (CHUNK Diario/NP De/NP La/NP Marina/NP)
# (CHUNK master/NN Montreal/NP bodybuilding/NN authority/NN)
# (CHUNK Weider/NP Push-Pull/NP Super-Set/NP technique/NN)
# (CHUNK Dr./NN-TL Wilson/NP C./NP Grant/NP)
# (CHUNK Westminster/NP-TL KC/NN-TL Dog/NN-TL Show/NN-TL)
# (CHUNK Mrs./NP-HL William/NP-HL H./NP-HL Long/NP-HL)
# (CHUNK Mrs./NP William/NP H./NP Long/NP)
# (CHUNK Thoroughbred/NP-TL Racing/NN-TL Ass'n/NN-TL Scholarship/NN-TL)
# (CHUNK year/NN Anne/NP Hone/NP Rogers/NP)
# (CHUNK Handlers'/NNS$-TL Ass'ns'/NNS$-TL Leonard/NP-TL Brumby/NP-TL)
# (CHUNK U.S./NP-TL Coast/NN-TL Guard/NN-TL cooperation/NN)
# (CHUNK U.S./NP-TL Coast/NN-TL Guard/NN-TL Auxiliary/NN-TL)
# (CHUNK Af/NN roundhead/NN steel/NN screws/NNS)
# (CHUNK Af/NN brass/NN bar/NN stock/NN 3-3/4''/NNS)
# (CHUNK grammar/NN school/NN arithmetic/NN classes/NNS)
# (CHUNK for/NN Engine/NN crankshaft/NN speed/NN)
# (CHUNK Faber/NP Hanover-Sally/NP Joe/NP Whippet/NP)
# (CHUNK Neil/NP Engle's/NP$ Miss/NP Phone/NP)
# (CHUNK Remington/NP Jet/NN-TL Magnum/NP-TL Center/NN-TL)
# (CHUNK slide-lock/NN side/NN safety/NN catch/NN)
# (CHUNK York/NP-TL J./NP Pierpont/NP Morgan/NP)
# (CHUNK Chicago's/NP$ Lake/NN-TL Shore/NN-TL Drive/NN-TL)
# (CHUNK
#   tablespoon/NN
#   Worcestershire/NP
#   sauce/NN
#   pineapple/NN-HL
#   chunks/NNS-HL)
# (CHUNK silicon/NN bronze/NN Stronghold/NN-TL nails/NNS)
# (CHUNK Glass/NN-TL Plastic/NN-TL Supply/NN-TL Co./NN-TL)
# (CHUNK Colonel/NN-TL Frederick/NP W./NP Lander/NP)
# (CHUNK Colonel/NN-TL Benjamin/NP F./NP Kelley's/NP$)
# (CHUNK Brigadier/NN-TL General/NN-TL William/NP E./NP)
# (CHUNK kitchen/NN range/NN exhaust/NN fan/NN)
# (CHUNK U./NP-TL S./NP-TL Forest/NN-TL Service/NN-TL)
# (CHUNK Ranger/NP-TL Fund/NN-TL purchase/NN awards/NNS)
# (CHUNK Laguna/NP-TL Beach/NN-TL Art/NN-TL Association/NN-TL)
# (CHUNK Ranger/NP-TL Fund/NN-TL Purchase/NN-TL Prize/NN-TL)
# (CHUNK Philadelphia/NP-TL Water/NN-TL Color/NN-TL Club/NN-TL)
# (CHUNK Drs./NNS-TL C./NP J./NP Martin/NP)
# (CHUNK Prof./NN-TL J./NP G./NP L./NP Manthey/NP)
# (CHUNK breed/NN registry/NN testing/NN programs/NNS)
# (CHUNK U./NP-TL S./NP-TL Rubber/NN-TL Company/NN-TL)
# (CHUNK OEP/NN director/NN Dr./NN-TL Julian/NP Smith/NP)
# (CHUNK Events/NNS-TL director/NN Jennings/NP Dennis/NP)
# (CHUNK Teen/NN-TL Hunter/NN-TL Club/NN-TL activities/NNS)
# (CHUNK W./NP R./NP G./NP Baker/NP)
# (CHUNK Staff/NN-HL engineer/NN-HL dept./NN-HL manager/NN-HL)
# (CHUNK Wall/NN-TL Street/NN-TL Journal/NN-TL survey/NN)
# (CHUNK Advance/NN-TL Neon/NN-TL Sign/NN-TL Co./NN-TL)
# (CHUNK Du/NP Pont's/NP$ Polychemicals/NNS-TL Dept./NN-TL)
# (CHUNK Advance/NN-TL Neon/NN-TL Sign/NN-TL Co./NN-TL)
# (CHUNK Lumber/NN-TL Dealers'/NNS$-TL Research/NN-TL Council/NN-TL)
# (CHUNK Lumber/NN-TL Dealers'/NNS$-TL Research/NN-TL Council/NN-TL)
# (CHUNK Type/NN-TL 6-B/NP floating-load/NN method/NN)
# (CHUNK Clay/NN-TL Products/NNS-TL Research/NN-TL Foundation/NN-TL)
# (CHUNK Alfa/NP Romeo/NP Giulietta/NP models/NNS)
# (CHUNK Charles/NP MacArthur-Helen/NP Hayes/NP saga/NN)
# (CHUNK Dr./NN-TL Henry/NP Lee/NP Smith/NP)
# (CHUNK President/NN-TL Franklin/NP Delano/NP Roosevelt/NP)
# (CHUNK Lt./NN-TL Howard/NP D./NP Beckstrom/NP)
# (CHUNK Lt./NN-TL Thomas/NP H./NP Richardson/NP)
# (CHUNK Capt./NN-TL A./NP B./NP Jenks/NP)
# (CHUNK Ensign/NN-TL Kay/NP K./NP Vesole/NP)
# (CHUNK Seaman/NN-TL 2/c/NP-TL Donald/NP L./NP Norton/NP)
# (CHUNK Seaman/NN-TL 1/c/NP-TL William/NP A./NP Rochford/NP)
# (CHUNK Seaman/NN-TL 1/c/NP-TL Stanley/NP Bishop/NP)
# (CHUNK Deck/NN-TL Cadet/NN-TL James/NP L./NP Cahill/NP)
# (CHUNK Capt./NN-TL Michael/NP A./NP Musmanno/NP)
# (CHUNK Dr./NN-TL H./NP V./NP Hilprecht/NP)
# (CHUNK
#   Post/NN-TL
#   Office/NN-TL
#   Department's/NN$-TL
#   Railway/NN-TL
#   Mail/NN-TL
#   Service/NN-TL)
# (CHUNK Burlington/NP aviator/NN John/NP J./NP Burns/NP)
# (CHUNK York/NP-TL State/NN-TL Guard/NN-TL flyers/NNS)
# (CHUNK
#   Emergency/NN-TL
#   Air/NN-TL
#   Mail/NN-TL
#   Star/NN-TL
#   Route/NN-TL
#   contract/NN)
# (CHUNK Cross/NN-TL Aide/NN-TL Reuben/NP Sleight/NP)
# (CHUNK Postmaster/NN-TL Charles/NP F./NP McKenna/NP)
# (CHUNK Star/NN-TL Route/NN-TL Air/NN-TL Mail/NN-TL)
# (CHUNK old-style/NN felt/NN farmer's/NN$ boots/NNS)
# (CHUNK U./NP-TL S./NP-TL Weather/NN-TL Station/NN-TL)
# (CHUNK Ground/NN-TL Control/NN-TL Approach/NN-TL systems/NNS)
# (CHUNK Dr./NN-TL Mary/NP Steichen/NP Calderone/NP)
# (CHUNK Dr./NN-TL Maurice/NP E./NP Linden/NP)
# (CHUNK District/NN-TL Attorney/NN-TL Anthony/NP Liebler/NP)
# (CHUNK York/NP-TL District/NN-TL Attorney's/NN$-TL office/NN)
# (CHUNK Dr./NN-TL William/NP W./NP McClellan/NP)
# (CHUNK Doctor/NN-TL Fraud's/NP$ cure-all/NN gadget/NN)
# (CHUNK Inspector/NN-TL David/NP H./NP Stephens/NP)
# (CHUNK day/NN Dick's/NP$ classmate/NN Jimmy/NP)
# (CHUNK Dr./NN-TL Allan/NP G./NP Brodie/NP)
# (CHUNK
#   parapsychology/NN
#   foundation's/NN$
#   long-range/NN
#   experiment/NN)
# (CHUNK Hudson's/NP$-TL Bay/NN-TL Company's/NN$-TL post/NN)
# (CHUNK Selkirk/NP Hudson's/NP$-TL Bay/NN-TL Company/NN-TL center/NN)
# (CHUNK Sergeant/NN-TL Edwin/NP H./NP Fay/NP)
# (CHUNK Private/NN-TL George/NP Gray/NP Hunter/NP)
# (CHUNK Private/NN-TL Jenkins/NP Lloyd/NP Jones/NP)
# (CHUNK Parson/NN-TL Weems's/NP$ George/NP Washington/NP)
# (CHUNK
#   Stephen/NP
#   Vincent/NP
#   Benet's/NP$
#   John/NP-TL
#   Brown's/NP$-TL
#   Body/NN-TL)
# (CHUNK Hawthorne/NP-TL Smoke/NN-TL Shop/NN-TL proceeds/NNS)
# (CHUNK Detective/NN-TL Sergeant/NN-TL John/NP J./NP Ryan/NP)
# (CHUNK Commander/NN-TL C./NP K./NP Green/NP)
# (CHUNK Lieutenant/NN-TL Colonel/NN-TL Melbourne/NP C./NP Chandler/NP)
# (CHUNK Colonel/NN-TL George/NP Armstrong/NP Custer/NP)
# (CHUNK St./NN-TL Patrick's/NP$-TL Day/NN-TL party/NN)
# (CHUNK Lieutenant/NN-TL Robert/NP M./NP Carroll/NP)
# (CHUNK Major/NN-TL Marcus/NP A./NP Reno/NP)
# (CHUNK Major/NN-TL General/NN-TL George/NP Armstrong/NP Custer/NP)
# (CHUNK Terry/NP De/NP La/NP Mesa/NP Allen/NP)
# (CHUNK Mr./NP J./NP J./NP A./NP Frans/NP)
# (CHUNK wasp/NN stings/NNS onion/NN juice/NN)
# (CHUNK
#   St./NN-TL
#   Martin's/NP$-TL
#   Parish/NN-TL
#   Police/NNS-TL
#   Jury/NN-TL)
# (CHUNK Harvard/NP dean/NN McGeorge/NP Bundy/NP)
# (CHUNK
#   Justice/NN-TL
#   Department's/NN$-TL
#   Information/NN-TL
#   Director/NN-TL)
# (CHUNK General/NN-TL James/NP Gavin's/NP$ paratroopers/NNS)
# (CHUNK capital's/NN$ Franklin/NP D./NP Roosevelt/NP Memorial/NN-TL)
# (CHUNK Henry/NP Francis/NP Du/NP Pont/NP)
# (CHUNK art/NN dealer/NN Georges/NP Wildenstein/NP)
# (CHUNK Mrs./NP Margaret/NP Thompson/NP Biddle/NP)
# (CHUNK Prexy/NP John/NP Sloan/NP Dickey/NP)
# (CHUNK Dr./NN-TL William/NP Jewett/NP Tucker/NP)
# (CHUNK Uncle/NN-TL John/NP Vinnicum/NP Morse/NP)
# (CHUNK Mrs./NP Harriet/NP A./NP Copp/NP)
# (CHUNK Miss/NP Celia/NP L./NP Brett/NP)
# (CHUNK Miss/NP Mary/NP Jane/NP Packard/NP)
# (CHUNK Brewers/NNS today/NR use/NN corn/NN)
# (CHUNK way/NN Charles/NP Arthur/NP Shires/NP)
# (CHUNK point/NN Charles/NP C./NP Hanch/NP)
# (CHUNK Via/NP-TL Di/NP-TL Santa/NP-TL Sabina/NP)
# (CHUNK Via/NP Di/NP S./NP Alessio/NP)
# (CHUNK Via/NP-TL Di/NP-TL Santa/NP-TL Prisca/NP-TL)
# (CHUNK Via/NP D./NP Teatro/NP Di/NP Marcello/NP)
# (CHUNK Via/NP Della/NP Tribuna/NP Di/NP Campitelli/NP)
# (CHUNK San/NP-TL Carlo/NP-TL Ai/NP-TL Catinari/NP-TL)
# (CHUNK Via/NP dell'/NP Arco/NP Del/NP Monte/NP)
# (CHUNK Via/NP Capo/NP Di/NP Ferro/NP)
# (CHUNK Via/NP Capo/NP Di/NP Ferro/NP)
# (CHUNK Sant'/NP-TL Andrea/NP-TL Della/NP-TL Valle/NP-TL)
# (CHUNK Via/NP-TL Di/NP-TL S./NP-TL Agnese/NP-TL)
# (CHUNK Santa/NP Maria/NP Della/NP Pace/NP)
# (CHUNK Representative/NN-TL John/NP J./NP Rooney/NP)
# (CHUNK Senator/NN-TL Joseph/NP McCarthy's/NP$ phrase/NN)
# (CHUNK Oregon/NP-TL State/NN-TL science/NN teachers/NNS)
# (CHUNK Masu's/NP$ home/NN economics/NN training/NN)
# (CHUNK Offutt/NP-TL Air/NN-TL Force/NN-TL Base/NN-TL)
# (CHUNK Col./NN-TL William/NP W./NP Wisman/NP)
# (CHUNK De/NP Falla's/NP$ La/NP Vida/NP Breve/NP)
# (CHUNK Accademia/NP Di/NP Santa/NP Cecilia/NP)
# (CHUNK Sir/NP Arthur/NP Conan/NP Doyle/NP)
# (CHUNK Boulevard/NP De/NP La/NP Madeleine/NP)
# (CHUNK Mr./NP Justice/NP Taney's/NP$ Dred/NP Scott/NP decision/NN)
# (CHUNK Sir/NP Arthur/NP Conan/NP Doyle's/NP$ Sherlock/NP Holmes/NP)
# (CHUNK Rex/NP Stout's/NP$ Nero/NP Wolfe/NP)
# (CHUNK Raymond/NP Chandler's/NP$ Philip/NP Marlowe/NP)
# (CHUNK Mickey/NP Spillane's/NP$ Mike/NP Hammer/NP)
# (CHUNK George/NP K./NP L./NP Morris/NP)
# (CHUNK Faulkner's/NP$ total/NN works/NNS today/NR)
# (CHUNK Tennessee/NP hillbilly/NN character/NN Sut/NP Lovingood/NP)
# (CHUNK Joseph/NP P./NP Lyford's/NP$ Introduction/NN-TL)
# (CHUNK point/NN Mrs./NP Frances/NP Cupply/NP)
# (CHUNK Senator/NN-TL George/NP William/NP Norris/NP)
# (CHUNK Edna/NP St./NP Vincent/NP Millay's/NP$)
# (CHUNK York/NP-TL Herald/NN-TL Tribune's/NN$-TL photographer/NN)
# (CHUNK Phi/NP Beta/NP Kappa/NP key/NN)
# (CHUNK Mary/NP Anne/NP Elizabeth/NP Magdalene/NP Steichen/NP)
# (CHUNK Paula's/NP$ Christmas/NP holiday/NN visit/NN)
# (CHUNK J./NP A./NP C./NP Robertson/NP)
# (CHUNK
#   has/NIL
#   made/NIL
#   about/NIL
#   his/NIL
#   pamphlet/NIL
#   on/NIL
#   Dunkirk/NIL
#   and/NIL
#   his/NIL
#   Crisis/NIL)
# (CHUNK
#   Then/NIL
#   he/NIL
#   launches/NIL
#   into/NIL
#   an/NIL
#   attack/NIL
#   on/NIL
#   the/NIL
#   Tory/NIL
#   ministers/NIL)
# (CHUNK whom/NIL he/NIL calls/NIL the/NIL)
# (CHUNK Greenwich/NP-TL Village/NN-TL fourth-flight/NN walk-up/NN)
# (CHUNK Negro/NP composer/NN Hall/NP Johnson/NP)
# (CHUNK sports/NNS writer/NN Arthur/NP Robinson/NP)
# (CHUNK Governor/NN-TL Alfred/NP E./NP Smith/NP)
# (CHUNK States/NNS-TL Senator/NN-TL Royal/NP S./NP Copeland/NP)
# (CHUNK City/NN editor/NN Victor/NP Watson/NP)
# (CHUNK Jack/NP Doyle's/NP$ pool/NN parlors/NNS)
# (CHUNK Dr./NN-TL Menas/NP S./NP Gregory/NP)
# (CHUNK Mrs./NP Frank/NP W./NP Stearns/NP)
# (CHUNK B./NP M./NP Spinley's/NP$ portrayal/NN)
# (CHUNK philosopher/NN Samuel/NP Alexander's/NP$ debt/NN)
# (CHUNK A./NP N./NP Whitehead's/NP$ understanding/NN)
# (CHUNK Mr./NP Hearst's/NP$ morning/NN American/NP)
# (CHUNK Hearst's/NP$ San/NP-TL Francisco/NP-TL Examiner/NN-TL)
# (CHUNK Judge/NN-TL Alton/NP B./NP Parker/NP)
# (CHUNK Indiana's/NP$ John/NP W./NP Kern/NP)
# (CHUNK San/NP-TL Francisco/NP-TL Examiner/NN-TL man/NN)
# (CHUNK Trevelyan's/NP$ Queen/NN-TL Anne/NP trilogy/NN)
# (CHUNK
#   I/NIL
#   had/NIL
#   made/NIL
#   many/NIL
#   friends/NIL
#   among/NIL
#   them/NIL)
# (CHUNK
#   taking/NIL
#   part/NIL
#   in/NIL
#   their/NIL
#   after-school/NIL
#   games/NIL
#   and/NIL
#   trying/NIL
#   desperately/NIL
#   to/NIL
#   translate/NIL
#   Grimm's/NIL
#   Fairy/NIL
#   Tales/NIL
#   into/NIL
#   an/NIL)
# (CHUNK World/NN-TL Citizen/NN-TL Jean/NP Babel/NP)
# (CHUNK Lieutenant/NN-TL Colonel/NN-TL James/NP P./NP Brownlow/NP)
# (CHUNK Secretary/NN-TL William/NP S./NP Fulton/NP)
# (CHUNK historian/NN Samuel/NP Greene/NP Arnold/NP)
# (CHUNK historian/NN Charles/NP Francis/NP Adams/NP)
# (CHUNK Dr./NN-TL R./NP F./NP Campbell/NP)
# (CHUNK Graham/NP-TL Memorial/NN-TL Building/NN-TL fund/NN)
# (CHUNK Malcolm/NP MacDonald's/NP$ Borneo/NP-TL People/NNS-TL)
# (CHUNK E./NP T./NP Leeds'/NP$ Archaeology/NN-TL)
# (CHUNK Staff/NN-TL Hugh/NP L./NP Scott/NP)
# (CHUNK Provost/NN-TL Marshal/NN-TL Enoch/NP Crowder/NP)
# (CHUNK Democrat/NP Stanley/NP H./NP Dent/NP)
# (CHUNK Floor/NN-TL Leader/NN-TL Claude/NP Kitchin/NP)
# (CHUNK Senator/NN-TL James/NP A./NP Reed/NP)
# (CHUNK minister/NN Harry/NP Emerson/NP Fosdick/NP)
# (CHUNK cousin/NN Sir/NP Fulke/NP Greville/NP)
# (CHUNK countriman/NN Mr./NP Wm./NP Shak./NP)
# (CHUNK Sr./NP Edw/NP Grevyles/NP$ minaces/NNS)
# (CHUNK tyme/NN Mr./NP Ryc'/NP Quyney/NP)
# (CHUNK Mark/NP Antony/NP De/NP Wolfe/NP Howe/NP)
# (CHUNK W./NP E./NP Burghardt/NP Du/NP Bois/NP)
# (CHUNK Bill/NP Brown's/NP$ Training/NN-TL Camp/NN-TL)
# (CHUNK Arthur/NP Clarke's/NP$ Childhood's/NN$-TL End/NN-TL)
# (CHUNK Kurt/NP Vonnegut's/NP$ Player/NN-TL Piano/NN-TL)
# (CHUNK San/NP Francisco/NP poetry/NN group/NN)
# (CHUNK York/NP-TL Times/NNS-TL Book/NN-TL Review/NN-TL)
# (CHUNK what-will-T./NIL S./NIL Eliot-or-Martin/NIL Buber-think/NIL)
# (CHUNK William/NP Lyon/NP Phelps/NP atmosphere/NN)
# (CHUNK Piazzo/NP Lauro/NP Di/NP Bosis/NP)
# (CHUNK SBA's/NN Management/NN-TL Counseling/NN-TL Program/NN-TL)
# (CHUNK property/NN sales/NNS assistance/NN program/NN)
# (CHUNK
#   even/NIL
#   years/NIL
#   before/NIL
#   construction/NIL
#   can/NIL
#   commence/NIL)
# (CHUNK
#   as/NIL
#   a/NIL
#   development/NIL
#   program/NIL
#   is/NIL
#   being/NIL
#   launched/NIL)
# (CHUNK
#   commitments/NIL
#   and/NIL
#   obligations/NIL
#   must/NIL
#   be/NIL
#   entered/NIL
#   into/NIL
#   in/NIL
#   a/NIL
#   given/NIL
#   year/NIL
#   which/NIL
#   may/NIL
#   exceed/NIL
#   by/NIL
#   twofold/NIL
#   or/NIL
#   threefold/NIL
#   the/NIL
#   expenditures/NIL
#   to/NIL
#   be/NIL
#   made/NIL
#   in/NIL
#   that/NIL
#   year/NIL)
# (CHUNK lesson/NN Sam/NP Rayburn's/NP$ career/NN)
# (CHUNK state/NN automobile/NN maintenance/NN unit/NN)
# (CHUNK Rhode/NP-TL-HL Island/NN-TL-HL property/NN-HL tax/NN-HL)
# (CHUNK
#   Rhode/NP-TL
#   Island/NN-TL
#   Tax/NN-TL
#   Officials/NNS-TL
#   Association/NN-TL)
# (CHUNK W./NP-TL R./NP-TL Cobb/NP-TL Company/NN-TL)
# (CHUNK R./NP I./NP Export/NN-TL Conference/NN-TL Committee/NN-TL)
# (CHUNK Kent/NP-TL County/NN-TL Water/NN-TL Authority/NN-TL)
# (CHUNK tax/NN collection/NN year/NN calendars/NNS)
# (CHUNK tax/NN collection/NN year/NN calendar/NN)
# (CHUNK tax/NN collection/NN year/NN calendar/NN)
# (CHUNK tax/NN collection/NN year/NN calendar/NN)
# (CHUNK tax/NN collection/NN year/NN calendars/NNS)
# (CHUNK
#   Rhode/NP-TL-HL
#   Island/NN-TL-HL
#   Heritage/NN-TL-HL
#   Week/NN-TL-HL
#   proclamation/NN-HL)
# (CHUNK Rhode/NP-TL Island/NN-TL Heritage/NN-TL Week/NN-TL)
# (CHUNK Rhode/NP-TL Island/NN-TL Heritage/NN-TL Week/NN-TL)
# (CHUNK
#   Miss/NP-TL
#   Rhode/NP-TL
#   Island/NN-TL
#   Pageant/NN-TL-HL
#   Week/NN-TL-HL
#   proclamation/NN-HL)
# (CHUNK Miss/NP-TL Rhode/NP-TL Island/NN-TL Pageant/NN-TL)
# (CHUNK Miss/NP Sally/NP May/NP Saabye/NP)
# (CHUNK Miss/NP-TL Rhode/NP-TL Island/NN-TL Pageant/NN-TL Week/NN-TL)
# (CHUNK
#   Rhode/NP-TL-HL
#   Island/NN-TL-HL
#   Week/NN-TL-HL
#   proclamation/NN-HL)
# (CHUNK John/NP A./NP Notte/NP Jr./NP)
# (CHUNK diphosphopyridine/NN nucleotide/NN synthesizine/NN enzyme/NN)
# (CHUNK Navy's/NN$-TL Hospital/NN-TL Corps/NN-TL Quarterly/NN-TL)
# (CHUNK Af/NN hydrogen/NN atom's/NN$ Af/NN)
# (CHUNK liquid/NN helium-4/NN vapor/NN pressures/NNS)
# (CHUNK liquid/NN helium/NN temperature/NN region/NN)
# (CHUNK Mr./NP W./NP A./NP Wildhack/NP)
# (CHUNK Dr./NN-TL C./NP M./NP Herzfeld/NP)
# (CHUNK Dr./NN-TL A./NP V./NP Astin/NP)
# (CHUNK Mr./NP Orvil/NP E./NP Dryfoos/NP)
# (CHUNK Mr./NP John/NP B./NP Oakes/NP)
# (CHUNK 40%/NN pivot/NN State/NN-TL share/NN)
# (CHUNK concrete/NN block/NN basement/NN shelter/NN)
# (CHUNK General/NN-TL Motors/NNS-TL vice/NN president/NN)
# (CHUNK Du/NP Pont's/NP$ General/NN-TL Motors/NNS-TL stock/NN)
# (CHUNK Du/NP Pont's/NP$ tax/NN basis/NN)
# (CHUNK Du/NP Pont's/NP$ General/NN-TL Motors/NNS-TL shares/NNS)
# (CHUNK Justice/NN-TL hearing/NN officer's/NN$ report/NN)
# (CHUNK Bible/NP-TL Student/NN-TL Servant/NN-TL positions/NNS)
# (CHUNK wildlife/NN habitat/NN management/NN proposals/NNS)
# (CHUNK blister/NN rust/NN control/NN work/NN)
# (CHUNK civilian/NN employee/NN health/NN program/NN)
# (CHUNK S./NP K./NP Patil/NP Excellency/NN-TL)
# (CHUNK food/NN reserve/NN storage/NN structures/NNS)
# (CHUNK 0.5-mv./m./NN 50-percent/NN time/NN skywave/NN contours/NNS)
# (CHUNK income/NN tax/NN return/NN Form/NN-TL)
# (CHUNK Dr./NN-TL James/NP Brown/NP Fisk/NP)
# (CHUNK Dr./NN-TL Gordon/NP N./NP Ray/NP)
# (CHUNK Dr./NN-TL James/NP F./NP Mathias/NP)
# (CHUNK Mr./NP J./NP Kellum/NP Smith/NP)
# (CHUNK Sir/NP Henry/NP Sumner/NP Maine/NP)
# (CHUNK Sharpe/NP-TL wire/NN gage/NN system/NN)
# (CHUNK Sharpe/NP-TL hand/NN screw/NN machine/NN)
# (CHUNK War/NN-TL period/NN Mr./NP Brown/NP)
# (CHUNK gear/NN making/NN equipment/NN field/NN)
# (CHUNK company's/NN$ precision/NN tool/NN business/NN)
# (CHUNK Mr./NP Oscar/NP J./NP Beale/NP)
# (CHUNK Sharpe/NP-TL machine/NN tool/NN line/NN)
# (CHUNK formed-tooth/NN gear/NN cutting/NN machines/NNS)
# (CHUNK U./NP S./NP income/NN tax/NN policy/NN)
# (CHUNK Patterson/NP-TL Moos/NP-TL Research/NN-TL Division/NN-TL)
# (CHUNK Patterson/NP-TL Moos/NP-TL Research/NN-TL Division/NN-TL)
# (CHUNK Midwest/NP-TL Conference/NN-TL eligibility/NN standards/NNS)
# (CHUNK
#   Interference/NN-TL
#   Control/NN-TL
#   Field/NN-TL
#   Service/NN-TL
#   Department/NN-TL)
# (CHUNK Interference/NN-TL Control/NN-TL Field/NN-TL Service/NN-TL)
# (CHUNK mass/NN flow/NN rate/NN Af/NN)
# (CHUNK Pyrometer/NN-TL Instrument/NN-TL Co./NN-TL Model/NN-TL)
# (CHUNK voltage/NN measurements/NNS pyrometer/NN readings/NNS)
# (CHUNK Gibbs/NP function/NN difference/NN Af/NN)
# (CHUNK spin/NN relaxation/NN time/NN Af/NN)
# (CHUNK nitrogen/NN gas/NN flow/NN method/NN)
# (CHUNK Van/NP der/NP Waal's/NP$ forces/NNS)
# (CHUNK gas/NN phase/NN exchange/NN reaction/NN)
# (CHUNK reagent/NN grade/NN carbon/NN tetrachloride/NN)
# (CHUNK mm./NN i.d./NN Pyrex/NP tubing/NN)
# (CHUNK mm./NN i.d./NN Pyrex/NP tubing/NN)
# (CHUNK uranyl/NN oxalate/NN actinometer/NN solution/NN)
# (CHUNK Beckman/NP model/NN DU/NN spectrophotometer/NN)
# (CHUNK Spinco/NP model/NN R/NN cell/NN)
# (CHUNK Whatman/NP 3MM/NN filter/NN paper/NN)
# (CHUNK Spinco/NP model/NN E/NN ultracentrifuge/NN)
# (CHUNK Spinco/NP model/NN L/NN ultracentrifuge/NN)
# (CHUNK Charles/NP C./NP Carpenter's/NP$ data/NNS)
# (CHUNK Alphonse/NP R./NP Hoge's/NP$ measurements/NNS)
# (CHUNK dog/NN lung/NN injection/NN studies/NNS)
# (CHUNK States/NNS-TL Pharmacopoeia/NN-TL reference/NN standard/NN)
# (CHUNK Serial/NN serum/NN potassium/NN levels/NNS)
# (CHUNK crown/NN gall/NN tissue/NN powder/NN)
# (CHUNK clover/NN stem/NN tissue/NN powder/NN)
# (CHUNK crown/NN gall/NN tumor/NN tissue/NN)
# (CHUNK crown/NN gall/NN tumor/NN tissue/NN)
# (CHUNK clover/NN crown/NN gall/NN tissue/NN powder/NN)
# (CHUNK perspective/NN De/NP Jonquieres/NP involution/NN)
# (CHUNK E./NP Van/NP De/NP Walle/NP)
# (CHUNK total/NN third-grade/NN school/NN population/NN)
# (CHUNK Mr./NP Alexander/NP H./NP Wheelan's/NP$)
# (CHUNK VA/NN home/NN loan/NN guaranty/NN program/NN)
# (CHUNK Industry/NN-HL product/NN-HL price/NN-HL policy/NN-HL)
# (CHUNK state/NN court/NN test/NN cases/NNS)
# (CHUNK Mr./NP Justice/NP Frankfurter's/NP$ opinions/NNS)
# (CHUNK Seaboard/NN-TL Air/NN-TL Line/NN-TL Railway/NN-TL)
# (CHUNK
#   Aerospace/NP-TL
#   Industries/NNS-TL
#   Association/NN-TL
#   members/NNS)
# (CHUNK IBM/NN punch/NN card/NN equipment/NN)
# (CHUNK state/NN school/NN board/NN action/NN)
# (CHUNK electric/NN utility/NN rate/NN cases/NNS)
# (CHUNK District/NN-TL Attorney/NN-TL M./NP W./NP Mills/NP)
# (CHUNK land/NN grant/NN company/NN officers/NNS)
# (CHUNK Dr./NN-TL I./NP P./NP George/NP)
# (CHUNK Manchester/NP-TL Depot/NN-TL Sewer/NN-TL Company/NN-TL)
# (CHUNK Manchester/NP-TL Village/NN-TL disposal/NN plant/NN)
# (CHUNK Rev./NP J./NP D./NP Wickham/NP)
# (CHUNK Samuel/NP F./NP B./NP Morse/NP)
# (CHUNK Canada/NP-TL Junction/NN-TL Telegraph/NN-TL Company/NN-TL)
# (CHUNK Peru/NP grocer/NN J./NP J./NP Hapgood/NP)
# (CHUNK Ekwanok/NP-TL Country/NN-TL Club/NN-TL tournaments/NNS)
# (CHUNK U./NP-TL S./NP-TL Amateur/NN-TL Golf/NN-TL tournament/NN)
# (CHUNK railroad/NN station/NN agent's/NN$ office/NN)
# (CHUNK Bennington/NP-TL County/NN-TL towns/NNS east/NR)
# (CHUNK Mrs./NP F./NP H./NP Briggs/NP)
# (CHUNK Vermont/NP-TL Marble/NN-TL Company/NN-TL system/NN)
# (CHUNK Reverend/NP George/NP T./NP Day/NP)
# (CHUNK William/NP H./NP H./NP Clements/NP)
# (CHUNK Rhode/NP-TL Island's/NN$-TL John/NP Brown/NP)
# (CHUNK U.S./NP-TL Steel's/NN$-TL Pittsburgh/NP works/NNS)
# (CHUNK hotelman's/NN$ downtown/NR unit/NN sales/NNS)
# (CHUNK land/NN economist/NN Homer/NP Hoyt/NP)
# (CHUNK San/NP Francisco's/NP$ Bay/NN-TL Bridge/NN-TL)
# (CHUNK Henry/NP Morgenthau's/NP$ cheap-money/NN policy/NN)
# (CHUNK architect/NN Charles/NP U./NP Walter/NP)
# (CHUNK George/NP Washington's/NP$ cherry/NN tree/NN)
# (CHUNK lb/NN BOD/day/1,000/NN cu/NN ft/NN aeration/NN capacity/NN)
# (CHUNK first-order/NN stress/NN relaxation/NN function/NN)
# (CHUNK C./NP A./NP J./NP Hoeve/NP)
# (CHUNK C./NP A./NP J./NP Hoeve/NP)
# (CHUNK C./NP A./NP J./NP Hoeve/NP)
# (CHUNK James/NP Dwight/NP Dana's/NP$ System/NN-TL)
# (CHUNK reactor/NN irradiation/NN loop/NN system/NN)
# (CHUNK Van/NP De/NP Graff/NP machines/NNS)
# (CHUNK Army/NN-TL Quartermaster/NN-TL Corps/NN-TL program/NN)
# (CHUNK
#   material/NN
#   (/NIL
#   B.t.u./sq./NIL
#   ft./NIL
#   of/NIL
#   material/hr./*0F./in./NIL
#   of/NIL
#   thickness/NIL
#   )/NIL)
# (CHUNK urethane/NN foam/NN sandwich/NN panels/NNS)
# (CHUNK 90-degrees-F/NNS (/NIL 29/NIL -/NIL 32-degrees-C/NIL )/NIL)
# (CHUNK 90-degrees-F/NNS (/NIL 32*0C./NIL )/NIL)
# (CHUNK 140-degrees-F/NNS (/NIL 38*0/NIL to/NIL 60*0C./NIL )/NIL)
# (CHUNK 275-degrees-F/NNS (/NIL 135*0C./NIL )/NIL)
# (CHUNK 160-degrees-F/NNS (/NIL 49*0/NIL -/NIL 71*&0C./NIL )/NIL)
# (CHUNK 105-degrees-F/NNS (/NIL 38/NIL -/NIL 43*0C./NIL )/NIL)
# (CHUNK 38/NIL -/NIL 43*0/NIL C./NIL )/NIL)
# (CHUNK 109-degrees-F/NNS (/NIL 38/NIL -/NIL 43*0C./NIL )/NIL)
# (CHUNK 109-degrees-F/NNS (/NIL 38/NIL -/NIL 43*0C/NIL )/NIL)
# (CHUNK electron/NN multiplication/NN image/NN intensifiers/NNS)
# (CHUNK double-stage/NN X-ray/NN-TL image/NN intensifier/NN)
# (CHUNK phosphor/NN conversion/NN efficiency/NN P/NN)
# (CHUNK end/NN reflection/NN losses/NNS R/NN)
# (CHUNK gyro/NN output/NN axis/NN Aj/NN)
# (CHUNK Wednesday/NR night/NN prayer/NN meeting/NN)
# (CHUNK Deacon/NN-TL Gordon's/NP$ cow/NN hole/NN)
# (CHUNK morning/NN TV/NN news/NN show/NN)
# (CHUNK Dr./NN-TL Breckenridge's/NP$ son/NN Robert/NP)
# (CHUNK Camden/NP-TL Cycly/NN-TL Company/NN-TL plant/NN)
# (CHUNK Miss/NP Ada's/NP$ alfresco/NN party/NN)
# (CHUNK while/NN Miss/NP Ada's/NP$ flowers/NNS)
# (CHUNK Acey/NP Squire's/NP$ station/NN wagon/NN)
# (CHUNK Miami/NP-TL Beach/NN-TL license/NN plates/NNS)
# (CHUNK Mr./NP Ferrell/NP Hirey/NP Lindsay/NP)
# (CHUNK Captain/NN-TL O./NP T./NP Killpath/NP)
# (CHUNK Jerry/NP Burton's/NP$ home/NR number/NN)
# (CHUNK San/NP-TL Luis/NP-TL Rey/NP-TL Mission/NN-TL)
# (CHUNK San/NP-TL Clemente/NP-TL Island/NN-TL yesterday/NR)
# (CHUNK
#   Mr./NP
#   Booker/NP
#   T./NP
#   W./NP
#   Jones/NP
#   Food/NN-TL
#   Technician/NN-TL)
# (CHUNK Major/NN-TL Hiram/NP Munroe/NP Culver/NP)
# (CHUNK Deputy/NN-TL Marshal/NN-TL Luke/NP Harper/NP)
# (CHUNK Captain/NN-TL Clemens'/NP$ signal/NN shot/NN)
# (CHUNK time/NN War/NN-TL Ax/NN-TL hands/NNS)
# (CHUNK U./NP-TL S./NP-TL Navy/NN-TL type/NN aircraft/NN)
# (CHUNK Mrs./NP Major/NN-TL J./NP A./NP Roebuck/NP)
# (CHUNK Senor/NP X's/NP$ Ford/NP turtle/NN)
# (CHUNK Thor's/NP$ partner/NN Bill/NP Blake/NP)
# (CHUNK words/NNS Billy/NP Tilghman's/NP$ life/NN)
# (CHUNK Ma/NN-TL Murphy's/NP$ dance/NN hall/NN)
# (CHUNK Feathertop/NP Ernie/NP Cargill's/NP$ voice/NN)
# (CHUNK pine/NN board/NN tourist/NN courts/NNS)
# (CHUNK Riverside/NP dugout/NN Frankie/NP Ricco/NP)
# (CHUNK San/NP Juan/NP Capistrano/NP By-the-Sea/NP)
# (CHUNK murderer's/NN$ Hollywood/NP sport/NN shirts/NNS)
# (CHUNK Eddie/NP Cantor/NP comedy/NN hour/NN)
# (CHUNK General/NN-TL Burnside's/NP$ horse's/NN$ belly/NN)
# (CHUNK guest/NN contralto/NN Hattie/NP Sforzt/NP)
# (CHUNK Albany/NP-TL Leather/NN-TL Conduit/NN-TL Company/NN-TL)
# (CHUNK Major/NN-TL Pockmanster's/NP$ Delhi/NP-TL Regiment/NN-TL)
# (CHUNK existentialist/NN hot-shot/NN Jean-Paul/NP Sartre/NP)
# (CHUNK New-Waver/NP Fredrico/NP de/NP Mille/NP Rossilini's/NP$)

# %% [markdown]
# ## Chinking

# %% [markdown]
# Sometimes it is easier to define what we want to exclude from a chunk. We can define a chink to be a sequence of tokens that is not included in a chunk. In the following example, barked/VBD at/IN is a chink:

# %% [raw]
# [ the/DT little/JJ yellow/JJ dog/NN ] barked/VBD at/IN [ the/DT cat/NN ]

# %% [markdown]
# Chinking is the process of removing a sequence of tokens from a chunk. If the matching sequence of tokens spans an entire chunk, then the whole chunk is removed; if the sequence of tokens appears in the middle of the chunk, these tokens are removed, leaving two chunks where there was only one before. If the sequence is at the periphery of the chunk, these tokens are removed, and a smaller chunk remains. These three possibilities are illustrated in 7.3.

# %% [raw]
# Table 7.3:
#
# Three chinking rules applied to the same chunk
#
#             Entire chunk 	         Middle of a chunk 	        End of a chunk
# Input 	    [a/DT little/JJ dog/NN]  [a/DT little/JJ dog/NN] 	[a/DT little/JJ dog/NN]
# Operation 	Chink "DT JJ NN" 	     Chink "JJ" 	            Chink "NN"
# Pattern 	}DT JJ NN{ 	             }JJ{ 	                    }NN{
# Output 	    a/DT little/JJ dog/NN 	 [a/DT] little/JJ [dog/NN] 	[a/DT little/JJ] dog/NN

# %% [markdown]
# In 7.5, we put the entire sentence into a single chunk, then excise the chinks.

# %%
grammar = r"""
  NP:
    {<.*>+}          # Chunk everything
    }<VBD|IN>+{      # Chink sequences of VBD and IN
"""
sentence = [("the", "DT"), ("little", "JJ"), ("yellow", "JJ"), ("dog", "NN"), ("barked", "VBD"), ("at", "IN"),  ("the", "DT"), ("cat", "NN")]
cp = nltk.RegexpParser(grammar)
print (cp.parse(sentence))

# %% [markdown]
# ### Representing Chunks: Tags vs Trees

# %% [markdown]
# As befits their intermediate status between tagging and parsing (8), chunk structures can be represented using either tags or trees. The most widespread file representation uses IOB tags. In this scheme, each token is tagged with one of three special chunk tags, I (inside), O (outside), or B (begin). A token is tagged as B if it marks the beginning of a chunk. Subsequent tokens within the chunk are tagged I. All other tokens are tagged O. The B and I tags are suffixed with the chunk type, e.g. B-NP, I-NP. Of course, it is not necessary to specify a chunk type for tokens that appear outside a chunk, so these are just labeled O. An example of this scheme is shown in 7.6.

# %% [raw]
# We    saw   the   yellow  dog
# PRP   VBD   DT    JJ      NN
# B-NP  O     B-NP  I-NP    I-NP
#
# IOB tags have become the standard way to represent chunk structures in files, and we will also be using this format. Here is how the information in 7.6 would appear in a file:
#
# We PRP B-NP
# saw VBD O
# the DT B-NP
# little JJ I-NP
# yellow JJ I-NP
# dog NN I-NP
#
# Note to self: In files, it appears like we would have token then part of speech then IOB tag
#
# In this representation there is one token per line, each with its part-of-speech tag and chunk tag. This format permits us to represent more than one chunk type, so long as the chunks do not overlap. As we saw earlier, chunk structures can also be represented using trees. These have the benefit that each chunk is a constituent that can be manipulated directly. An example is shown in 7.7.

# %% [raw]
# Sometimes it is easier to define what we want to exclude from a chunk. We can define a chink to be a sequence of tokens that is not included in a chunk. In the following example, barked/VBD at/IN is a chink:
#
# [ the/DT little/JJ yellow/JJ dog/NN ] barked/VBD at/IN [ the/DT cat/NN ]
#
# Chinking is the process of removing a sequence of tokens from a chunk. If the matching sequence of tokens spans an entire chunk, then the whole chunk is removed; if the sequence of tokens appears in the middle of the chunk, these tokens are removed, leaving two chunks where there was only one before. If the sequence is at the periphery of the chunk, these tokens are removed, and a smaller chunk remains. These three possibilities are illustrated in 2.1.
#
# Table 2.1:
#
# Three chinking rules applied to the same chunk
#
# ... I skipped the rest of this section
# Skipped 2.6 as well

# %% [markdown]
# # My Own Code!

# %%
# Building Bob's special noun chunker...

# Here, we have a simple text string
sample_string = """
For any given question, it's likely that someone has written the answer down somewhere. The amount of natural language text that is available in electronic form is truly staggering, and is increasing every day. However, the complexity of natural language can make it very difficult to access the information in that text. The state of the art in NLP is still a long way from being able to build general-purpose representations of meaning from unrestricted text. If we instead focus our efforts on a limited set of questions or "entity relations," such as "where are different facilities located," or "who is employed by what company," we can make significant progress.
"""

# Now let's convert the text string into a format NLTK can understand
sentences = ie_preprocess(sample_string)

sentences[0]

# %%
# Inspired by http://web.media.mit.edu/~havasi/MAS.S60/chunk.pdf

grammar = r"""
NP:
{<DT>?<JJ>*<N.*>+} # chunk determiners, adjectives and nouns
{<NNP>+}           # chunk sequences of proper nouns
"""

cp = nltk.RegexpParser(grammar)
result = cp.parse(sentences[0])
print(result)

# %%
# Now... how can we parse result?

print (result[0])
print (result[1])
print (result[2])
print (result[3])
print (result[4])
print (result[5])
print (result[6])
print (result[7])
print (result[8])
print (result[9])
print (result[10])
print (result[11])
print (result[12])
print (result[13])
print (result[14])
print (result[15])

# %%
type(result)
# result is an NLTK tree

# %%
# this is a way to access the leaves...

ROOT = 'ROOT'
tree = result
def getNodes(parent):
    for node in parent:
        if type(node) is nltk.Tree:
            if node.label() == ROOT:
                print ("======== Sentence =========")
                print ("Sentence:", " ".join(node.leaves()))
            else:
                print ("Label:", node.label())
                print ("Leaves:", node.leaves())
            getNodes(node)
        else:
            print ("Word:", node)

getNodes(tree)

# %% [markdown]
# # 7.3 Developing and Evaluating Chunkers
#
# Now you have a taste of what chunking does, but we haven't explained how to evaluate chunkers. As usual, this requires a suitably annotated corpus. We begin by looking at the mechanics of converting IOB format into an NLTK tree, then at how this is done on a larger scale using a chunked corpus. We will see how to score the accuracy of a chunker relative to a corpus, then look some more data-driven ways to search for NP chunks. Our focus throughout will be on expanding the coverage of a chunker.

# %% [markdown]
# ## Reading IOB Format and the CoNLL 2000 Corpus
#
# Using the corpora module we can load Wall Street Journal text that has been tagged then chunked using the IOB notation. The chunk categories provided in this corpus are NP, VP and PP. As we have seen, each sentence is represented using multiple lines, as shown below:

# %% [raw]
# he PRP B-NP          (he is a pronoun with IOB: begin noun phrase)
# accepted VBD B-VP    (accepted is a verb with IOB: begin verb phrase)
# the DT B-NP          (the is a determiner with IOB: begin noun phrase)
# position NN I-NP     (position is a noun with IOB: inside noun phrase)
# ...

# %% [raw]
# A conversion function chunk.conllstr2tree() builds a tree representation from one of these multi-line strings. Moreover, it permits us to choose any subset of the three chunk types to use, here just for NP chunks:

# %%
text = '''
... he PRP B-NP
... accepted VBD B-VP
... the DT B-NP
... position NN I-NP
... of IN B-PP
... vice NN B-NP
... chairman NN I-NP
... of IN B-PP
... Carlyle NNP B-NP
... Group NNP I-NP
... , , O
... a DT B-NP
... merchant NN I-NP
... banking NN I-NP
... concern NN I-NP
... . . O
... '''
nltk.chunk.conllstr2tree(text, chunk_types=['NP']).draw()

# %% [markdown]
# We can use the NLTK corpus module to access a larger amount of chunked text. The CoNLL 2000 corpus contains 270k words of Wall Street Journal text, divided into "train" and "test" portions, annotated with part-of-speech tags and chunk tags in the IOB format. We can access the data using nltk.corpus.conll2000. Here is an example that reads the 100th sentence of the "train" portion of the corpus:

# %%
from nltk.corpus import conll2000
print (conll2000.chunked_sents('train.txt')[99])
# Out:
# (S
#   (PP Over/IN)
#   (NP a/DT cup/NN)
#   (PP of/IN)
#   (NP coffee/NN)
#   ,/,
#   (NP Mr./NNP Stone/NNP)
#   (VP told/VBD)
#   (NP his/PRP$ story/NN)
#   ./.)

# %% [markdown]
# As you can see, the CoNLL 2000 corpus contains three chunk types: NP chunks, which we have already seen; VP chunks such as has already delivered; and PP chunks such as because of. Since we are only interested in the NP chunks right now, we can use the chunk_types argument to select them:

# %%
print (conll2000.chunked_sents('train.txt', chunk_types=['NP'])[99])

# %% [markdown]
# ## Simple Evaluation and Baselines
#
# Now that we can access a chunked corpus, we can evaluate chunkers. We start off by establishing a baseline for the trivial chunk parser cp that creates no chunks:

# %%
from nltk.corpus import conll2000 # import chunked corpus
cp = nltk.RegexpParser("") # parser chunks nothing
test_sents = conll2000.chunked_sents('test.txt', chunk_types=['NP']) # test dummy parser against true NP chunks
print (cp.evaluate(test_sents))

# %% [markdown]
# The IOB tag accuracy indicates that more than a third of the words are tagged with O, i.e. not in an NP chunk. However, since our tagger did not find any chunks, its precision, recall, and f-measure are all zero. Now let's try a naive regular expression chunker that looks for tags beginning with letters that are characteristic of noun phrase tags (e.g. CD, DT, and JJ).

# %%
grammar = r"NP: {<[CDJNP].*>+}" # don't understand this regex
cp = nltk.RegexpParser(grammar)
print (cp.evaluate(test_sents))

# %% [markdown]
# As you can see, this approach achieves decent results. However, we can improve on it by adopting a more data-driven approach, where we use the training corpus to find the chunk tag (I, O, or B) that is most likely for each part-of-speech tag. In other words, we can build a chunker using a unigram tagger (5.4). But rather than trying to determine the correct part-of-speech tag for each word, we are trying to determine the correct chunk tag, given each word's part-of-speech tag.
#
# In 7.8, we define the UnigramChunker class, which uses a unigram tagger to label sentences with chunk tags. Most of the code in this class is simply used to convert back and forth between the chunk tree representation used by NLTK's ChunkParserI interface, and the IOB representation used by the embedded tagger. The class defines two methods: a constructor [1] which is called when we build a new UnigramChunker; and the parse method [3] which is used to chunk new sentences.

# %%
class UnigramChunker(nltk.ChunkParserI):
    def __init__(self, train_sents): # [1]
        train_data = [[(t,c) for w,t,c in nltk.chunk.tree2conlltags(sent)]
                      for sent in train_sents]
        self.tagger = nltk.UnigramTagger(train_data) # [2]

    def parse(self, sentence): # [3]
        pos_tags = [pos for (word,pos) in sentence]
        tagged_pos_tags = self.tagger.tag(pos_tags)
        chunktags = [chunktag for (pos, chunktag) in tagged_pos_tags]
        conlltags = [(word, pos, chunktag) for ((word,pos),chunktag)
                     in zip(sentence, chunktags)]
        return nltk.chunk.conlltags2tree(conlltags)

# %% [markdown]
# The constructor [1] expects a list of training sentences, which will be in the form of chunk trees. It first converts training data to a form that suitable for training the tagger, using tree2conlltags to map each chunk tree to a list of word,tag,chunk triples. It then uses that converted training data to train a unigram tagger, and stores it in self.tagger for later use.
#
# The parse method [3] takes a tagged sentence as its input, and begins by extracting the part-of-speech tags from that sentence. It then tags the part-of-speech tags with IOB chunk tags, using the tagger self.tagger that was trained in the constructor. Next, it extracts the chunk tags, and combines them with the original sentence, to yield conlltags. Finally, it uses conlltags2tree to convert the result back into a chunk tree.
#
# Now that we have UnigramChunker, we can train it using the CoNLL 2000 corpus, and test its resulting performance:

# %%
test_sents = conll2000.chunked_sents('test.txt', chunk_types=['NP'])
train_sents = conll2000.chunked_sents('train.txt', chunk_types=['NP'])
unigram_chunker = UnigramChunker(train_sents)
print (unigram_chunker.evaluate(test_sents))

# %% [markdown]
# This chunker does reasonably well, achieving an overall f-measure score of 83%. Let's take a look at what it's learned, by using its unigram tagger to assign a tag to each of the part-of-speech tags that appear in the corpus:

# %%
postags = sorted(set(pos for sent in train_sents
...                      for (word,pos) in sent.leaves()))
print (unigram_chunker.tagger.tag(postags))

# %% [markdown]
# It has discovered that most punctuation marks occur outside of NP chunks, with the exception of # and $, both of which are used as currency markers. It has also found that determiners (DT) and possessives (PRP$ and WP$) occur at the beginnings of NP chunks, while noun types (NN, NNP, NNPS, NNS) mostly occur inside of NP chunks.
#
# Having built a unigram chunker, it is quite easy to build a bigram chunker: we simply change the class name to BigramChunker, and modify line [2] in 7.8 to construct a BigramTagger rather than a UnigramTagger. The resulting chunker has slightly higher performance than the unigram chunker:

# %%
class BigramChunker(nltk.ChunkParserI):
    def __init__(self, train_sents): #[1]
        train_data = [[(t,c) for w,t,c in nltk.chunk.tree2conlltags(sent)]
                      for sent in train_sents]
        self.tagger = nltk.BigramTagger(train_data) #[2]

    def parse(self, sentence):
        pos_tags = [pos for (word,pos) in sentence]
        tagged_pos_tags = self.tagger.tag(pos_tags)
        chunktags = [chunktag for (pos, chunktag) in tagged_pos_tags]
        conlltags = [(word, pos, chunktag) for ((word,pos),chunktag)
                     in zip(sentence, chunktags)]
        return nltk.chunk.conlltags2tree(conlltags)

bigram_chunker = BigramChunker(train_sents)
print (bigram_chunker.evaluate(test_sents))

# %% [markdown]
# ### Training Classifier-Based Chunkers

# %% [markdown]
# Both the regular-expression based chunkers and the n-gram chunkers decide what chunks to create entirely based on part-of-speech tags. However, sometimes part-of-speech tags are insufficient to determine how a sentence should be chunked. For example, consider the following two statements:
#
# (3)
#
# a.		Joey/NN sold/VBD the/DT farmer/NN rice/NN ./.
#
# b.		Nick/NN broke/VBD my/DT computer/NN monitor/NN ./.
#
# These two sentences have the same part-of-speech tags, yet they are chunked differently. In the first sentence, the farmer and rice are separate chunks, while the corresponding material in the second sentence, the computer monitor, is a single chunk. Clearly, we need to make use of information about the content of the words, in addition to just their part-of-speech tags, if we wish to maximize chunking performance.
#
# One way that we can incorporate information about the content of words is to use a classifier-based tagger to chunk the sentence. Like the n-gram chunker considered in the previous section, this classifier-based chunker will work by assigning IOB tags to the words in a sentence, and then converting those tags to chunks. For the classifier-based tagger itself, we will use the same approach that we used in 6.1 to build a part-of-speech tagger.
#
# The basic code for the classifier-based NP chunker is shown in 7.9. It consists of two classes. The first class [1] is almost identical to the ConsecutivePosTagger class from 6.5. The only two differences are that it calls a different feature extractor [2] and that it uses a MaxentClassifier rather than a NaiveBayesClassifier [3]. The second class [4] is basically a wrapper around the tagger class that turns it into a chunker. During training, this second class maps the chunk trees in the training corpus into tag sequences; in the parse() method, it converts the tag sequence provided by the tagger back into a chunk tree.

# %%
class ConsecutiveNPChunkTagger(nltk.TaggerI):
    def __init__(self, train_sents):
        train_set = []
        for tagged_sent in train_sents:
            untagged_sent = nltk.tag.untag(tagged_sent)
            history = []
            for i, (word, tag) in enumerate(tagged_sent):
                featureset = npchunk_features(untagged_sent, i, history)
                train_set.append( (featureset, tag) )
                history.append(tag)
        self.classifier = nltk.MaxentClassifier.train(train_set, algorithm='megam', trace=0)

    def tag(self, sentence):
        history = []
        for i, word in enumerate(sentence):
            featureset = npchunk_features(sentence, i, history)
            tag = self.classifier.classify(featureset)
            history.append(tag)
        return zip(sentence, history)

class ConsecutiveNPChunker(nltk.ChunkParserI):
    def __init__(self, train_sents):
        tagged_sents = [[((w,t),c) for (w,t,c) in
                         nltk.chunk.tree2conlltags(sent)]
                        for sent in train_sents]
        self.tagger = ConsecutiveNPChunkTagger(tagged_sents)

    def parse(self, sentence):
        tagged_sents = self.tagger.tag(sentence)
        conlltags = [(w,t,c) for ((w,t),c) in tagged_sents]
        return nltk.chunk.conlltags2tree(conlltags)

# %% [markdown]
# The only piece left to fill in is the feature extractor. We begin by defining a simple feature extractor which just provides the part-of-speech tag of the current token. Using this feature extractor, our classifier-based chunker is very similar to the unigram chunker, as is reflected in its performance:

# %%
def npchunk_features(sentence, i, history):
    word, pos = sentence[i]
    return {"pos": pos}
chunker = ConsecutiveNPChunker(train_sents)
print (chunker.evaluate(test_sents))

# %% [markdown]
# Skipped the rest of Section 7.3, as I am not clear the value added in debugging megam file to work with this. To get started for my prototype, just use off the shelf chunkers and work on the relation extraction.

# %% [markdown]
# # 7.4   Recursion in Linguistic Structure
#
# ## Building Nested Structure with Cascaded Chunkers
#
# So far, our chunk structures have been relatively flat. Trees consist of tagged tokens, optionally grouped under a chunk node such as NP. However, it is possible to build chunk structures of arbitrary depth, simply by creating a multi-stage chunk grammar containing recursive rules. 7.10 has patterns for noun phrases, prepositional phrases, verb phrases, and sentences. This is a four-stage chunk grammar, and can be used to create structures having a depth of at most four.

# %%
grammar = r"""
  NP: {<DT|JJ|NN.*>+}          # Chunk sequences of DT, JJ, NN
  PP: {<IN><NP>}               # Chunk prepositions followed by NP
  VP: {<VB.*><NP|PP|CLAUSE>+$} # Chunk verbs and their arguments
  CLAUSE: {<NP><VP>}           # Chunk NP, VP
  """
cp = nltk.RegexpParser(grammar)
sentence = [("Mary", "NN"), ("saw", "VBD"), ("the", "DT"), ("cat", "NN"),
    ("sit", "VB"), ("on", "IN"), ("the", "DT"), ("mat", "NN")]

print (cp.parse(sentence))

# %% [markdown]
# Unfortunately this result misses the VP headed by saw. It has other shortcomings too. Let's see what happens when we apply this chunker to a sentence having deeper nesting. Notice that it fails to identify the VP chunk starting at [1].

# %%
sentence = [("John", "NNP"), ("thinks", "VBZ"), ("Mary", "NN"),
     ("saw", "VBD"), ("the", "DT"), ("cat", "NN"), ("sit", "VB"),
     ("on", "IN"), ("the", "DT"), ("mat", "NN")]
print (cp.parse(sentence))

# %% [markdown]
# The solution to these problems is to get the chunker to loop over its patterns: after trying all of them, it repeats the process. We add an optional second argument loop to specify the number of times the set of patterns should be run:

# %%
cp = nltk.RegexpParser(grammar, loop=2)
print (cp.parse(sentence))

# %% [markdown]
# Note
#
# This cascading process enables us to create deep structures. However, creating and debugging a cascade is difficult, and there comes a point where it is more effective to do full parsing (see 8). Also, the cascading process can only produce trees of fixed depth (no deeper than the number of stages in the cascade), and this is insufficient for complete syntactic analysis.

# %% [markdown]
# ### Trees
#
# A tree is a set of connected labeled nodes, each reachable by a unique path from a distinguished root node. Here's an example of a tree (note that they are standardly drawn upside-down)
#
# We use a 'family' metaphor to talk about the relationships of nodes in a tree: for example, S is the parent of VP; conversely VP is a child of S. Also, since NP and VP are both children of S, they are also siblings. For convenience, there is also a text format for specifying trees:

# %% [raw]
# (S
#    (NP Alice)
#    (VP
#       (V chased)
#       (NP
#          (Det the)
#          (N rabbit))))

# %% [markdown]
# Although we will focus on syntactic trees, trees can be used to encode any homogeneous hierarchical structure that spans a sequence of linguistic forms (e.g. morphological structure, discourse structure). In the general case, leaves and node values do not have to be strings.
#
# In NLTK, we create a tree by giving a node label and a list of children:

# %%
tree1 = nltk.Tree('NP', ['Alice'])
print (tree1)

# %%
tree2 = nltk.Tree('NP', ['the', 'rabbit'])
print (tree2)

# %% [markdown]
# We can incorporate these into successively larger trees as follows:

# %%
tree3 = nltk.Tree('VP', ['chased', tree2])
tree4 = nltk.Tree('S', [tree1, tree3])
print (tree4)

# %% [markdown]
# Here are some of the methods available for tree objects:

# %%
print (tree4[1])

# %%
print (tree4[0])

# %%
tree4[1].label() # use label() instead of .node

# %%
tree4.leaves()

# %%
tree4[1][1][1] # makes sense if you look at tree in NLTK book

# %% [markdown]
# The bracketed representation for complex trees can be difficult to read. In these cases, the draw method can be very useful. It opens a new window, containing a graphical representation of the tree. The tree display window allows you to zoom in and out, to collapse and expand subtrees, and to print the graphical representation to a postscript file (for inclusion in a document).

# %%
tree3.draw()

# %% [markdown]
# ### Tree Traversal
#
# It is standard to use a recursive function to traverse a tree. The listing in 7.11 demonstrates this.

# %%
def traverse(t):
    try:
        t.label()
    except AttributeError:
        print (t,)
    else:
        # Now we know that t.node is defined
        print ('(', t.label(),)
        for child in t:
            traverse(child)
        print (')',)
        
# note: I replaced t.node with t.label() for the function to work...

# %%
# t = nltk.Tree('(S (NP Alice) (VP chased (NP the rabbit)))')
traverse(tree4)
# not sure what happened with t. So I used tree4.

# %% [markdown]
# Note
#
# We have used a technique called duck typing to detect that t is a tree (i.e. t.node is defined).

# %% [markdown]
# # 7.5   Named Entity Recognition

# %% [markdown]
# At the start of this chapter, we briefly introduced named entities (NEs). Named entities are definite noun phrases that refer to specific types of individuals, such as organizations, persons, dates, and so on. 7.4 lists some of the more commonly used types of NEs. These should be self-explanatory, except for "Facility": human-made artifacts in the domains of architecture and civil engineering; and "GPE": geo-political entities such as city, state/province, and country.

# %% [raw]
# Table 7.4:
#
# Commonly Used Types of Named Entity
#
# NE Type 	  Examples
# ORGANIZATION  Georgia-Pacific Corp., WHO
# PERSON 	      Eddy Bonte, President Obama
# LOCATION 	  Murray River, Mount Everest
# DATE 	      June, 2008-06-29
# TIME 	      two fifty a m, 1:30 p.m.
# MONEY 	      175 million Canadian Dollars, GBP 10.40
# PERCENT 	  twenty pct, 18.75 %
# FACILITY 	  Washington Monument, Stonehenge
# GPE 	      South East Asia, Midlothian

# %% [markdown]
# The goal of a named entity recognition (NER) system is to identify all textual mentions of the named entities. This can be broken down into two sub-tasks: identifying the boundaries of the NE, and identifying its type. While named entity recognition is frequently a prelude to identifying relations in Information Extraction, it can also contribute to other tasks. For example, in Question Answering (QA), we try to improve the precision of Information Retrieval by recovering not whole pages, but just those parts which contain an answer to the user's question. Most QA systems take the documents returned by standard Information Retrieval, and then attempt to isolate the minimal text snippet in the document containing the answer. Now suppose the question was Who was the first President of the US?, and one of the documents that was retrieved contained the following passage:
#
# (5)		The Washington Monument is the most prominent structure in Washington, D.C. and one of the city's early attractions. It was built in honor of George Washington, who led the country to independence and then became its first President.
#
# Analysis of the question leads us to expect that an answer should be of the form X was the first President of the US, where X is not only a noun phrase, but also refers to a named entity of type PER. This should allow us to ignore the first sentence in the passage. While it contains two occurrences of Washington, named entity recognition should tell us that neither of them has the correct type.
#
# How do we go about identifying named entities? One option would be to look up each word in an appropriate list of names. For example, in the case of locations, we could use a gazetteer, or geographical dictionary, such as the Alexandria Gazetteer or the Getty Gazetteer. However, doing this blindly runs into problems, as shown in 7.12.
#
# Observe that the gazetteer has good coverage of locations in many countries, and incorrectly finds locations like Sanchez in the Dominican Republic and On in Vietnam. Of course we could omit such locations from the gazetteer, but then we won't be able to identify them when they do appear in a document.
#
# It gets even harder in the case of names for people or organizations. Any list of such names will probably have poor coverage. New organizations come into existence every day, so if we are trying to deal with contemporary newswire or blog entries, it is unlikely that we will be able to recognize many of the entities using gazetteer lookup.
#
# Another major source of difficulty is caused by the fact that many named entity terms are ambiguous. Thus May and North are likely to be parts of named entities for DATE and LOCATION, respectively, but could both be part of a PERSON; conversely Christian Dior looks like a PERSON but is more likely to be of type ORGANIZATION. A term like Yankee will be ordinary modifier in some contexts, but will be marked as an entity of type ORGANIZATION in the phrase Yankee infielders.
#
# Further challenges are posed by multi-word names like Stanford University, and by names that contain other names such as Cecil H. Green Library and Escondido Village Conference Service Center. In named entity recognition, therefore, we need to be able to identify the beginning and end of multi-token sequences.
#
# Named entity recognition is a task that is well-suited to the type of classifier-based approach that we saw for noun phrase chunking. In particular, we can build a tagger that labels each word in a sentence using the IOB format, where chunks are labeled by their appropriate type. Here is part of the CONLL 2002 (conll2002) Dutch training data:

# %% [raw]
# Eddy N B-PER
# Bonte N I-PER
# is V O
# woordvoerder N O
# van Prep O
# diezelfde Pron O
# Hogeschool N B-ORG
# . Punc O

# %% [markdown]
# In this representation, there is one token per line, each with its part-of-speech tag and its named entity tag. Based on this training corpus, we can construct a tagger that can be used to label new sentences; and use the nltk.chunk.conlltags2tree() function to convert the tag sequences into a chunk tree.
#
# NLTK provides a classifier that has already been trained to recognize named entities, accessed with the function nltk.ne_chunk(). If we set the parameter binary=True [1], then named entities are just tagged as NE; otherwise, the classifier adds category labels such as PERSON, ORGANIZATION, and GPE.

# %%
sent = nltk.corpus.treebank.tagged_sents()[22]
print (nltk.ne_chunk(sent, binary=True))

# %% [markdown]
# # 7.6   Relation Extraction
#
# Once named entities have been identified in a text, we then want to extract the relations that exist between them. As indicated earlier, we will typically be looking for relations between specified types of named entity. One way of approaching this task is to initially look for all triples of the form (X, α, Y), where X and Y are named entities of the required types, and α is the string of words that intervenes between X and Y. We can then use regular expressions to pull out just those instances of α that express the relation that we are looking for. The following example searches for strings that contain the word in. The special regular expression (?!\b.+ing\b) is a negative lookahead assertion that allows us to disregard strings such as success in supervising the transition of, where in is followed by a gerund.

# %%
IN = re.compile(r'.*\bin\b(?!\b.+ing)')
for doc in nltk.corpus.ieer.parsed_docs('NYT_19980315'):
    for rel in nltk.sem.extract_rels('ORG', 'LOC', doc, corpus='ieer', pattern = IN):
        print (nltk.sem.rtuple(rel))
        
# Not sure I completely understand this regular expression. Come back...
# However, this is pretty damn impressive.

# %% [markdown]
# Searching for the keyword in works reasonably well, though it will also retrieve false positives such as [ORG: House Transportation Committee] , secured the most money in the [LOC: New York]; there is unlikely to be simple string-based method of excluding filler strings such as this.
#
# As shown above, the conll2002 Dutch corpus contains not just named entity annotation but also part-of-speech tags. This allows us to devise patterns that are sensitive to these tags, as shown in the next example. The method show_clause() prints out the relations in a clausal form, where the binary relation symbol is specified as the value of parameter relsym [1].

# %%
from nltk.corpus import conll2002
vnv = """
    (
    is/V|    # 3rd sing present and
    was/V|   # past forms of the verb zijn ('be')
    werd/V|  # and also present
    wordt/V  # past of worden ('become)
    )
    .*       # followed by anything
    van/Prep # followed by van ('of')
    """
VAN = re.compile(vnv, re.VERBOSE)
for doc in conll2002.chunked_sents('ned.train'):
    for r in nltk.sem.extract_rels('PER', 'ORG', doc, corpus='conll2002', pattern=VAN):
        print  (nltk.sem.clause(r, relsym="VAN"))

# %% [markdown]
# Note
#
# Your Turn: Replace the last line [1], by print show_raw_rtuple(rel, lcon=True, rcon=True). This will show you the actual words that intervene between the two NEs and also their left and right context, within a default 10-word window. With the help of a Dutch dictionary, you might be able to figure out why the result VAN('annie_lennox', 'eurythmics') is a false hit.

# %%
for doc in conll2002.chunked_sents('ned.train'):
    for r in nltk.sem.extract_rels('PER', 'ORG', doc, corpus='conll2002', pattern=VAN):
        print  (nltk.sem.rtuple(rel, lcon=True, rcon=True))

# %% [markdown]
# Dr. Bell - you completed Chapter 7...
